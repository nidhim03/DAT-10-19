# %% [markdown]
# ### Unit 1 Homework:  Scraping the Yelp Website
#
# Welcome!  For this homework assignment you'll be tasked with building a web scraper in a manner that builds on what was covered in our web scraping class.
#
# The assignment will extend the lab work done during that time, where we built a dataset that listed the name, number of reviews and price range for restaurant on the following web page: https://www.yelp.com/search?find_desc=Restaurants&find_loc=London%2C%20United%20Kingdom&ns=1
#
# **What You'll Turn In:**
#
# A finished jupyter notebook that walks us through the steps you took in order to get your results.  Provide notes where appropriate to explain what you are doing.
#
# The notebook should produce a finished dataset at the end.
#
# If for some reason you're experiencing problems with the final result, please let someone know when turning it in.
#
# Your homework will be divided into three tiers, each of which have increasing levels of difficulty:
#
# ##### Tier 1: Five Columns From the First Page
#
# At the most basic level for this assignment, you will need to extend what we did in class, and create a dataset that has five columns in it that are 30 rows long.  This means you will not need to go off the first page in order to complete this section.
#
# ##### Tier 2:  100 Row Dataset With At Least 3 Columns
#
# For this portion of the assignment, take 3 of your columns from step 1, and extend them out to multiple pages on the yelp website.  You should appropriately account for the presence of missing values.
#
# ##### Tier 3:  100 Row Dataset With At Least 5 Columns
#
# Very similar to Tier 2, but if you use this many columns you will be forced to encounter some columns that will frequently have missing values, whereas with Tier 2 you could likely skip these if you wanted to.
#
# ##### Tier 4:  100 Row Dataset With At Least 5 Columns + Individual Restaurant Categories
#
# Restaurants often have different categories associated with them, so grabbing them individually as separate values is often challenging.  To complete this tier, you'll have to find a way to 'pick out' each of the individual categories as their own separate column value.
#
# ##### Tier 5:  Unlimited Row Dataset With At Least 5 Columns + Individual Restaurant Categories
#
# Take what you did in Tier 4, and extend it so that the code will work with an arbitrary number of pages.  Ie, regardless of how many pages there are listing the best restaurants in London, your scraper will find them, and cleanly parse their information into clean datasets.
#
# ### Hints
#
# Here are a few tips that will save you time when completing this assignment:
#
#  - The name, average rating, total ratings and neighborhood of a restaurant tend to be the 'easy' ones, because they rarely have missing values, so what ever logic you use on the first page will typically apply to all pages.  They are a good place to start
#  - Phone numbers, price ranges and reviews are more commonly missing, so if you are trying to get a larger number of items from them across multiple pages you should expect to do some error handling
#  - You can specify any sort of selector when using the `find_all()` method, not just `class`.  For example, imagine you have the following `<div>` tag:
#     `<div class='main-container red-blue-green' role='front-unit' aria-select='left-below'>Some content here</div>`
#
#    This means that when you use `scraper.find_all('div')`, you can pass in arguments like `scraper.find_all('div', {'role': 'front-unit'})` or anything else that allows you to isolate that particular tag.
#  - When specifying selectors like `{'class': 'dkght__384Ko'}`, sometimes less is more.  If you include multiple selectors, you are saying return a tag with **any one of these** distinctions, not all of them.  So if your results are large, try different combinations of selectors to get the smallest results possible.
#  - If you begin dealing with values that are unreliably entered, you should use the 'outside in' technique where you grab a parent container that holds the element and find a way to check to see if a particular value is there by scraping it further.  The best way to do this is to try and find a unique container for every single restaurant.  This means that you will have a reliable parent element for every single restaurant, and within *each of these* you can search for `<p>`, `<a>`, `<div>`, and `<span>` tags and apply further logic.
#  - When you get results from `BeautifulSoup`, you will be given data that's denoted as either `bs4.element.Tag` or `bs4.element.ResultSet`.  They are **not the same**.  Critically, you can search a `bs4.element.Tag` for further items, but you cannot do this with a `bs4.element.ResultSet`.
#
#    For example, let's say you grab all of the divs from a page with `scraper.find_all('div')` and save it as the variable `total_divs`.  This means `total_divs` will look somethig like this:
#
#    `[<div><p>Div content</p><p>Second paragraph</p></div>,`
#       `<div><p>Div content</p><p>Second paragraph</p></div>,`
#       `<div><p>Div content</p><p>Second paragraph</p></div>]`
#
#    In this case the variable `total_divs` is a result set and there's nothing else you can do to it directly.  However, every item within `total_divs` is a tag, which means you can scrape it further.
#
#    So if you wanted you could write a line like:  `total_paragraphs = [div.find_all('p') for div in total_divs]`, and get the collection of paragraphs within each div.
#
#    If you confuse the two you'll get the following error message:
#
#    `AttributeError: ResultSet object has no attribute 'find_all'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?`
#  - The values of the different selectors change periodically on yelp, so if your scraper all of a sudden stops working that's probably why.  Ie, if you have a command like `scraper.find_all('div', {'class': '485dk0W__container09'}` that no longer returns results, the class `485dk0W__container09` may now be `r56kW__container14` or something similar.

# %% [markdown]
# # Yelp Reviews Code

# %% [markdown]
# First, I start by importing various libraries to help with my web scraping functions. I also define the London Yelp url here so that it can be reused throughout as a variable.
#
# **Note**: In future enhancements for this code, I would like to implement a feature that allows users to directly call the city they want to search for reviews for.

# %%
# your code here
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import math
import numpy as np

yelp_url = 'https://www.yelp.com/search?find_desc=Restaurants&find_loc=London%2C%20United%20Kingdom&ns=1'

# %% [markdown]
# To find useful data to collect from the Yelp page, I first scanned the webpage and noticed that each restaurant had a name, category, and rating. Most restaurants also had reviews and a cost rating, too. To systematically select those values for each record, I inspected the HTML to see the classes of the HTML tags the data was contained in (e.g. div or a).
#
# The most difficult value to get was the star rating, because each rating tier (4 star, 4.5 star, etc.) had its own unique class. I used a regular expression module to do a partial match for the term "i-stars" which was contained in each class name. I then used the text in the aria-label to determine what the rating was and converted that value to a float.
#
# To get rid of the pound symbol representing cost, I simply counted the length of the string and used an integer to represent it instead.

# %%
def find_yelp_reviews(restaurant_data):
    """Helper function that returns a dictionary with restauraunt names, cost, reviews, ratings, and 
    categories for a given Yelp page. """
    restaurants = []
    for restaurant in restaurant_data:
        d = dict()
        categories = []
        name = restaurant.find('a', class_='link__09f24__1kwXV link-color--inherit__09f24__3PYlA link-size--inherit__09f24__2Uj95')
        try:
            name = name.text
        except AttributeError:
            name = False
        if name:
            #only do further data work if the restaurant has a valid name; 
            #otherwise skip to the next restaurant in the data set
            
            #checking for null values of category so the code doesn't blow up; skips if no valid category
            categories_data = restaurant.find_all('a', class_='link__09f24__1kwXV link-color--inherit__09f24__3PYlA link-size--default__09f24__3xWLF')
            for data in categories_data:
                try:
                    categories.append(data.text)
                except AttributeError:
                    pass

            # trying to generate a cost rating
            cost = restaurant.find('span', class_="text__09f24__2tZKC priceRange__09f24__2O6le text-color--black-extra-light__09f24__38DtK text-align--left__09f24__3Drs0 text-bullet--after__09f24__1MWoX")
            try:
                cost = str(len(cost.text))
            except AttributeError:
                cost = ''
                
            # trying to generate number of reviews
            num_reviews = restaurant.find('span', class_="text__09f24__2tZKC reviewCount__09f24__EUXPN text-color--black-extra-light__09f24__38DtK text-align--left__09f24__3Drs0")
            try:
                num_reviews = int(num_reviews.text)
            except AttributeError:
                num_reviews = 0
                
            # trying to generate a rating
            rating = restaurant.find('div', class_=re.compile("i-stars"))
            try:
                rating = float(rating['aria-label'].split()[0])
            except AttributeError:
                rating = 0
            except TypeError:
                rating = 0
            #building out a dictionary with the restaurant's attributes
            d['Name'] = name
            d['Rating'] = rating
            d['Cost'] = cost
            d['Reviews'] = num_reviews
            
            # building new columns for each category:
            for i in range(0,len(categories)):
                d[f"Category {i+1}"] = categories[i]
            
            
            # adding completed dictionary for the current page
            restaurants.append(d)
    
    return restaurants

# %% [markdown]
# Once I could reliably capture all restaurant data on a single page, the next step was to extend that functionality to find all restaurants across all search results pages. I did this by noticing that on each results page, the website tells how many total result pages there are. In the case of the London restaurants, there are 24. I also noticed that on subsequent results pages, there's a "&start=" appended to the url, indicating which result to display first. Because there are 10 restaurants listed per results page, that means the final page could be found by subtracting one from the totaly number of pages and multiplying by 10. So in the case of the London data, the last page would have "&start=230" ending the url. I tested this by trying numbers larger than that, and the website returned an error.
#
# To get data on all resturants, then, I simply ran the above function on each page in a loop and then combined all of the results into a final data frame. I paginated by adding 10 to the "&start=" after each url in the range 0 to max pages. Note that these calculations are performed in the function itself, so the function can be used on any Yelp restaurant results page without the user having prior knowledge about the number of results.
#
# I additionally tested that this function can be generally used on other cities by finding all results for Gaithersburg, Maryland, where I live.

# %%
def display_yelp_reviews(url):
    """Takes a Yelp url and returns a Data Frame with restaurant data for all restaurants in that location."""
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    
    #Find the total number of pages to determine how many times to loop to get data. Loop should end at (n-1)*10
    num_pages = soup.find('span', class_="text__09f24__2tZKC text-color--black-extra-light__09f24__38DtK text-align--left__09f24__3Drs0")
    max_start = ((int(num_pages.text.split()[2]))-1)*10
        
    restaurants = []
    
    for index in range(0,max_start+1,10):
        current_page = requests.get(url+'&start='+str(index))
        current_soup = BeautifulSoup(current_page.content, 'html.parser')
        restaurant_data = current_soup.find_all('li', class_='border-color--default__09f24__R1nRO')
        
        restaurants += find_yelp_reviews(restaurant_data)
    
    
    return pd.DataFrame(restaurants).replace({np.nan: None})

# %%
london_data = display_yelp_reviews(yelp_url)

# %%
pd.set_option('display.max_rows', None)
# sorting based on rating

london_data.sort_values(by=['Rating'], ascending=False)
# Out:
#                                               Name  Rating Cost  Reviews  \
# 68                                 Naughty Piglets     5.0    2       10
# 172                                      Bento Bab     5.0    1       10
# 27                            Kennington Lane Cafe     5.0    1       98
# 199                                         Kibele     5.0    2        7
# 114                                      Roast Hog     5.0    1       10
# 143                                           Kazu     5.0             2
# 209                                 Bánh Mì Hoi-An     5.0    1        4
# 18                             The Ivy In the Park     5.0             5
# 212                                      Tanakatsu     5.0             4
# 16                                  Piebury Corner     5.0    1       35
# 214                          Fondue Factory London     5.0             1
# 218                                           Rumi     5.0             3
# 109                                   Warisan Cafe     5.0             4
# 148                                    Cafe Vienna     5.0    2        3
# 99                                       Tanakatsu     5.0             4
# 3                                The Golden Chippy     5.0    2      107
# 157                                  Carl’s Tavern     5.0    2        1
# 187                          Alexandrie Restaurant     5.0    3        5
# 224                                      Bento Bab     5.0    1       10
# 223                          Frog By Adam Handling     5.0             9
# 152                  London House by Gordon Ramsay     4.5    3       23
# 154                          The Crown and Sceptre     4.5    2       22
# 147                                        Dishoom     4.5    2      386
# 146                                        Cottons     4.5    2        9
# 142                       Orjowan Lebanese Cuisine     4.5    2      105
# 131                                     Makan Café     4.5    1       32
# 141                                       Boqueria     4.5    2       11
# 159                                 Maggie Jones’s     4.5    3      119
# 138                      Dominique Ansel Treehouse     4.5             3
# 133                                        Domo 94     4.5    2       17
# 156                                          Ma Po     4.5    2        5
# 0                               The Mayfair Chippy     4.5    2      280
# 121                              The Blues Kitchen     4.5    2       17
# 1                              Ffiona’s Restaurant     4.5    2      269
# 117                            Da Mario Restaurant     4.5    2      140
# 115                                          Abeno     4.5    2      101
# 161  Honest Burgers Meard St - Soho - Temp. CLOSED     4.5    2      277
# 113                                    The Ledbury     4.5    4      167
# 112                                      Ngon Ngon     4.5    2       57
# 110                                   The Victoria     4.5    2      215
# 103             Duck & Waffle Local - Temp. CLOSED     4.5    2      142
# 100                                  Flour & Grape     4.5    2       26
# 97                           Market Halls Victoria     4.5            10
# 96                                       Nambu Tei     4.5    2       34
# 95                                Cambridge Street     4.5    2       50
# 94                     Lots Road Pub & Dining Room     4.5    2       21
# 93                                      Laksamania     4.5            11
# 160                                        Santore     4.5    2       58
# 171                         Toff’s of Muswell Hill     4.5    2       52
# 162                                   Bistro Union     4.5    2       11
# 219                           Lobos Meat and Tapas     4.5    3       30
# 204                                Band of Burgers     4.5    2       10
# 205                                  Sandwich Shop     4.5    1       33
# 206                        Wok to Walk - Oxford St     4.5    1       16
# 207                                 Mezcal Cantina     4.5             5
# 208                                      Flat Iron     4.5             3
# 213                         The Palomar Restaurant     4.5    3      104
# 220                         O Cantinho De Portugal     4.5    2       13
# 163                                      Flat Iron     4.5             3
# 222                                     Homeburger     4.5    2       14
# 225                               The Harwood Arms     4.5    3      128
# 230                                    The Ledbury     4.5    4      167
# 231                                Moroccan Sahara     4.5    2       17
# 232                                 Tea and Tattle     4.5    2       80
# 237                                      Tanakatsu     4.5    1        3
# 198                                 Persian Nights     4.5             2
# 195                         Hackney Church Brew Co     4.5             3
# 189                               Burger & Lobster     4.5    2       93
# 186                                    Roast To Go     4.5    1       36
# 185                                    Shake Shuka     4.5    1       20
# 183                                  Hungry Donkey     4.5    2       13
# 182                                           Azou     4.5    2       22
# 181                            Max’s Sandwich Shop     4.5    1       10
# 180                                The Stoke House     4.5    2       31
# 178                                   Seoul Bakery     4.5    1       40
# 175                                    Patty & Bun     4.5    2      185
# 173                       Master Wei Xi’An Cuisine     4.5            10
# 84                             Core by Clare Smyth     4.5            18
# 169                                     Roti Joupa     4.5    2       34
# 168                                   La Tua Pasta     4.5            17
# 167                                    Texas Joe’s     4.5    2       22
# 164                           CASK Pub and Kitchen     4.5    2      139
# 91                              The Queen of Sheba     4.5    2       22
# 120                               Circolo Popolare     4.5            11
# 83                                 Sichuan Kitchen     4.5    2        5
# 64                          Where the Pancakes are     4.5    2       74
# 43                                Black Axe Mangal     4.5    2       10
# 46                           Goddards at Greenwich     4.5    1       84
# 48                                       Ngon Ngon     4.5    2       57
# 49                                            HOOK     4.5    2       73
# 52                                            Milk     4.5    2       49
# 53              Wright Brothers - South Kensington     4.5    2       22
# 54                       BunBunBun Vietnamese Food     4.5    2       33
# 55                             Bradleys Restaurant     4.5    2       10
# 56                                            José     4.5    2       82
# 57                                         Gökyüzü     4.5    2       59
# 58                                    Regency Café     4.5    1      393
# 59                           Homeslice Neal’s Yard     4.5    2      227
# 60                         African Kitchen Gallery     4.5    2       16
# 61                          Cirilo Filipino Kainan     4.5    2       45
# 62                             The Colonel Fawcett     4.5    2       26
# 41                          Boxcar Butcher & Grill     4.5    2       23
# 38                                         Jasmine     4.5    2       35
# 36                                         Dishoom     4.5    2      491
# 17                                         Dishoom     4.5    2      545
# 2                                          Dishoom     4.5    2     1840
# 4                                          Padella     4.5    2      205
# 5                                        Flat Iron     4.5    2      380
# 6                                  The Queens Arms     4.5    2      118
# 7                      The Fat Bear - Temp. CLOSED     4.5    2      122
# 10                                       Flat Iron     4.5    2      380
# 22                                    Savoir Faire     4.5    2      194
# 35                      Gordon Ramsay Street Pizza     4.5    2       30
# 23                             The Pig and Butcher     4.5    2      109
# 24                                   Monohon Ramen     4.5    2       16
# 25                    Bang Bang Oriental Food Hall     4.5    2       12
# 28                                        The Shed     4.5    2       78
# 30                                       Jin Kichi     4.5    2       42
# 33                        Street Hawker Restaurant     4.5    2        6
# 63                         Bailey’s Fish and Chips     4.5    1      132
# 47                                           Kazan     4.5    2      112
# 239                                     Homeburger     4.5    2       14
# 66                                       Mamak Don     4.5             4
# 72                                       Gunpowder     4.5    2       46
# 75                                      Maroush II     4.5    2       98
# 80                                   Eat Aroi Thai     4.5    2       23
# 71                                       Kanada-Ya     4.5    2      165
# 70                                            Azou     4.5    2       22
# 67                                       Pho House     4.5    2       23
# 78                                    The Victoria     4.5    2      215
# 82                             Da Mario Restaurant     4.5    2      140
# 191                               Okan Okonomiyaki     4.0    1       36
# 200                                        The Cow     4.0    2       54
# 76                                          Negril     4.0    2       54
# 184                                     Holly Bush     4.0    2      118
# 32                         Ye Olde Cheshire Cheese     4.0    2      352
# 79                                 The Chelsea Pig     4.0    2       20
# 203                                    Snaps & Rye     4.0    2       12
# 31                                         Nando’s     4.0    2       95
# 98                                  Belgo Centraal     4.0    2      319
# 202                         Hana Korean Restaurant     4.0    3       11
# 201                                         Gloria     4.0            10
# 188                                    Mama’s Jerk     4.0    1        4
# 192                                    Dirty Bones     4.0    2       42
# 29                              Lanzhou Noodle Bar     4.0    1      351
# 26                                      Ottolenghi     4.0    2      212
# 197                               The Queen’s Arms     4.0    2      127
# 190                      Street Feast Hawker House     4.0    2       17
# 21                                      BAO - Soho     4.0    2      185
# 196                                    Bao Borough     4.0            12
# 77                             Kintan Japanese BBQ     4.0    2       51
# 194                                    Firecracker     4.0    2       48
# 193                                    Giant Robot     4.0             1
# 81                                       Roti Chai     4.0    2      296
# 211                               Burger & Lobster     4.0    2      291
# 20                                Laughing Halibut     4.0    2      242
# 19                                         Tayyabs     4.0    2      684
# 238                             Tokyo Sukiyaki-Tei     4.0    3        5
# 86                                 The Barge House     4.0    2       27
# 236                                 Little Georgia     4.0    2       15
# 235                               The Queen’s Arms     4.0    2      127
# 234                                       Mes Amis     4.0    2        5
# 233                               101 Thai Kitchen     4.0    2       23
# 87                            Phat Phuc Noodle Bar     4.0    1       57
# 88                                       Zeitgeist     4.0    2       27
# 229                                       Chilango     4.0    1      153
# 227                         The Ivy Chelsea Garden     4.0    3       70
# 226                             Tokyo Sukiyaki-Tei     4.0    3        5
# 90                           Golden Union Fish Bar     4.0    2      299
# 8                                      Mother Mash     4.0    2      468
# 9                                 The Grazing Goat     4.0    2      242
# 221                            Holborn Dining Room     4.0    3       41
# 11                                    Maria Sabina     4.0            10
# 12                              Lanzhou Noodle Bar     4.0    1      351
# 13                                The Grazing Goat     4.0    2      242
# 216                    Original Lahore Kebab House     4.0    2      138
# 215                            Tsiakkos & Charcoal     4.0    2       12
# 14                                         Chee Mc     4.0    2       13
# 15                                      BAO - Soho     4.0    2      185
# 92                                        Bleecker     4.0    2       85
# 34                                         Chee Mc     4.0    2       13
# 65                        Xi’An BiangBiang Noodles     4.0            16
# 122                                    The Brigade     4.0    2       31
# 136                                           Fego     4.0    2       13
# 179                                     Ottolenghi     4.0    2       77
# 150                                 Electric Diner     4.0    2      109
# 149                                            BAO     4.0    2       45
# 111                                     On The Bab     4.0    2       92
# 145                              Addie’s Thai Cafe     4.0    2      115
# 69                                       The Table     4.0    2      265
# 116                                       Bizzarro     4.0    2      149
# 140                                        The Cow     4.0    2       54
# 139                   Murger Han Xi’ An Restaurant     4.0    2       15
# 137                                         Tukdin     4.0    2       57
# 135                                       The Swan     4.0    2      115
# 73                                            Naru     4.0    2       66
# 134                                         Lupita     4.0    2       44
# 118                                 Dragonfly Cafe     4.0    1       23
# 119                                         Negril     4.0    2       54
# 130                                    Satay House     4.0    2       79
# 129                                   La Patagonia     4.0    2       35
# 128                              Xi’an Impressions     4.0    2       27
# 127                                The Golden Hind     4.0    2      253
# 126                                        Mestizo     4.0    2      152
# 125                      Scoff & Banter Kensington     4.0    2       42
# 124                                        A. Wong     4.0    2       55
# 153                                         Wahaca     4.0    2      311
# 151                                         Dotori     4.0    2       52
# 155                                Paradise Garage     4.0    2       12
# 166                                  The Blackbird     4.0    2      159
# 37                                      On The Bab     4.0    2       92
# 177                                 805 Restaurant     4.0    2       20
# 176                               Burger & Lobster     4.0    2      291
# 102                                        Lemonia     4.0    2       94
# 174                           Fish, Wings, & Tings     4.0    2       31
# 39                                        Bizzarro     4.0    2      149
# 40                                         Poppies     4.0    2      341
# 74                                 Burger & Beyond     4.0             7
# 170                                   NoorJahan II     4.0    2      135
# 42                                    Shoryu Ramen     4.0    2      375
# 108                                  Taste Of Siam     4.0    2       60
# 44                              The Churchill Arms     4.0    2      357
# 104                                       Rasputin     4.0    2        2
# 165                                       Thailand     4.0    2       17
# 45                                    The Ivy Café     4.0    2       13
# 51                                   Lan Kwai Fong     4.0             1
# 158                                    Busaba Soho     4.0    2      381
# 50                              The Breakfast Club     4.0    2      495
# 107                              Masters Superfish     4.0    2      154
# 106                                    Royal China     4.0    2      104
# 101                                    Pieminister     4.0    1       89
# 85                                    Granger & Co     4.0    2      182
# 105                            Carmen Bar De Tapas     4.0    2       22
# 89                                         Kimchee     3.5    2      124
# 217                                        K Place     3.5    2       30
# 228                                      El Vergel     3.5    1       15
# 132                                   The Rosemary     3.5    2        5
# 123                             China Palace Excel     3.5    2       32
# 144                                        K Place     3.5    2       30
# 210                   Shake Shack Leicester Square     3.0    2       33
#
#                  Category 1              Category 2              Category 3
# 68          Modern European                    None                    None
# 172                  Korean                    None                    None
# 27                    Cafes                    None                    None
# 199                 Turkish                    None                    None
# 114              Portuguese             Food Stands                    None
# 143                Japanese              Sushi Bars                    None
# 209              Vietnamese                    None                    None
# 18                  British                    None                    None
# 212                Japanese                    None                    None
# 16                  British                    None                    None
# 214                  Fondue                    None                    None
# 218         Persian/Iranian          Middle Eastern                    None
# 109               Malaysian                    None                    None
# 148                Austrian                    None                    None
# 99                 Japanese                    None                    None
# 3              Fish & Chips                    None                    None
# 157              Australian                    None                    None
# 187           Mediterranean          Middle Eastern                    None
# 224                  Korean                    None                    None
# 223         Modern European                 British                    None
# 152         Modern European                    None                    None
# 154              Gastropubs                    None                    None
# 147                  Indian      Breakfast & Brunch                    None
# 146               Caribbean                    Bars                    None
# 142          Middle Eastern                    None                    None
# 131               Malaysian                    None                    None
# 141                 Spanish              Tapas Bars                    None
# 159                 British                    None                    None
# 138                Bakeries                 Bistros                    None
# 133                 Italian                    None                    None
# 156                Szechuan                    None                    None
# 0              Fish & Chips                    None                    None
# 121          American (New)      Breakfast & Brunch                    None
# 1                   British                    None                    None
# 117                 Italian                    None                    None
# 115                Japanese                    None                    None
# 161                 Burgers                    None                    None
# 113         Modern European                    None                    None
# 112              Vietnamese                 Noodles                    None
# 110                    Pubs                 British                    None
# 103                    Bars                 Waffles                    None
# 100                 Italian               Wine Bars                    None
# 97               Food Court                    None                    None
# 96                 Japanese                    None                    None
# 95                  British                    None                    None
# 94               Gastropubs                    None                    None
# 93                Malaysian                    None                    None
# 160                 Italian                    None                    None
# 171            Fish & Chips                 British                    None
# 162                 British                    None                    None
# 219      Tapas/Small Plates              Tapas Bars                 Spanish
# 204                 Burgers                    None                    None
# 205              Sandwiches                    None                    None
# 206                    Thai            Asian Fusion              Vegetarian
# 207                 Tex-Mex                 Mexican           Cocktail Bars
# 208             Steakhouses                    None                    None
# 213          Middle Eastern           Mediterranean                    None
# 220              Portuguese                    None                    None
# 163             Steakhouses                    None                    None
# 222                 Burgers                    None                    None
# 225              Gastropubs                 British                    None
# 230         Modern European                    None                    None
# 231                Moroccan                    None                    None
# 232                 British            Coffee & Tea                    None
# 237                Japanese          Street Vendors                    None
# 198         Persian/Iranian                    None                    None
# 195                Brewpubs                    Pubs             Restaurants
# 189  American (Traditional)                 Seafood                 Burgers
# 186             Food Stands                    None                    None
# 185                Lebanese                    None                    None
# 183                   Greek                    None                    None
# 182                 African                Moroccan                    None
# 181              Sandwiches                    None                    None
# 180                 British             Steakhouses                    None
# 178                   Cafes                  Korean                    None
# 175                 Burgers                    None                    None
# 173                 Chinese                    None                    None
# 84                  British                    None                    None
# 169               Fast Food               Caribbean                    None
# 168                 Italian                    Food                    None
# 167                Barbeque                    None                    None
# 164                    Pubs              Gastropubs                    None
# 91                Ethiopian                 African                    None
# 120                 Italian                    None                    None
# 83                 Szechuan                    None                    None
# 64                 Pancakes                    None                    None
# 43                  Turkish                    None                    None
# 46                  British                    None                    None
# 48               Vietnamese                 Noodles                    None
# 49             Fish & Chips                 Seafood                    None
# 52             Coffee & Tea      Breakfast & Brunch                    None
# 53                  Seafood                    None                    None
# 54               Vietnamese                    None                    None
# 55                  British         Modern European                    None
# 56                  Spanish              Tapas Bars                    None
# 57                  Turkish                    None                    None
# 58                    Cafes                    None                    None
# 59                    Pizza                    None                    None
# 60                  African                    None                    None
# 61                 Filipino                    None                    None
# 62               Gastropubs                    None                    None
# 41                  Butcher                   Delis                    None
# 38                     Thai                    None                    None
# 36                   Indian      Breakfast & Brunch                    None
# 17                   Indian                    None                    None
# 2                    Indian                    None                    None
# 4                   Italian                    None                    None
# 5               Steakhouses                    None                    None
# 6                   British                    Pubs              Gastropubs
# 7    American (Traditional)               Soul Food            Cajun/Creole
# 10              Steakhouses                    None                    None
# 22                   French                    None                    None
# 35                    Pizza                    Bars                    None
# 23                  British              Gastropubs                    None
# 24                    Ramen                    None                    None
# 25                Pan Asian                    None                    None
# 28                  British                    None                    None
# 30                 Japanese              Sushi Bars                    None
# 33             Asian Fusion                    None                    None
# 63             Fish & Chips                    None                    None
# 47                  Turkish                    None                    None
# 239                 Burgers                    None                    None
# 66                Malaysian                    None                    None
# 72                   Indian                    None                    None
# 75           Middle Eastern                    None                    None
# 80                     Thai                    None                    None
# 71                    Ramen                    None                    None
# 70                  African                Moroccan                    None
# 67               Vietnamese                    None                    None
# 78                     Pubs                 British                    None
# 82                  Italian                    None                    None
# 191                Japanese          Street Vendors                    None
# 200                 British              Gastropubs                    None
# 76                Caribbean                    None                    None
# 184                    Pubs              Gastropubs                    None
# 32                     Pubs                 British                    None
# 79               Gastropubs                    None                    None
# 203            Scandinavian                    None                    None
# 31             Chicken Shop               Fast Food                    None
# 98                  Belgian                    None                    None
# 202                  Korean                    None                    None
# 201                 Italian                    None                    None
# 188               Caribbean                    None                    None
# 192                    Bars  American (Traditional)                    None
# 29                  Chinese                 Noodles                    None
# 26            Mediterranean         Modern European                    None
# 197                    Pubs                 British                    None
# 190             Food Stands                    None                    None
# 21                Taiwanese                    None                    None
# 196                 Chinese                 Karaoke               Taiwanese
# 77                 Japanese                Barbeque      Tapas/Small Plates
# 194            Asian Fusion                 Karaoke                    None
# 193             Food Stands                    None                    None
# 81                   Indian                   Kebab                    None
# 211                 Seafood                 Burgers                    None
# 20             Fish & Chips                    None                    None
# 19                   Indian               Pakistani                   Halal
# 238                Japanese                    None                    None
# 86                  Lounges                 British                    None
# 236                Georgian                    None                    None
# 235                    Pubs                 British                    None
# 234          Middle Eastern                    None                    None
# 233                    Thai                    None                    None
# 87               Vietnamese                 Noodles                    None
# 88                   German                    None                    None
# 229                 Mexican                    None                    None
# 227                 British                    Bars                    None
# 226                Japanese                    None                    None
# 90             Fish & Chips                    None                    None
# 8                   British                    None                    None
# 9                Gastropubs                 British                    None
# 221                 British                    Bars                    None
# 11                  Mexican                    None                    None
# 12                  Chinese                 Noodles                    None
# 13               Gastropubs                 British                    None
# 216                  Indian               Pakistani                   Halal
# 215                   Greek                    None                    None
# 14                   Korean                    None                    None
# 15                Taiwanese                    None                    None
# 92                  Burgers                    None                    None
# 34                   Korean                    None                    None
# 65                  Noodles                    None                    None
# 122                 British                    None                    None
# 136              Brasseries                    None                    None
# 179           Mediterranean         Modern European                    None
# 150                  Diners                    None                    None
# 149               Taiwanese                    None                    None
# 111                  Korean                    None                    None
# 145                    Thai                    None                    None
# 69                  British      Breakfast & Brunch                    Bars
# 116                 Italian                    None                    None
# 140                 British              Gastropubs                    None
# 139                 Chinese                    None                    None
# 137               Malaysian                    None                    None
# 135                    Pubs                 British                    None
# 73                   Korean                    None                    None
# 134                 Mexican                    None                    None
# 118              Vietnamese                 Noodles                    None
# 119               Caribbean                    None                    None
# 130               Malaysian                   Halal                    None
# 129               Argentine                    None                    None
# 128                Szechuan                    None                    None
# 127            Fish & Chips                    None                    None
# 126                 Mexican                    Bars                    None
# 125                 British                    None                    None
# 124                 Chinese                    None                    None
# 153                 Mexican                    None                    None
# 151                  Korean                Japanese                    None
# 155                 British                    None                    None
# 166                    Pubs                 British      Breakfast & Brunch
# 37                   Korean                    None                    None
# 177                 African                    None                    None
# 176                 Seafood                 Burgers                    None
# 102                   Greek                    None                    None
# 174               Fast Food               Caribbean                    None
# 39                  Italian                    None                    None
# 40             Fish & Chips               Fast Food                    None
# 74                  Burgers                    None                    None
# 170                  Indian                    None                    None
# 42                 Japanese                    None                    None
# 108                    Thai                    None                    None
# 44                     Pubs                    Thai                    None
# 104                 Russian                    None                    None
# 165                    Thai                    None                    None
# 45                    Cafes                    None                    None
# 51               Sushi Bars                 Dim Sum                    None
# 158                    Thai                    None                    None
# 50             Coffee & Tea      Breakfast & Brunch  American (Traditional)
# 107            Fish & Chips                    None                    None
# 106                 Dim Sum                    None                    None
# 101                 British                    None                    None
# 85                  British         Modern European      Breakfast & Brunch
# 105                 Spanish              Tapas Bars                    None
# 89                   Korean                    None                    None
# 217                  Korean                    None                    None
# 228          Latin American                    None                    None
# 132               Hungarian                    None                    None
# 123                 Chinese                    None                    None
# 144                  Korean                    None                    None
# 210                 Burgers          Milkshake Bars                Hot Dogs

# %%
# gaithersburg_data = display_yelp_reviews('https://www.yelp.com/search?find_desc=Restaurants&find_loc=Gaithersburg%2C%20Maryland&ns=1')
# gaithersburg_data = gaithersburg_data.replace({np.nan: None})
