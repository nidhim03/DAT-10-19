# %% [markdown]
# ## Homework 1: Advanced Track -- Harvest the Twitter API

# %% [markdown]
# **Objective:** Write a series of functions that allow you to dynamically harvest Twitter data.
#
# **Estimated Time to Complete:** 4-12 hours
#
# #### Sections
#
#  - **Section 1:** Setting up your developer account, using OAuth1 authentication (approx 45-120 minutes)
#  - **Section 2:** Navigating the API documentation, getting your first query string (approx 45-120 minutes)
#  - **Section 3:** Writing your API calls (approx 90 - 360 minutes)
#
# #### What You'll Turn In:
#  - A `.py` (not a Notebook!) file that contains the functions that you were prompted to create.  These should contain comments demonstrating why your code does what it does, and after it's run, the instructor should be able to make the appropriate function calls in Spyder or any other IDE.

# %% [markdown]
# ## Section 1:  Setting Up Your Developer Account

# %% [markdown]
# Most API's require you to do a little pre-work in order to be able to use them, so the first part of this homework assignment will be spent setting up your developer account so you have API Access.

# %% [markdown]
# **Step 1:  Create a Twitter Developer Account**
#
#  - Make sure you have a regular twitter account before you do this
#  - You can apply for a developer account here:  https://developer.twitter.com/en/apply-for-access
#   - Choose either a student or hobbyist/personal account

# %% [markdown]
# **Step 2:  Create An App**
#
# You don't have to intend to build an official software program to have an app.....this is just a way for you to get authentication keys to use with the API.
#
#  - Go to the menu in the upper right hand corner and click on **Your Name** > **Apps**
#  - Choose **Create An App**
#  - You'll be prompted to enter some information about your app.  Don't worry too much about this, it can say almost anything.  You'll be prompted to list websites where it will be hosted...this can be anything for now.  Use https://generalassemb.ly if you're undecided about what to put.

# %% [markdown]
# **Step 3: Create Your API Tokens**
#
# Now that you have an app, you can use its API tokens to go ahead and make requests like we did in class 3.  Like a lot of API's, the Twitter API uses something called OAuth authentication.
#
# If you didn't wait until the night before this assignment was due and have a spare 30 minutes, you can read a little about it here: https://oauth.net/
#
# In any event, you need API tokens in order to make requests.  Do the following:
#
#  - Go to the **Apps** section of your developer portal
#  - Click on the **Details** button for the app that you just created
#  - Click on the **Keys & Tokens** tab
#   - Two keys should already be given to you:  **API Key** & **API Secret Key**
#   - Two you have to generate:  **Access token** & **Access token secret**
#  - Generate your Access Token and Access Token Secret keys.  You'll need to write these down when you're done
#
# Now you're ready to make requests to the Twitter api.  Everytime you make a request, you'll need to include the 4 tokens you just created.  (You can always regenerate them for whatever reason).

# %% [markdown]
# **Step 4:  Your First Request**
#
# To make requests to the Twitter API you're going to need a module which is **not** already pre-installed in Anaconda. You'll need to install it via PIP, which is python's package manager.  It's called `requests_oauthlib`.  You can install this via Anaconda Prompt or Terminal by simply typing in the command `pip install requests_oauthlib`, and then you'll be finished.
#
# The logistics of making an OAuth1 authenticated request are very similar to what was done in class 3, but with a few additional steps.  You can see how to do it here:  https://requests.readthedocs.io/en/master/user/authentication/#oauth-1-authentication.  The only thing you'll need to change is the info for your API tokens that are passed into the `OAuth1()` function.
#
# Try making a request to the following URL to confirm that it works: 'https://api.twitter.com/1.1/account/verify_credentials.json'

# %%
# your code here
import requests
from requests_oauthlib import OAuth1

# passing in my developer tokens to the OAuth1 function
tokens = OAuth1('NOZHm1aLT1AVmchGbCmiZOAga', 'nPyaYCt8L7ymqGZtU8EqC0a2ypI9aSJgVNIhtoZ0wGsaf3BJw9',
                '1079981876864008192-AlhO4yOa06oW2sXZpLpWPwnOxEERYS', 'o3E0AsKJfDoTBk77UQYExzOG7E46jPYvpWNGAKsD6lUBY')

# url that I'm going to connect to
url = 'https://api.twitter.com/1.1/account/verify_credentials.json'

# initiate the request
req = requests.get(url, auth=tokens).json()

# %%
# and here it is
req
# Out:
# {'id': 1079981876864008192,
#  'id_str': '1079981876864008192',
#  'name': 'Jonathan Bechtel',
#  'screen_name': 'JonathanBechte6',
#  'location': '',
#  'description': '',
#  'url': None,
#  'entities': {'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 1,
#  'friends_count': 18,
#  'listed_count': 0,
#  'created_at': 'Tue Jan 01 06:05:19 +0000 2019',
#  'favourites_count': 1,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': False,
#  'verified': False,
#  'statuses_count': 1,
#  'lang': None,
#  'status': {'created_at': 'Fri Nov 29 23:27:52 +0000 2019',
#   'id': 1200557014067363843,
#   'id_str': '1200557014067363843',
#   'text': "@kunjanshah @paulg @Austen How do you define 'solved'?  I would define it as quality-adjusted real prices that go d… https://t.co/ghgIv3irn6",
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'kunjanshah',
#      'name': 'Kunjan Shah',
#      'id': 14828205,
#      'id_str': '14828205',
#      'indices': [0, 11]},
#     {'screen_name': 'paulg',
#      'name': 'Paul Graham',
#      'id': 183749519,
#      'id_str': '183749519',
#      'indices': [12, 18]},
#     {'screen_name': 'Austen',
#      'name': '🏜️ Austen Allred',
#      'id': 221838349,
#      'id_str': '221838349',
#      'indices': [19, 26]}],
#    'urls': [{'url': 'https://t.co/ghgIv3irn6',
#      'expanded_url': 'https://twitter.com/i/web/status/1200557014067363843',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': 1200483467529740288,
#   'in_reply_to_status_id_str': '1200483467529740288',
#   'in_reply_to_user_id': 14828205,
#   'in_reply_to_user_id_str': '14828205',
#   'in_reply_to_screen_name': 'kunjanshah',
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': 'F5F8FA',
#  'profile_background_image_url': None,
#  'profile_background_image_url_https': None,
#  'profile_background_tile': False,
#  'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#  'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#  'profile_link_color': '1DA1F2',
#  'profile_sidebar_border_color': 'C0DEED',
#  'profile_sidebar_fill_color': 'DDEEF6',
#  'profile_text_color': '333333',
#  'profile_use_background_image': True,
#  'has_extended_profile': False,
#  'default_profile': True,
#  'default_profile_image': True,
#  'following': False,
#  'follow_request_sent': False,
#  'notifications': False,
#  'translator_type': 'none',
#  'suspended': False,
#  'needs_phone_verification': False}

# %% [markdown]
# If you get your json object back, then you're good to go.

# %% [markdown]
# ## Section 2: Searching Tweets

# %% [markdown]
# Most websites you access will have a long string attached to the end of them that look something like this:  `http://thewebsite.com/?year=2019&color=golden%20yellow&user_id=48549395959438`.
#
# Most people have no reason to pay attention to any of this, but all the special symbols at the end are basically encoded commands that say 'return a website that displays x,y,z characteristics.'
#
# When accessing api data, it basically works the same way.

# %% [markdown]
# **Step 1:  Set Up Your First Query String**

# %% [markdown]
# If you go into Twitter and search for the term `Data Science`, you should be brought to a url that looks like this:  `https://twitter.com/search?q=Data%20Science&src=typed_query`
#
# If you'd like, you can drop the `&src=typed_query` from the url and still get the same results.
#
# There are some important details to pay attention to:
#
#  - Like class 3 when we worked with GitHub, there is a **base url**.  In this case it's `https://twitter.com/search`
#  - Whenever you enter a search for something, the base url will be followed by something that looks like `?q=My%20Search%20Term`
#   - The `?` marks the beginning of the query string.  This basically says 'initiate a request with whatever parameters that follow'
#   - The `q` is a **parameter**, essentially some condition to pass into the query string that determines what results will be given back to you.
#
# **Useful Thing To Do Right Now:** Go back to the Twitter search page, and just try searching for different things, and notice what shows up after the `q=`.  Here are some questions to ask yourself:
#
#  - How are white spaces encoded?  Ie, if you search for `Jonathan Bechtel` in the search box, what shows up to account for the space between the two words?
#  - What about hash symbols?  If you search for `#MeToo`, `#GirlsWhoCode` or `#DataScience`, what happens with that `#` symbol?
#  - Once you get the hang of this, see if you can just re-create some searches yourself by creating the url directly, and bypassing the search box altogether.
#
# Now, let's try and make a request for a search for `Data Science`.
#
# If you look at Twitter's docs, you'll see that the base url for the search API is `https://api.twitter.com/1.1/search/tweets.json`
#
# This means you have to add the `?q=Whatever%20Word%20%Goes%20Here` to the end to complete the search.
#
# So go ahead, and see if you can create your API call for a search for the term `Data Science`.
#
# If you did it correctly, you should have a dictionary with a key called `statuses`, and it'll be a list with all of the tweets returned by your search.

# %%
# your answer here
base_url = 'https://api.twitter.com/1.1/search/tweets.json'
search = '?q=Data%20Science'

req = requests.get(base_url + search, auth=tokens).json()

# %%
# and here's our dictionary, with our key that contains all the tweets returned by our response
req['statuses']
# Out:
# [{'created_at': 'Wed Oct 21 21:41:08 +0000 2020',
#   'id': 1319030987519569920,
#   'id_str': '1319030987519569920',
#   'text': '"J. Michael Lane, a General in the Rout of Smallpox, Dies at 84" by BY ROBERT D. MCFADDEN via NYT https://t.co/It3vYV5uhC',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/It3vYV5uhC',
#      'expanded_url': 'https://ift.tt/37pX9Lb',
#      'display_url': 'ift.tt/37pX9Lb',
#      'indices': [98, 121]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1229576562409967616,
#    'id_str': '1229576562409967616',
#    'name': '#Girlpower',
#    'screen_name': 'Data_is_God',
#    'location': '',
#    'description': 'Science and religion are two sides of same coin. \nTruman was the best president.\nNO unsolicited DMs.\nMask it or Casket.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 148,
#    'friends_count': 467,
#    'listed_count': 0,
#    'created_at': 'Tue Feb 18 01:21:55 +0000 2020',
#    'favourites_count': 8149,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 574,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1288998249827901441/RfGfwveH_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1288998249827901441/RfGfwveH_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1229576562409967616/1597370999',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:40:58 +0000 2020',
#   'id': 1319030944465080327,
#   'id_str': '1319030944465080327',
#   'text': 'RT @DD_FaFa_: Creativity in Data Science https://t.co/MjvpR0iiuV',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'DD_FaFa_',
#      'name': 'fafa.👩🏻\u200d💻',
#      'id': 2728657237,
#      'id_str': '2728657237',
#      'indices': [3, 12]}],
#    'urls': [{'url': 'https://t.co/MjvpR0iiuV',
#      'expanded_url': 'https://medium.com/glad-community/creativity-in-data-science-1faf259ca643',
#      'display_url': 'medium.com/glad-community…',
#      'indices': [41, 64]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1244361439927840768,
#    'id_str': '1244361439927840768',
#    'name': 'Luther Flagstad',
#    'screen_name': '_LutherAF_',
#    'location': 'Brooklyn, NY',
#    'description': 'Accidental Data Analyst. Tableau Desktop Certified Associate. Blog at https://t.co/4VgfBnRJrA and Tableau Public at https://t.co/eN6LCJtHTn.',
#    'url': None,
#    'entities': {'description': {'urls': [{'url': 'https://t.co/4VgfBnRJrA',
#        'expanded_url': 'http://vizstas.com',
#        'display_url': 'vizstas.com',
#        'indices': [70, 93]},
#       {'url': 'https://t.co/eN6LCJtHTn',
#        'expanded_url': 'http://tabsoft.co/3gIwHxF',
#        'display_url': 'tabsoft.co/3gIwHxF',
#        'indices': [116, 139]}]}},
#    'protected': False,
#    'followers_count': 552,
#    'friends_count': 1095,
#    'listed_count': 5,
#    'created_at': 'Sun Mar 29 20:31:10 +0000 2020',
#    'favourites_count': 1793,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 1000,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1244361688792604672/dXkvsTt6_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1244361688792604672/dXkvsTt6_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1244361439927840768/1589813843',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Oct 21 21:33:12 +0000 2020',
#    'id': 1319028991081152512,
#    'id_str': '1319028991081152512',
#    'text': 'Creativity in Data Science https://t.co/MjvpR0iiuV',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/MjvpR0iiuV',
#       'expanded_url': 'https://medium.com/glad-community/creativity-in-data-science-1faf259ca643',
#       'display_url': 'medium.com/glad-community…',
#       'indices': [27, 50]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://twitter.com/DD_FaFa_" rel="nofollow">FAFA_DD_App_2</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2728657237,
#     'id_str': '2728657237',
#     'name': 'fafa.👩🏻\u200d💻',
#     'screen_name': 'DD_FaFa_',
#     'location': 'Melbourne Australia',
#     'description': 'Customer Insights Director @DATAFYiNG \nI tweet mostly about #DataScience with #Coffee',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 23639,
#     'friends_count': 13814,
#     'listed_count': 738,
#     'created_at': 'Wed Aug 13 05:22:09 +0000 2014',
#     'favourites_count': 49792,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 103563,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/917289210289176576/JzqB9ZW6_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/917289210289176576/JzqB9ZW6_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2728657237/1409832944',
#     'profile_link_color': 'D81E5B',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 1,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:40:52 +0000 2020',
#   'id': 1319030921765572610,
#   'id_str': '1319030921765572610',
#   'text': 'When will the politicians follow the actual science that lockdowns kill? Here is more data to back that up. https://t.co/pGgjtPj9Q9',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/pGgjtPj9Q9',
#      'expanded_url': 'https://twitter.com/justin_hart/status/1318921146264252417',
#      'display_url': 'twitter.com/justin_hart/st…',
#      'indices': [108, 131]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 948576577821929477,
#    'id_str': '948576577821929477',
#    'name': 'Anonymous Because You People Are Crazy',
#    'screen_name': 'AnonBecauseOf',
#    'location': '',
#    'description': 'I love politics & reading. Most of all, I love the Lord Jesus. Be kind & tell the truth. The fear of the Lord is the beginning of wisdom.\n#ProLife #ProIsrael',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 5120,
#    'friends_count': 5271,
#    'listed_count': 0,
#    'created_at': 'Wed Jan 03 15:27:34 +0000 2018',
#    'favourites_count': 43402,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 6130,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1247043224184578049/KrxowRiT_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1247043224184578049/KrxowRiT_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/948576577821929477/1600877287',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': True,
#   'quoted_status_id': 1318921146264252417,
#   'quoted_status_id_str': '1318921146264252417',
#   'quoted_status': {'created_at': 'Wed Oct 21 14:24:40 +0000 2020',
#    'id': 1318921146264252417,
#    'id_str': '1318921146264252417',
#    'text': 'The CDC yesterday: "Adults aged 25–44 years have experienced the largest average percentage increase in the number… https://t.co/n2Qy7gnYNP',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/n2Qy7gnYNP',
#       'expanded_url': 'https://twitter.com/i/web/status/1318921146264252417',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 8349572,
#     'id_str': '8349572',
#     'name': 'Justin Hart',
#     'screen_name': 'justin_hart',
#     'location': 'San Diego, CA',
#     'description': 'Unraveling COVID-19 fears one chart at a time // mktg + AI // data, demographics, and steaks. justinhart.biz@gmail.com // claimed by @jennyerikson. Father to 7!',
#     'url': 'https://t.co/5LvqjDJ2U5',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/5LvqjDJ2U5',
#         'expanded_url': 'https://rationalground.com',
#         'display_url': 'rationalground.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 56000,
#     'friends_count': 5268,
#     'listed_count': 891,
#     'created_at': 'Wed Aug 22 06:00:16 +0000 2007',
#     'favourites_count': 9017,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 58144,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme17/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme17/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1136035242173538304/RFCc7ac4_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1136035242173538304/RFCc7ac4_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/8349572/1597341872',
#     'profile_link_color': '981CEB',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 500,
#    'favorite_count': 1078,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:40:18 +0000 2020',
#   'id': 1319030779352092672,
#   'id_str': '1319030779352092672',
#   'text': 'RT @Elon_Careers: Hey @elonbusiness Data Analytics majors! Join us next Tuesday to learn from a panel of accomplished data science professi…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'Elon_Careers',
#      'name': 'Elon Career Services',
#      'id': 25579747,
#      'id_str': '25579747',
#      'indices': [3, 16]},
#     {'screen_name': 'elonbusiness',
#      'name': 'Elon Business',
#      'id': 111416433,
#      'id_str': '111416433',
#      'indices': [22, 35]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 90931050,
#    'id_str': '90931050',
#    'name': 'Raghu Tadepalli',
#    'screen_name': 'tadepallir',
#    'location': 'Elon, NC',
#    'description': 'Dean, Love School of Business @ Elon University. I tweet on issues relating to business strategy, globalization and ethics. Views expressed are mine alone.',
#    'url': 'https://t.co/CuJRfXQcOD',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/CuJRfXQcOD',
#        'expanded_url': 'http://www.elon.edu/e-web/academics/business/dean.xhtml',
#        'display_url': 'elon.edu/e-web/academic…',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1382,
#    'friends_count': 344,
#    'listed_count': 86,
#    'created_at': 'Wed Nov 18 18:44:52 +0000 2009',
#    'favourites_count': 11618,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 7295,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'BADFCD',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme12/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme12/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/532850547/Raghu_200x270_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/532850547/Raghu_200x270_normal.jpg',
#    'profile_link_color': 'FF0000',
#    'profile_sidebar_border_color': 'F2E195',
#    'profile_sidebar_fill_color': 'FFF7CC',
#    'profile_text_color': '0C3E53',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Oct 21 21:00:47 +0000 2020',
#    'id': 1319020834284077056,
#    'id_str': '1319020834284077056',
#    'text': 'Hey @elonbusiness Data Analytics majors! Join us next Tuesday to learn from a panel of accomplished data science pr… https://t.co/QXZLkiDZY2',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'elonbusiness',
#       'name': 'Elon Business',
#       'id': 111416433,
#       'id_str': '111416433',
#       'indices': [4, 17]}],
#     'urls': [{'url': 'https://t.co/QXZLkiDZY2',
#       'expanded_url': 'https://twitter.com/i/web/status/1319020834284077056',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 25579747,
#     'id_str': '25579747',
#     'name': 'Elon Career Services',
#     'screen_name': 'Elon_Careers',
#     'location': 'Elon, NC and beyond!',
#     'description': 'Empowering Elon University students to find internships, jobs and achieve their career goals!',
#     'url': 'http://t.co/dk6lwCZoK4',
#     'entities': {'url': {'urls': [{'url': 'http://t.co/dk6lwCZoK4',
#         'expanded_url': 'http://www.elon.edu/careers',
#         'display_url': 'elon.edu/careers',
#         'indices': [0, 22]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 4259,
#     'friends_count': 589,
#     'listed_count': 175,
#     'created_at': 'Fri Mar 20 21:27:34 +0000 2009',
#     'favourites_count': 614,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 5859,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '660000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme5/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme5/bg.gif',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/721042854571683841/iWeHcpZ0_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/721042854571683841/iWeHcpZ0_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25579747/1602002436',
#     'profile_link_color': '9C7501',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': 'ECDC79',
#     'profile_text_color': '0D0D0D',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 2,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 2,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:39:54 +0000 2020',
#   'id': 1319030676855861250,
#   'id_str': '1319030676855861250',
#   'text': '@realDonaldTrump Will you stop calling Covid the plague &amp; China Virus. Follow the data &amp; the science. Start helping… https://t.co/MfZJqL8N6C',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'realDonaldTrump',
#      'name': 'Donald J. Trump',
#      'id': 25073877,
#      'id_str': '25073877',
#      'indices': [0, 16]}],
#    'urls': [{'url': 'https://t.co/MfZJqL8N6C',
#      'expanded_url': 'https://twitter.com/i/web/status/1319030676855861250',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [125, 148]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': 1319028572665700352,
#   'in_reply_to_status_id_str': '1319028572665700352',
#   'in_reply_to_user_id': 25073877,
#   'in_reply_to_user_id_str': '25073877',
#   'in_reply_to_screen_name': 'realDonaldTrump',
#   'user': {'id': 25685954,
#    'id_str': '25685954',
#    'name': 'Ellen Lee Schwartz',
#    'screen_name': 'Ellen_Lee3',
#    'location': 'New York, New York',
#    'description': 'Disabilities Advocate, Teacher, Writer, and Lover of all things Labrador Retriever. Not necessarily in that order. @Wellesley alumna',
#    'url': 'https://t.co/5BEZ271hj6',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/5BEZ271hj6',
#        'expanded_url': 'http://www.linkedin.com/in/ellenleeschwartz/',
#        'display_url': 'linkedin.com/in/ellenleesch…',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 700,
#    'friends_count': 2112,
#    'listed_count': 23,
#    'created_at': 'Sat Mar 21 15:31:17 +0000 2009',
#    'favourites_count': 6199,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 30490,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'BADFCD',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme12/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme12/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1170492914163703808/iw4hEcbH_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1170492914163703808/iw4hEcbH_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25685954/1567902233',
#    'profile_link_color': 'FF0000',
#    'profile_sidebar_border_color': 'F2E195',
#    'profile_sidebar_fill_color': 'FFF7CC',
#    'profile_text_color': '0C3E53',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:39:41 +0000 2020',
#   'id': 1319030621566619653,
#   'id_str': '1319030621566619653',
#   'text': 'JB is a fatuous windbag who has given all of us permission to only obey an authority if we deem them trustworthy. J… https://t.co/UUgItmFq5b',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/UUgItmFq5b',
#      'expanded_url': 'https://twitter.com/i/web/status/1319030621566619653',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 15744891,
#    'id_str': '15744891',
#    'name': 'Dennis Papp',
#    'screen_name': 'dennismpapp',
#    'location': 'Channahon, IL',
#    'description': 'Psalm 90 :: 2 Corinthians 4',
#    'url': 'https://t.co/Phwh59DJgV',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/Phwh59DJgV',
#        'expanded_url': 'http://dennismpapp.com',
#        'display_url': 'dennismpapp.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 102,
#    'friends_count': 203,
#    'listed_count': 1,
#    'created_at': 'Wed Aug 06 02:18:36 +0000 2008',
#    'favourites_count': 10831,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 4602,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1250136171063250947/wRnNUmku_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1250136171063250947/wRnNUmku_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15744891/1401829506',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:39:40 +0000 2020',
#   'id': 1319030619662356481,
#   'id_str': '1319030619662356481',
#   'text': '@DPosthu @WiringTheBrain Nope. GWASs will never yield anything useful. Best to abandon them and move to looking at… https://t.co/9KhAt4m6g0',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'DPosthu',
#      'name': 'Danielle',
#      'id': 3298214777,
#      'id_str': '3298214777',
#      'indices': [0, 8]},
#     {'screen_name': 'WiringTheBrain',
#      'name': 'Kevin Mitchell',
#      'id': 325719227,
#      'id_str': '325719227',
#      'indices': [9, 24]}],
#    'urls': [{'url': 'https://t.co/9KhAt4m6g0',
#      'expanded_url': 'https://twitter.com/i/web/status/1319030619662356481',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [116, 139]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': 1319029186078658561,
#   'in_reply_to_status_id_str': '1319029186078658561',
#   'in_reply_to_user_id': 3298214777,
#   'in_reply_to_user_id_str': '3298214777',
#   'in_reply_to_screen_name': 'DPosthu',
#   'user': {'id': 159394307,
#    'id_str': '159394307',
#    'name': 'Dave Curtis',
#    'screen_name': 'davecurtis314',
#    'location': 'London',
#    'description': 'Retired psychiatrist doing genetics research. Check the link for details.',
#    'url': 'https://t.co/2IDlOeaWlJ',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/2IDlOeaWlJ',
#        'expanded_url': 'http://www.davecurtis.net/dcurtis.html',
#        'display_url': 'davecurtis.net/dcurtis.html',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 4236,
#    'friends_count': 501,
#    'listed_count': 53,
#    'created_at': 'Fri Jun 25 07:23:40 +0000 2010',
#    'favourites_count': 59723,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 22888,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '1A1B1F',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1087072512910024705/JReebbZ-_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1087072512910024705/JReebbZ-_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/159394307/1400521403',
#    'profile_link_color': '2FC2EF',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '252429',
#    'profile_text_color': '666666',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:39:36 +0000 2020',
#   'id': 1319030600863547393,
#   'id_str': '1319030600863547393',
#   'text': 'RT @AmyJacobson: The REAL problem in DuPage County is NOT restaurants and bars but nursing homes and long term care facilities.\n\n@GovPritzk…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'AmyJacobson',
#      'name': 'Amy Jacobson',
#      'id': 17172311,
#      'id_str': '17172311',
#      'indices': [3, 15]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 246039023,
#    'id_str': '246039023',
#    'name': 'Mama Ford',
#    'screen_name': 'Cake0824',
#    'location': '',
#    'description': 'Proud mama... is there anything else worth living for!? ❤️🏈🎀',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 97,
#    'friends_count': 321,
#    'listed_count': 0,
#    'created_at': 'Wed Feb 02 00:28:46 +0000 2011',
#    'favourites_count': 2917,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 1556,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '0E0F0F',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1306937734477602817/iLzaOv1-_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1306937734477602817/iLzaOv1-_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/246039023/1570643476',
#    'profile_link_color': 'D11FAD',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Tue Oct 20 20:13:31 +0000 2020',
#    'id': 1318646548964802562,
#    'id_str': '1318646548964802562',
#    'text': 'The REAL problem in DuPage County is NOT restaurants and bars but nursing homes and long term care facilities.… https://t.co/75DRAEd8Yq',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/75DRAEd8Yq',
#       'expanded_url': 'https://twitter.com/i/web/status/1318646548964802562',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [112, 135]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 17172311,
#     'id_str': '17172311',
#     'name': 'Amy Jacobson',
#     'screen_name': 'AmyJacobson',
#     'location': 'Chicago',
#     'description': "Chicago's Morning Answer AM 560 WIND, Emmy Award winning journalist. CPS COACH, Proud mom of 2 Puerto Rican boys! Phi Beta Kappas U of Iowa, MT PROSPECT",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 21727,
#     'friends_count': 4366,
#     'listed_count': 179,
#     'created_at': 'Tue Nov 04 23:11:04 +0000 2008',
#     'favourites_count': 2726,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 5738,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'BADFCD',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme12/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme12/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/766785824/amy_j_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/766785824/amy_j_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/17172311/1555526371',
#     'profile_link_color': 'FF000D',
#     'profile_sidebar_border_color': 'F2E195',
#     'profile_sidebar_fill_color': 'FFF7CC',
#     'profile_text_color': '0C3E53',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 1318542910896431105,
#    'quoted_status_id_str': '1318542910896431105',
#    'quoted_status': {'created_at': 'Tue Oct 20 13:21:41 +0000 2020',
#     'id': 1318542910896431105,
#     'id_str': '1318542910896431105',
#     'text': 'Look at this list! \nRecent DuPage Co COVID outbreaks. \n\nSchools not on the list! \n\nThen why are Health Officials de… https://t.co/Lqt8wWgtix',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/Lqt8wWgtix',
#        'expanded_url': 'https://twitter.com/i/web/status/1318542910896431105',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 17172311,
#      'id_str': '17172311',
#      'name': 'Amy Jacobson',
#      'screen_name': 'AmyJacobson',
#      'location': 'Chicago',
#      'description': "Chicago's Morning Answer AM 560 WIND, Emmy Award winning journalist. CPS COACH, Proud mom of 2 Puerto Rican boys! Phi Beta Kappas U of Iowa, MT PROSPECT",
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 21727,
#      'friends_count': 4366,
#      'listed_count': 179,
#      'created_at': 'Tue Nov 04 23:11:04 +0000 2008',
#      'favourites_count': 2726,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 5738,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'BADFCD',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme12/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme12/bg.gif',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/766785824/amy_j_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/766785824/amy_j_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/17172311/1555526371',
#      'profile_link_color': 'FF000D',
#      'profile_sidebar_border_color': 'F2E195',
#      'profile_sidebar_fill_color': 'FFF7CC',
#      'profile_text_color': '0C3E53',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 115,
#     'favorite_count': 394,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'retweet_count': 116,
#    'favorite_count': 311,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': True,
#   'quoted_status_id': 1318542910896431105,
#   'quoted_status_id_str': '1318542910896431105',
#   'retweet_count': 116,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:39:33 +0000 2020',
#   'id': 1319030589606010880,
#   'id_str': '1319030589606010880',
#   'text': 'RT @GuerfiImen: Thanks IBM  for these courses.\n#Python #AI #ML #CV #NLP #Visual_Recognition #Deep_Learning #Chatbot #Integration #IBM_Watso…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'Python', 'indices': [47, 54]},
#     {'text': 'AI', 'indices': [55, 58]},
#     {'text': 'ML', 'indices': [59, 62]},
#     {'text': 'CV', 'indices': [63, 66]},
#     {'text': 'NLP', 'indices': [67, 71]},
#     {'text': 'Visual_Recognition', 'indices': [72, 91]},
#     {'text': 'Deep_Learning', 'indices': [92, 106]},
#     {'text': 'Chatbot', 'indices': [107, 115]},
#     {'text': 'Integration', 'indices': [116, 128]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'GuerfiImen',
#      'name': 'Guerfi Imen',
#      'id': 1248234168020017152,
#      'id_str': '1248234168020017152',
#      'indices': [3, 14]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://github.com/lina2497" rel="nofollow">Python Data Science Tweets</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1288754505211883521,
#    'id_str': '1288754505211883521',
#    'name': 'Python for Data Science',
#    'screen_name': 'py_data_sci',
#    'location': '',
#    'description': 'Interested in using #Python for #DataScience. A bot maintained by \n@AlexBetts. Retweets are not endorsements. For #rstats, check out my other bot @rstats4ds.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 800,
#    'friends_count': 2,
#    'listed_count': 5,
#    'created_at': 'Thu Jul 30 08:33:21 +0000 2020',
#    'favourites_count': 18655,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 18650,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1288765343339614208/JNqvhKEe_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1288765343339614208/JNqvhKEe_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1288754505211883521/1596100587',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Oct 21 21:26:58 +0000 2020',
#    'id': 1319027421333590016,
#    'id_str': '1319027421333590016',
#    'text': 'Thanks IBM  for these courses.\n#Python #AI #ML #CV #NLP #Visual_Recognition #Deep_Learning #Chatbot #Integration… https://t.co/kiOBMCba1c',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'Python', 'indices': [31, 38]},
#      {'text': 'AI', 'indices': [39, 42]},
#      {'text': 'ML', 'indices': [43, 46]},
#      {'text': 'CV', 'indices': [47, 50]},
#      {'text': 'NLP', 'indices': [51, 55]},
#      {'text': 'Visual_Recognition', 'indices': [56, 75]},
#      {'text': 'Deep_Learning', 'indices': [76, 90]},
#      {'text': 'Chatbot', 'indices': [91, 99]},
#      {'text': 'Integration', 'indices': [100, 112]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/kiOBMCba1c',
#       'expanded_url': 'https://twitter.com/i/web/status/1319027421333590016',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [114, 137]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1248234168020017152,
#     'id_str': '1248234168020017152',
#     'name': 'Guerfi Imen',
#     'screen_name': 'GuerfiImen',
#     'location': '',
#     'description': 'Ingénieur GÉNIE DES SYSTÈMES ELECTRONIQUES ET COMMUNICATION Spécialité systèmes Electroniques Intelligents',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 14,
#     'friends_count': 227,
#     'listed_count': 0,
#     'created_at': 'Thu Apr 09 13:00:32 +0000 2020',
#     'favourites_count': 40,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 71,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1294255167110619138/urvo-Dhp_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1294255167110619138/urvo-Dhp_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1248234168020017152/1586437749',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 1,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:39:30 +0000 2020',
#   'id': 1319030578201542657,
#   'id_str': '1319030578201542657',
#   'text': 'Éloignement physique : Comment ralentir la propagation de la COVID-19\nhttps://t.co/VeaMJZ7sMH\n(… https://t.co/bq7LkfooqK',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/VeaMJZ7sMH',
#      'expanded_url': 'https://canada.ca/fr/sante-publique/services/publications/maladies-affections/distanciation-sociale.html',
#      'display_url': 'canada.ca/fr/sante-publi…',
#      'indices': [70, 93]},
#     {'url': 'https://t.co/bq7LkfooqK',
#      'expanded_url': 'https://twitter.com/i/web/status/1319030578201542657',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [97, 120]}]},
#   'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 899369342562746369,
#    'id_str': '899369342562746369',
#    'name': 'Charleux',
#    'screen_name': 'Paris________41',
#    'location': 'Japon',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 47,
#    'friends_count': 1077,
#    'listed_count': 0,
#    'created_at': 'Sun Aug 20 20:35:35 +0000 2017',
#    'favourites_count': 1467,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 5280,
# ...
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#    'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': True,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:38:44 +0000 2020',
#   'id': 1319030381635465217,
#   'id_str': '1319030381635465217',
#   'text': 'Wednesday, October 21, 2020, 02:28:24 PM Pacific \nDemocratic ticket has an 84%\n  chance of winning #Elections202 \nE… https://t.co/msL86TikCV',
#   'truncated': True,
#   'entities': {'hashtags': [{'text': 'Elections202', 'indices': [99, 112]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/msL86TikCV',
#      'expanded_url': 'https://twitter.com/i/web/status/1319030381635465217',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 3274053018,
#    'id_str': '3274053018',
#    'name': 'Thomas Miller',
#    'screen_name': 'virtualtout',
#    'location': '',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 895,
#    'friends_count': 22,
#    'listed_count': 5,
#    'created_at': 'Fri Jul 10 09:57:36 +0000 2015',
#    'favourites_count': 1,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 626,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1310639594145079296/lZZ53IBt_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1310639594145079296/lZZ53IBt_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3274053018/1601324233',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:38:29 +0000 2020',
#   'id': 1319030319010426882,
#   'id_str': '1319030319010426882',
#   'text': 'New Swarthmore Computer Science course for Spring 2021! CS58: Advanced Data Structures. In this class, students wil… https://t.co/Af3KiAJEuF',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/Af3KiAJEuF',
#      'expanded_url': 'https://twitter.com/i/web/status/1319030319010426882',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://cheapbotsdonequick.com" rel="nofollow">Cheap Bots, Done Quick!</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1243662647901462529,
#    'id_str': '1243662647901462529',
#    'name': 'cs_swat',
#    'screen_name': 'cs_swat',
#    'location': '',
#    'description': 'Follow this page for announcements about new Computer Science courses at Swarthmore College!',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 15,
#    'friends_count': 1,
#    'listed_count': 1,
#    'created_at': 'Fri Mar 27 22:14:39 +0000 2020',
#    'favourites_count': 0,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 1472,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1243663410946064385/XzA_u8qV_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1243663410946064385/XzA_u8qV_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1243662647901462529/1585521553',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:38:10 +0000 2020',
#   'id': 1319030238978912256,
#   'id_str': '1319030238978912256',
#   'text': '@GaryAlessio @deb_cohen We have real time data from Spain which has mandated masks inside and out. Their cases have… https://t.co/7wbHly9rMc',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'GaryAlessio',
#      'name': 'Gary Alessio',
#      'id': 63270071,
#      'id_str': '63270071',
#      'indices': [0, 12]},
#     {'screen_name': 'deb_cohen',
#      'name': 'Deborah Cohen',
#      'id': 227382347,
#      'id_str': '227382347',
#      'indices': [13, 23]}],
#    'urls': [{'url': 'https://t.co/7wbHly9rMc',
#      'expanded_url': 'https://twitter.com/i/web/status/1319030238978912256',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': 1319015419823480833,
#   'in_reply_to_status_id_str': '1319015419823480833',
#   'in_reply_to_user_id': 63270071,
#   'in_reply_to_user_id_str': '63270071',
#   'in_reply_to_screen_name': 'GaryAlessio',
#   'user': {'id': 951998058,
#    'id_str': '951998058',
#    'name': 'Louise',
#    'screen_name': 'Louise_katz',
#    'location': '',
#    'description': 'Loves animals and nature. No support for MSM misinformation or left wing nonsense. 🇬🇧 ✡️',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 4745,
#    'friends_count': 4842,
#    'listed_count': 23,
#    'created_at': 'Fri Nov 16 16:41:18 +0000 2012',
#    'favourites_count': 138581,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 62270,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1288477628857548801/0ewditpQ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1288477628857548801/0ewditpQ_normal.jpg',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:37:54 +0000 2020',
#   'id': 1319030173715566592,
#   'id_str': '1319030173715566592',
#   'text': 'RT @penny1_lucky: @mabelyang @ColleenHuberNMD @ResearchGate ResearchGate needs to provide conclusive data that shows masks are effective ag…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'penny1_lucky',
#      'name': 'LuckyPenny1',
#      'id': 1298694658344849408,
#      'id_str': '1298694658344849408',
#      'indices': [3, 16]},
#     {'screen_name': 'mabelyang',
#      'name': 'Mabel R.',
#      'id': 78291079,
#      'id_str': '78291079',
#      'indices': [18, 28]},
#     {'screen_name': 'ColleenHuberNMD',
#      'name': 'Colleen Huber, NMD',
#      'id': 819296296062201857,
#      'id_str': '819296296062201857',
#      'indices': [29, 45]},
#     {'screen_name': 'ResearchGate',
#      'name': 'ResearchGate',
#      'id': 18237848,
#      'id_str': '18237848',
#      'indices': [46, 59]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 584576439,
#    'id_str': '584576439',
#    'name': 'Ann Marcos',
#    'screen_name': 'annmarcos1',
#    'location': 'Ireland',
#    'description': '“There is nothing noble in being superior to your fellow man; true nobility is being superior to your former self.” Support all due to unnecessary adversity.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1545,
#    'friends_count': 830,
#    'listed_count': 1,
#    'created_at': 'Sat May 19 06:22:36 +0000 2012',
#    'favourites_count': 152439,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 117213,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1190726141746827264/UQ_HVhIE_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1190726141746827264/UQ_HVhIE_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/584576439/1566569226',
#    'profile_link_color': 'ABB8C2',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Oct 21 19:02:16 +0000 2020',
#    'id': 1318991006025486336,
#    'id_str': '1318991006025486336',
#    'text': '@mabelyang @ColleenHuberNMD @ResearchGate ResearchGate needs to provide conclusive data that shows masks are effect… https://t.co/KvSTVHkOeg',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'mabelyang',
#       'name': 'Mabel R.',
#       'id': 78291079,
#       'id_str': '78291079',
#       'indices': [0, 10]},
#      {'screen_name': 'ColleenHuberNMD',
#       'name': 'Colleen Huber, NMD',
#       'id': 819296296062201857,
#       'id_str': '819296296062201857',
#       'indices': [11, 27]},
#      {'screen_name': 'ResearchGate',
#       'name': 'ResearchGate',
#       'id': 18237848,
#       'id_str': '18237848',
#       'indices': [28, 41]}],
#     'urls': [{'url': 'https://t.co/KvSTVHkOeg',
#       'expanded_url': 'https://twitter.com/i/web/status/1318991006025486336',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': 1318969597920481281,
#    'in_reply_to_status_id_str': '1318969597920481281',
#    'in_reply_to_user_id': 78291079,
#    'in_reply_to_user_id_str': '78291079',
#    'in_reply_to_screen_name': 'mabelyang',
#    'user': {'id': 1298694658344849408,
#     'id_str': '1298694658344849408',
#     'name': 'LuckyPenny1',
#     'screen_name': 'penny1_lucky',
#     'location': '',
#     'description': 'truth seeker / former reporter',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 14,
#     'friends_count': 57,
#     'listed_count': 1,
#     'created_at': 'Wed Aug 26 18:51:56 +0000 2020',
#     'favourites_count': 2246,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 251,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1298799359467966464/Olbv72VV_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1298799359467966464/Olbv72VV_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 3,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 1,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'}]

# %% [markdown]
# For good measure, try doing a search for tweets relating to `#MeToo` as well.

# %%
# your answer here
query_string = '?q=%23MeToo'

req = requests.get(base_url + query_string, auth=tokens).json()

# %%
# and here are our returned tweets
req['statuses']
# Out:
# [{'created_at': 'Wed Oct 21 21:41:12 +0000 2020',
#   'id': 1319031005261385728,
#   'id_str': '1319031005261385728',
#   'text': "RT @4aPeoplesParty: BREAKING: @rosemcgowan and @ProudSocialist to deliver the People's Party Debate Response with Nick Brana tomorrow.\n\nMcG…",
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': '4aPeoplesParty',
#      'name': 'Movement for a People’s Party',
#      'id': 811414973985550336,
#      'id_str': '811414973985550336',
#      'indices': [3, 18]},
#     {'screen_name': 'rosemcgowan',
#      'name': 'Rose McGowan',
#      'id': 46233559,
#      'id_str': '46233559',
#      'indices': [30, 42]},
#     {'screen_name': 'ProudSocialist',
#      'name': 'Ryan Knight 🌹',
#      'id': 755057897583804416,
#      'id_str': '755057897583804416',
#      'indices': [47, 62]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1213553296369016832,
#    'id_str': '1213553296369016832',
#    'name': 'dan the sometimes man',
#    'screen_name': 'EChronicals',
#    'location': 'Seattle',
#    'description': 'BLM -- Go Green Party in 2020! -- findom paypig cashcow',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 135,
#    'friends_count': 269,
#    'listed_count': 1,
#    'created_at': 'Sat Jan 04 20:10:38 +0000 2020',
#    'favourites_count': 1318,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 2411,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1213555882480390144/WXZmV1hW_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1213555882480390144/WXZmV1hW_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Oct 21 19:57:42 +0000 2020',
#    'id': 1319004958075781123,
#    'id_str': '1319004958075781123',
#    'text': "BREAKING: @rosemcgowan and @ProudSocialist to deliver the People's Party Debate Response with Nick Brana tomorrow.… https://t.co/HM8miKZA7C",
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'rosemcgowan',
#       'name': 'Rose McGowan',
#       'id': 46233559,
#       'id_str': '46233559',
#       'indices': [10, 22]},
#      {'screen_name': 'ProudSocialist',
#       'name': 'Ryan Knight 🌹',
#       'id': 755057897583804416,
#       'id_str': '755057897583804416',
#       'indices': [27, 42]}],
#     'urls': [{'url': 'https://t.co/HM8miKZA7C',
#       'expanded_url': 'https://twitter.com/i/web/status/1319004958075781123',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 811414973985550336,
#     'id_str': '811414973985550336',
#     'name': 'Movement for a People’s Party',
#     'screen_name': '4aPeoplesParty',
#     'location': 'United States',
#     'description': "We're building a major new progressive populist party in America. Because Wall Street has two major parties and working people have none. Join us! #PeoplesParty",
#     'url': 'https://t.co/SM1h4ANr8r',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/SM1h4ANr8r',
#         'expanded_url': 'https://peoplesparty.org/',
#         'display_url': 'peoplesparty.org',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 76763,
#     'friends_count': 22361,
#     'listed_count': 372,
#     'created_at': 'Wed Dec 21 03:36:19 +0000 2016',
#     'favourites_count': 43277,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 41403,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1256916348568993792/NKngGvRl_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1256916348568993792/NKngGvRl_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/811414973985550336/1602698386',
#     'profile_link_color': 'E56717',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 155,
#    'favorite_count': 460,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 155,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:40:52 +0000 2020',
#   'id': 1319030920297459713,
#   'id_str': '1319030920297459713',
#   'text': "@alexthechick I'm old enough to remember the #metoo movement where this kind of behavior was bad",
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'metoo', 'indices': [45, 51]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'alexthechick',
#      'name': 'alexandriabrown',
#      'id': 15753954,
#      'id_str': '15753954',
#      'indices': [0, 13]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': 1319027422306717707,
#   'in_reply_to_status_id_str': '1319027422306717707',
#   'in_reply_to_user_id': 15753954,
#   'in_reply_to_user_id_str': '15753954',
#   'in_reply_to_screen_name': 'alexthechick',
#   'user': {'id': 1217027438229762052,
#    'id_str': '1217027438229762052',
#    'name': 'NiedermeyersDeadHorse aka NDH',
#    'screen_name': 'NiedsG',
#    'location': '',
#    'description': '"Nobody ever wanted power who didn\'t want to use it" - Shit some realtor said\n\nParler, same as twitter: @Niedsg',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 655,
#    'friends_count': 996,
#    'listed_count': 5,
#    'created_at': 'Tue Jan 14 10:16:12 +0000 2020',
#    'favourites_count': 5400,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 47314,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1235403671963303937/XV67v1nF_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1235403671963303937/XV67v1nF_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1217027438229762052/1591125526',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:40:36 +0000 2020',
#   'id': 1319030854207811592,
#   'id_str': '1319030854207811592',
#   'text': "RT @4aPeoplesParty: BREAKING: @rosemcgowan and @ProudSocialist to deliver the People's Party Debate Response with Nick Brana tomorrow.\n\nMcG…",
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': '4aPeoplesParty',
#      'name': 'Movement for a People’s Party',
#      'id': 811414973985550336,
#      'id_str': '811414973985550336',
#      'indices': [3, 18]},
#     {'screen_name': 'rosemcgowan',
#      'name': 'Rose McGowan',
#      'id': 46233559,
#      'id_str': '46233559',
#      'indices': [30, 42]},
#     {'screen_name': 'ProudSocialist',
#      'name': 'Ryan Knight 🌹',
#      'id': 755057897583804416,
#      'id_str': '755057897583804416',
#      'indices': [47, 62]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 833509228136505344,
#    'id_str': '833509228136505344',
#    'name': "What's hard about this? #BlackLivesMatter",
#    'screen_name': 'Repugnantclowns',
#    'location': 'Live From Planet Earth, USA',
#    'description': 'Politically cynical but a progressive. #RaiderNation member since 1974. Sane Humanist. Lover and loved. Scientist, cook, coach, chemist, philosopher, audiophile',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 926,
#    'friends_count': 1282,
#    'listed_count': 3,
#    'created_at': 'Mon Feb 20 02:51:00 +0000 2017',
#    'favourites_count': 126473,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 28284,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1250435683019186177/LUSRrPxO_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1250435683019186177/LUSRrPxO_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Oct 21 19:57:42 +0000 2020',
#    'id': 1319004958075781123,
#    'id_str': '1319004958075781123',
#    'text': "BREAKING: @rosemcgowan and @ProudSocialist to deliver the People's Party Debate Response with Nick Brana tomorrow.… https://t.co/HM8miKZA7C",
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'rosemcgowan',
#       'name': 'Rose McGowan',
#       'id': 46233559,
#       'id_str': '46233559',
#       'indices': [10, 22]},
#      {'screen_name': 'ProudSocialist',
#       'name': 'Ryan Knight 🌹',
#       'id': 755057897583804416,
#       'id_str': '755057897583804416',
#       'indices': [27, 42]}],
#     'urls': [{'url': 'https://t.co/HM8miKZA7C',
#       'expanded_url': 'https://twitter.com/i/web/status/1319004958075781123',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 811414973985550336,
#     'id_str': '811414973985550336',
#     'name': 'Movement for a People’s Party',
#     'screen_name': '4aPeoplesParty',
#     'location': 'United States',
#     'description': "We're building a major new progressive populist party in America. Because Wall Street has two major parties and working people have none. Join us! #PeoplesParty",
#     'url': 'https://t.co/SM1h4ANr8r',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/SM1h4ANr8r',
#         'expanded_url': 'https://peoplesparty.org/',
#         'display_url': 'peoplesparty.org',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 76763,
#     'friends_count': 22361,
#     'listed_count': 372,
#     'created_at': 'Wed Dec 21 03:36:19 +0000 2016',
#     'favourites_count': 43277,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 41403,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1256916348568993792/NKngGvRl_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1256916348568993792/NKngGvRl_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/811414973985550336/1602698386',
#     'profile_link_color': 'E56717',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 155,
#    'favorite_count': 462,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 155,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:40:20 +0000 2020',
#   'id': 1319030787652620288,
#   'id_str': '1319030787652620288',
#   'text': 'RT @Zigmanfreud: When will HBO and Oprah apologize to Michael Jackson , his family, and fans?! \n\nOh, and #MeToo ...',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'MeToo', 'indices': [105, 111]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'Zigmanfreud',
#      'name': 'John Ziegler',
#      'id': 558360059,
#      'id_str': '558360059',
#      'indices': [3, 15]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 49437485,
#    'id_str': '49437485',
#    'name': 'Jennifer Jackson',
#    'screen_name': 'iamjenjaxn',
#    'location': 'Neverland',
#    'description': 'All is possible, even the impossible. -Mary Poppins',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 3092,
#    'friends_count': 1713,
#    'listed_count': 144,
#    'created_at': 'Sun Jun 21 21:40:24 +0000 2009',
#    'favourites_count': 11066,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 54232,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '08090A',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1311494391022989314/qUpiPELE_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1311494391022989314/qUpiPELE_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/49437485/1569274053',
#    'profile_link_color': 'F5ABB5',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': 'C9080B',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Oct 21 16:35:27 +0000 2020',
#    'id': 1318954060435738626,
#    'id_str': '1318954060435738626',
#    'text': 'When will HBO and Oprah apologize to Michael Jackson , his family, and fans?! \n\nOh, and #MeToo ... https://t.co/yKg2iSxOpb',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'MeToo', 'indices': [88, 94]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/yKg2iSxOpb',
#       'expanded_url': 'https://twitter.com/tmz/status/1318932691471921156',
#       'display_url': 'twitter.com/tmz/status/131…',
#       'indices': [99, 122]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 558360059,
#     'id_str': '558360059',
#     'name': 'John Ziegler',
#     'screen_name': 'Zigmanfreud',
#     'location': 'Los Angeles',
#     'description': '@Mediaite Senior Columnist, Talk Show Host (2-time Talkers Magazine Top 100), Filmmaker, Emmy-Winner, Conservative/Libertarian, Georgetown Hoya, Husband/Father.',
#     'url': 'https://t.co/SvEihMTVQW',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/SvEihMTVQW',
#         'expanded_url': 'http://www.FreeSpeechBroadcasting.com',
#         'display_url': 'FreeSpeechBroadcasting.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 44849,
#     'friends_count': 20655,
#     'listed_count': 601,
#     'created_at': 'Fri Apr 20 05:55:22 +0000 2012',
#     'favourites_count': 288730,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 171486,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/724814157414076416/3aZNTIc2_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/724814157414076416/3aZNTIc2_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/558360059/1549583220',
#     'profile_link_color': '0051B3',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 1318932691471921156,
#    'quoted_status_id_str': '1318932691471921156',
#    'quoted_status': {'created_at': 'Wed Oct 21 15:10:32 +0000 2020',
#     'id': 1318932691471921156,
#     'id_str': '1318932691471921156',
#     'text': 'Michael Jackson Accuser James Safechuck Loses Revived Abuse Lawsuit https://t.co/joWYtWLCMl',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/joWYtWLCMl',
#        'expanded_url': 'http://dlvr.it/Rk3MZ7',
#        'display_url': 'dlvr.it/Rk3MZ7',
#        'indices': [68, 91]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://dlvrit.com/" rel="nofollow">dlvr.it</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 16331010,
#      'id_str': '16331010',
#      'name': 'TMZ',
#      'screen_name': 'TMZ',
#      'location': 'Los Angeles, CA',
#      'description': 'TMZ has consistently been credited for breaking the biggest stories dominating the entertainment news landscape and changing the way the public gets their news.',
#      'url': 'https://t.co/WFmNNP7hvg',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/WFmNNP7hvg',
#          'expanded_url': 'http://www.TMZ.com',
#          'display_url': 'TMZ.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 5552403,
#      'friends_count': 909,
#      'listed_count': 19993,
#      'created_at': 'Wed Sep 17 15:50:22 +0000 2008',
#      'favourites_count': 1280,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': True,
#      'statuses_count': 316968,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': True,
#      'profile_background_color': '1A1B1F',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/948698715220410368/EkNILtvi_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/948698715220410368/EkNILtvi_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16331010/1571072693',
#      'profile_link_color': 'FF1A1A',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 590,
#     'favorite_count': 2161,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'retweet_count': 193,
#    'favorite_count': 508,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': True,
#   'quoted_status_id': 1318932691471921156,
#   'quoted_status_id_str': '1318932691471921156',
#   'retweet_count': 193,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:40:20 +0000 2020',
#   'id': 1319030784246878211,
#   'id_str': '1319030784246878211',
#   'text': '@shuntingyard @mcschindler @sufranke #MeToo',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'MeToo', 'indices': [37, 43]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'shuntingyard',
#      'name': 'Twythmare 🐍',
#      'id': 116877549,
#      'id_str': '116877549',
#      'indices': [0, 13]},
#     {'screen_name': 'mcschindler',
#      'name': 'Marie-Chr. Schindler',
#      'id': 36645888,
#      'id_str': '36645888',
#      'indices': [14, 26]},
#     {'screen_name': 'sufranke',
#      'name': 'Su Franke',
#      'id': 19705250,
#      'id_str': '19705250',
#      'indices': [27, 36]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': 1319030084276203524,
#   'in_reply_to_status_id_str': '1319030084276203524',
#   'in_reply_to_user_id': 116877549,
#   'in_reply_to_user_id_str': '116877549',
#   'in_reply_to_screen_name': 'shuntingyard',
#   'user': {'id': 864847477756878849,
#    'id_str': '864847477756878849',
#    'name': 'TweetsFromThrone',
#    'screen_name': 'gehtsnoch_gut',
#    'location': 'Near Winterfell',
#    'description': 'English: Politics and more. Tenacious believer that we can do better. Deutsch: Politik und mehr. Hartnäckig glaubend, dass wir es besser machen können.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 120,
#    'friends_count': 239,
#    'listed_count': 0,
#    'created_at': 'Wed May 17 14:18:01 +0000 2017',
#    'favourites_count': 4522,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 5873,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1054845186101121024/fAc_8kJ4_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1054845186101121024/fAc_8kJ4_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/864847477756878849/1540329665',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'und'},
#  {'created_at': 'Wed Oct 21 21:40:19 +0000 2020',
#   'id': 1319030780182581258,
#   'id_str': '1319030780182581258',
#   'text': 'Why are they trying to normalize this???? This is disgusting. Where is the #MeToo movement? https://t.co/7U7LkC4ZUM',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'MeToo', 'indices': [75, 81]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/7U7LkC4ZUM',
#      'expanded_url': 'https://twitter.com/JoeConchaTV/status/1318970831691784193',
#      'display_url': 'twitter.com/JoeConchaTV/st…',
#      'indices': [92, 115]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 4010248637,
#    'id_str': '4010248637',
#    'name': 'Melissa',
#    'screen_name': 'toastmastermel2',
#    'location': 'United States',
#    'description': 'You are so worthy of a beautiful life. Love is an act of the will.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 138,
#    'friends_count': 880,
#    'listed_count': 2,
#    'created_at': 'Wed Oct 21 15:11:13 +0000 2015',
#    'favourites_count': 32291,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 10089,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme10/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme10/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1031340881578799104/mVSwimzN_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1031340881578799104/mVSwimzN_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4010248637/1556229174',
#    'profile_link_color': '981CEB',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': True,
#   'quoted_status_id': 1318970831691784193,
#   'quoted_status_id_str': '1318970831691784193',
#   'quoted_status': {'created_at': 'Wed Oct 21 17:42:06 +0000 2020',
#    'id': 1318970831691784193,
#    'id_str': '1318970831691784193',
#    'text': "No... it's really isn't about our unease on the topic. It was on a work Zoom call. With women present. It is stunni… https://t.co/YqTy41tIWN",
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/YqTy41tIWN',
#       'expanded_url': 'https://twitter.com/i/web/status/1318970831691784193',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 245441097,
#     'id_str': '245441097',
#     'name': 'Joe Concha',
#     'screen_name': 'JoeConchaTV',
#     'location': 'Jersey, baby',
#     'description': 'Media reporter, The Hill. Also provide analysis & opinions on TV. Husband of Jean. Dad of Cameron & Liam & Chase. RTs may or may not be endorsements.',
#     'url': 'https://t.co/XMLVmWKm8o',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/XMLVmWKm8o',
#         'expanded_url': 'http://thehill.com',
#         'display_url': 'thehill.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 103025,
#     'friends_count': 4208,
#     'listed_count': 757,
#     'created_at': 'Mon Jan 31 18:13:37 +0000 2011',
#     'favourites_count': 20098,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 52390,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/747792220447707136/cTeh4-k9_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/747792220447707136/cTeh4-k9_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/245441097/1358979748',
#     'profile_link_color': '1B95E0',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 1318929803702132738,
#    'quoted_status_id_str': '1318929803702132738',
#    'retweet_count': 358,
#    'favorite_count': 1248,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:40:05 +0000 2020',
#   'id': 1319030722628386816,
#   'id_str': '1319030722628386816',
#   'text': '69% percent of white male founders see a positive impact since #MeToo, compared to 35% of white women founders and… https://t.co/dE8j4A4Clh',
#   'truncated': True,
#   'entities': {'hashtags': [{'text': 'MeToo', 'indices': [63, 69]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/dE8j4A4Clh',
#      'expanded_url': 'https://twitter.com/i/web/status/1319030722628386816',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [116, 139]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://www.hootsuite.com" rel="nofollow">Hootsuite Inc.</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 3027220101,
#    'id_str': '3027220101',
#    'name': 'EqualPayDayChicago',
#    'screen_name': 'EqualPayDayChic',
#    'location': 'Chicago, IL',
#    'description': "Started in 2010, but we're not there yet.  \nSee you on October 29th, the last #EqualPayDay for 2020. #EPD2020",
#    'url': 'https://t.co/LP6Cf368t7',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/LP6Cf368t7',
#        'expanded_url': 'http://www.equalpaydaychi.xyz',
#        'display_url': 'equalpaydaychi.xyz',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 768,
#    'friends_count': 191,
#    'listed_count': 24,
#    'created_at': 'Mon Feb 09 21:58:02 +0000 2015',
#    'favourites_count': 1701,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 1879,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/650744777009270785/PfwXyDNZ_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/650744777009270785/PfwXyDNZ_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3027220101/1443984605',
#    'profile_link_color': 'FF0000',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:40:02 +0000 2020',
#   'id': 1319030710058045440,
#   'id_str': '1319030710058045440',
#   'text': 'Bitte Hinweise an https://t.co/5owI7mfQ4y schicken\n#MeToo\n#Koblenz https://t.co/2yjE6yDaQT',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'MeToo', 'indices': [51, 57]},
#     {'text': 'Koblenz', 'indices': [58, 66]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/5owI7mfQ4y',
#      'expanded_url': 'https://www.facebook.com/kinderseelenschuetzer',
#      'display_url': 'facebook.com/kinderseelensc…',
#      'indices': [18, 41]}],
#    'media': [{'id': 1319029976918884353,
#      'id_str': '1319029976918884353',
#      'indices': [67, 90],
#      'media_url': 'http://pbs.twimg.com/media/Ek4ixoZXgAEJLCX.png',
#      'media_url_https': 'https://pbs.twimg.com/media/Ek4ixoZXgAEJLCX.png',
#      'url': 'https://t.co/2yjE6yDaQT',
#      'display_url': 'pic.twitter.com/2yjE6yDaQT',
#      'expanded_url': 'https://twitter.com/Mogreen92/status/1319030710058045440/photo/1',
#      'type': 'photo',
#      'sizes': {'large': {'w': 565, 'h': 800, 'resize': 'fit'},
#       'medium': {'w': 565, 'h': 800, 'resize': 'fit'},
#       'small': {'w': 480, 'h': 680, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}}}]},
#   'extended_entities': {'media': [{'id': 1319029976918884353,
#      'id_str': '1319029976918884353',
#      'indices': [67, 90],
#      'media_url': 'http://pbs.twimg.com/media/Ek4ixoZXgAEJLCX.png',
#      'media_url_https': 'https://pbs.twimg.com/media/Ek4ixoZXgAEJLCX.png',
#      'url': 'https://t.co/2yjE6yDaQT',
#      'display_url': 'pic.twitter.com/2yjE6yDaQT',
#      'expanded_url': 'https://twitter.com/Mogreen92/status/1319030710058045440/photo/1',
#      'type': 'photo',
#      'sizes': {'large': {'w': 565, 'h': 800, 'resize': 'fit'},
#       'medium': {'w': 565, 'h': 800, 'resize': 'fit'},
#       'small': {'w': 480, 'h': 680, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}}}]},
#   'metadata': {'iso_language_code': 'de', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1318984661624913920,
#    'id_str': '1318984661624913920',
#    'name': 'Mogreen',
#    'screen_name': 'Mogreen92',
#    'location': '',
#    'description': 'ertrage keine Ungerechtigkeit',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 5,
#    'friends_count': 33,
#    'listed_count': 0,
#    'created_at': 'Wed Oct 21 18:37:08 +0000 2020',
#    'favourites_count': 12,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 55,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1318988868755066883/pb5I-PSn_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1318988868755066883/pb5I-PSn_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1318984661624913920/1603306781',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'de'},
#  {'created_at': 'Wed Oct 21 21:39:54 +0000 2020',
#   'id': 1319030678713815044,
#   'id_str': '1319030678713815044',
#   'text': "RT @4aPeoplesParty: BREAKING: @rosemcgowan and @ProudSocialist to deliver the People's Party Debate Response with Nick Brana tomorrow.\n\nMcG…",
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': '4aPeoplesParty',
#      'name': 'Movement for a People’s Party',
#      'id': 811414973985550336,
#      'id_str': '811414973985550336',
#      'indices': [3, 18]},
#     {'screen_name': 'rosemcgowan',
#      'name': 'Rose McGowan',
#      'id': 46233559,
#      'id_str': '46233559',
#      'indices': [30, 42]},
#     {'screen_name': 'ProudSocialist',
#      'name': 'Ryan Knight 🌹',
#      'id': 755057897583804416,
#      'id_str': '755057897583804416',
#      'indices': [47, 62]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1249145268777308160,
#    'id_str': '1249145268777308160',
#    'name': 'Your Revolution LA',
#    'screen_name': 'YourRevLA',
#    'location': 'California',
#    'description': '#YRLA brings you interviews and news you can trust in English & Spanish every week! Hosts @Eynelys @ThePresidentRod @SkyHuete',
#    'url': 'https://t.co/XMHvWEuzQ2',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/XMHvWEuzQ2',
#        'expanded_url': 'https://linktr.ee/yrla',
#        'display_url': 'linktr.ee/yrla',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 84,
#    'friends_count': 179,
#    'listed_count': 0,
#    'created_at': 'Sun Apr 12 01:20:33 +0000 2020',
#    'favourites_count': 86,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 100,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1249145419868688384/fhxNXBqf_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1249145419868688384/fhxNXBqf_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1249145268777308160/1587076402',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Oct 21 19:57:42 +0000 2020',
#    'id': 1319004958075781123,
#    'id_str': '1319004958075781123',
#    'text': "BREAKING: @rosemcgowan and @ProudSocialist to deliver the People's Party Debate Response with Nick Brana tomorrow.… https://t.co/HM8miKZA7C",
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'rosemcgowan',
#       'name': 'Rose McGowan',
#       'id': 46233559,
#       'id_str': '46233559',
#       'indices': [10, 22]},
#      {'screen_name': 'ProudSocialist',
#       'name': 'Ryan Knight 🌹',
#       'id': 755057897583804416,
#       'id_str': '755057897583804416',
#       'indices': [27, 42]}],
#     'urls': [{'url': 'https://t.co/HM8miKZA7C',
#       'expanded_url': 'https://twitter.com/i/web/status/1319004958075781123',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 811414973985550336,
#     'id_str': '811414973985550336',
#     'name': 'Movement for a People’s Party',
#     'screen_name': '4aPeoplesParty',
#     'location': 'United States',
#     'description': "We're building a major new progressive populist party in America. Because Wall Street has two major parties and working people have none. Join us! #PeoplesParty",
#     'url': 'https://t.co/SM1h4ANr8r',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/SM1h4ANr8r',
#         'expanded_url': 'https://peoplesparty.org/',
#         'display_url': 'peoplesparty.org',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 76763,
#     'friends_count': 22361,
#     'listed_count': 372,
#     'created_at': 'Wed Dec 21 03:36:19 +0000 2016',
#     'favourites_count': 43277,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 41403,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1256916348568993792/NKngGvRl_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1256916348568993792/NKngGvRl_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/811414973985550336/1602698386',
#     'profile_link_color': 'E56717',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
# ...
#       'expanded_url': 'https://twitter.com/i/web/status/1319004958075781123',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 811414973985550336,
#     'id_str': '811414973985550336',
#     'name': 'Movement for a People’s Party',
#     'screen_name': '4aPeoplesParty',
#     'location': 'United States',
#     'description': "We're building a major new progressive populist party in America. Because Wall Street has two major parties and working people have none. Join us! #PeoplesParty",
#     'url': 'https://t.co/SM1h4ANr8r',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/SM1h4ANr8r',
#         'expanded_url': 'https://peoplesparty.org/',
#         'display_url': 'peoplesparty.org',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 76763,
#     'friends_count': 22361,
#     'listed_count': 372,
#     'created_at': 'Wed Dec 21 03:36:19 +0000 2016',
#     'favourites_count': 43277,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 41403,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1256916348568993792/NKngGvRl_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1256916348568993792/NKngGvRl_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/811414973985550336/1602698386',
#     'profile_link_color': 'E56717',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 155,
#    'favorite_count': 462,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 155,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:39:14 +0000 2020',
#   'id': 1319030509247320065,
#   'id_str': '1319030509247320065',
#   'text': "RT @4aPeoplesParty: BREAKING: @rosemcgowan and @ProudSocialist to deliver the People's Party Debate Response with Nick Brana tomorrow.\n\nMcG…",
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': '4aPeoplesParty',
#      'name': 'Movement for a People’s Party',
#      'id': 811414973985550336,
#      'id_str': '811414973985550336',
#      'indices': [3, 18]},
#     {'screen_name': 'rosemcgowan',
#      'name': 'Rose McGowan',
#      'id': 46233559,
#      'id_str': '46233559',
#      'indices': [30, 42]},
#     {'screen_name': 'ProudSocialist',
#      'name': 'Ryan Knight 🌹',
#      'id': 755057897583804416,
#      'id_str': '755057897583804416',
#      'indices': [47, 62]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 779862631347785739,
#    'id_str': '779862631347785739',
#    'name': 'Grant Scarboro #PeoplesParty',
#    'screen_name': 'AuraTerrorbird',
#    'location': 'Maryland, USA',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 90,
#    'friends_count': 641,
#    'listed_count': 2,
#    'created_at': 'Sun Sep 25 01:58:35 +0000 2016',
#    'favourites_count': 8514,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 23434,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/884901745360388100/hqyQ3qFZ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/884901745360388100/hqyQ3qFZ_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/779862631347785739/1577054345',
#    'profile_link_color': '19CF86',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Oct 21 19:57:42 +0000 2020',
#    'id': 1319004958075781123,
#    'id_str': '1319004958075781123',
#    'text': "BREAKING: @rosemcgowan and @ProudSocialist to deliver the People's Party Debate Response with Nick Brana tomorrow.… https://t.co/HM8miKZA7C",
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'rosemcgowan',
#       'name': 'Rose McGowan',
#       'id': 46233559,
#       'id_str': '46233559',
#       'indices': [10, 22]},
#      {'screen_name': 'ProudSocialist',
#       'name': 'Ryan Knight 🌹',
#       'id': 755057897583804416,
#       'id_str': '755057897583804416',
#       'indices': [27, 42]}],
#     'urls': [{'url': 'https://t.co/HM8miKZA7C',
#       'expanded_url': 'https://twitter.com/i/web/status/1319004958075781123',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 811414973985550336,
#     'id_str': '811414973985550336',
#     'name': 'Movement for a People’s Party',
#     'screen_name': '4aPeoplesParty',
#     'location': 'United States',
#     'description': "We're building a major new progressive populist party in America. Because Wall Street has two major parties and working people have none. Join us! #PeoplesParty",
#     'url': 'https://t.co/SM1h4ANr8r',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/SM1h4ANr8r',
#         'expanded_url': 'https://peoplesparty.org/',
#         'display_url': 'peoplesparty.org',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 76763,
#     'friends_count': 22361,
#     'listed_count': 372,
#     'created_at': 'Wed Dec 21 03:36:19 +0000 2016',
#     'favourites_count': 43277,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 41403,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1256916348568993792/NKngGvRl_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1256916348568993792/NKngGvRl_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/811414973985550336/1602698386',
#     'profile_link_color': 'E56717',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 155,
#    'favorite_count': 462,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 155,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:38:16 +0000 2020',
#   'id': 1319030266971697152,
#   'id_str': '1319030266971697152',
#   'text': "RT @4aPeoplesParty: BREAKING: @rosemcgowan and @ProudSocialist to deliver the People's Party Debate Response with Nick Brana tomorrow.\n\nMcG…",
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': '4aPeoplesParty',
#      'name': 'Movement for a People’s Party',
#      'id': 811414973985550336,
#      'id_str': '811414973985550336',
#      'indices': [3, 18]},
#     {'screen_name': 'rosemcgowan',
#      'name': 'Rose McGowan',
#      'id': 46233559,
#      'id_str': '46233559',
#      'indices': [30, 42]},
#     {'screen_name': 'ProudSocialist',
#      'name': 'Ryan Knight 🌹',
#      'id': 755057897583804416,
#      'id_str': '755057897583804416',
#      'indices': [47, 62]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 732792387852992516,
#    'id_str': '732792387852992516',
#    'name': 'Barbara Weiler',
#    'screen_name': 'BarbaraWeiler2',
#    'location': '',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 59,
#    'friends_count': 360,
#    'listed_count': 0,
#    'created_at': 'Wed May 18 04:38:14 +0000 2016',
#    'favourites_count': 29367,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 5608,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1168730696019521541/KnY3bXVB_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1168730696019521541/KnY3bXVB_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Oct 21 19:57:42 +0000 2020',
#    'id': 1319004958075781123,
#    'id_str': '1319004958075781123',
#    'text': "BREAKING: @rosemcgowan and @ProudSocialist to deliver the People's Party Debate Response with Nick Brana tomorrow.… https://t.co/HM8miKZA7C",
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'rosemcgowan',
#       'name': 'Rose McGowan',
#       'id': 46233559,
#       'id_str': '46233559',
#       'indices': [10, 22]},
#      {'screen_name': 'ProudSocialist',
#       'name': 'Ryan Knight 🌹',
#       'id': 755057897583804416,
#       'id_str': '755057897583804416',
#       'indices': [27, 42]}],
#     'urls': [{'url': 'https://t.co/HM8miKZA7C',
#       'expanded_url': 'https://twitter.com/i/web/status/1319004958075781123',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 811414973985550336,
#     'id_str': '811414973985550336',
#     'name': 'Movement for a People’s Party',
#     'screen_name': '4aPeoplesParty',
#     'location': 'United States',
#     'description': "We're building a major new progressive populist party in America. Because Wall Street has two major parties and working people have none. Join us! #PeoplesParty",
#     'url': 'https://t.co/SM1h4ANr8r',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/SM1h4ANr8r',
#         'expanded_url': 'https://peoplesparty.org/',
#         'display_url': 'peoplesparty.org',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 76763,
#     'friends_count': 22361,
#     'listed_count': 372,
#     'created_at': 'Wed Dec 21 03:36:19 +0000 2016',
#     'favourites_count': 43277,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 41403,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1256916348568993792/NKngGvRl_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1256916348568993792/NKngGvRl_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/811414973985550336/1602698386',
#     'profile_link_color': 'E56717',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 155,
#    'favorite_count': 462,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 155,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'}]

# %% [markdown]
# **Step 2:  Adding Parameters to Your Query String**

# %% [markdown]
# Query strings basically have two parts:
#
#  - What follows fhe `?` encodes the actual text to search for, using utf-8 encoding to account for special characters.  This is required.
#  - You can also add additional search parameters, which are encoded by `&`. They dictate what kinds of results are returned.
#   - For example, a parameter you can use in Twitter's search API is `count`, which tells you how many results to return.  The default is 15, but you can return up to 100.  So if we wanted to search for tweets and return 50 results our query string would look like the following:
#     `https://api.twitter.com/1.1/search/tweets.json?My%20Search%20String&count=50`
#   - You can add as many of these parameters to your string as you'd like.  So for example, if we wanted to include parameters for `count` and `result_type`, we could do the following: `https://api.twitter.com/1.1/search/tweets.json?My%20Search%20String&count=50&result_type=mixed`
#
# To get the hang of this, try searching for tweets that mention the hashtag `#DeepLearning`, and return 75 results.

# %%
# our search string
query_string = '?q=%23DeepLearning&count=75'
# initiate a request at this endpoint
results = requests.get(base_url+query_string, auth=tokens).json()

# %%
# and now we have our results!
results['statuses']
# Out:
# [{'created_at': 'Wed Oct 21 21:41:04 +0000 2020',
#   'id': 1319030970683711490,
#   'id_str': '1319030970683711490',
#   'text': '10 RNN Open Source Projects You Must Try Your Hands On #DeepLearning #learning via https://t.co/vBsHOsqluy https://t.co/91wvJn4g6c',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'DeepLearning', 'indices': [55, 68]},
#     {'text': 'learning', 'indices': [69, 78]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/vBsHOsqluy',
#      'expanded_url': 'http://twinybots.ch',
#      'display_url': 'twinybots.ch',
#      'indices': [83, 106]},
#     {'url': 'https://t.co/91wvJn4g6c',
#      'expanded_url': 'https://analyticsindiamag.com/10-rnn-open-source-projects-you-must-try-your-hands-on/',
#      'display_url': 'analyticsindiamag.com/10-rnn-open-so…',
#      'indices': [107, 130]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twinybots.com" rel="nofollow">TwinyBots</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1121091885802635266,
#    'id_str': '1121091885802635266',
#    'name': 'marlyk',
#    'screen_name': 'Roby41262525',
#    'location': 'Nairobi.',
#    'description': 'I am a dying breed. \nPH.D  data science C.E.O Techxnoss .#OwnYourData #DataOwner\n#AI',
#    'url': 'https://t.co/ZpAa2DfRQW',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/ZpAa2DfRQW',
#        'expanded_url': 'http://techxnoss.com',
#        'display_url': 'techxnoss.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 576,
#    'friends_count': 268,
#    'listed_count': 4,
#    'created_at': 'Wed Apr 24 16:41:49 +0000 2019',
#    'favourites_count': 6498,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 20583,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1270673783188271104/Oj4ojwef_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1270673783188271104/Oj4ojwef_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1121091885802635266/1590492558',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:41:00 +0000 2020',
#   'id': 1319030952845336577,
#   'id_str': '1319030952845336577',
#   'text': 'RT @RichardEudes: Why Do You Need Machine Learning? https://t.co/chuuGbXo9p #artificialintelligence, #bi, #bigdata, #dataengineering, #data…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'artificialintelligence',
#      'indices': [76, 99]},
#     {'text': 'bi', 'indices': [101, 104]},
#     {'text': 'bigdata', 'indices': [106, 114]},
#     {'text': 'dataengineering', 'indices': [116, 132]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'RichardEudes',
#      'name': 'Richard Eudes, PhD',
#      'id': 49427323,
#      'id_str': '49427323',
#      'indices': [3, 16]}],
#    'urls': [{'url': 'https://t.co/chuuGbXo9p',
#      'expanded_url': 'https://bit.ly/37G6Y83',
#      'display_url': 'bit.ly/37G6Y83',
#      'indices': [52, 75]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://twitter.com/datasciencebot_" rel="nofollow">TheDataScienceBot</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1276058041389953024,
#    'id_str': '1276058041389953024',
#    'name': 'The Data Science Bot',
#    'screen_name': 'datasciencebot_',
#    'location': '',
#    'description': "A bot created by @PatkarSumedh to retweet hashtags #DataScience & #DataVisualization\n\nLet's learn together!\n\nMisusing hashtags and spam will not be tolerated",
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1098,
#    'friends_count': 1,
#    'listed_count': 17,
#    'created_at': 'Thu Jun 25 07:42:09 +0000 2020',
#    'favourites_count': 21,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 129144,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1276064635456647168/omX9K1KU_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1276064635456647168/omX9K1KU_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1276058041389953024/1593080314',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Oct 21 20:30:22 +0000 2020',
#    'id': 1319013179272417286,
#    'id_str': '1319013179272417286',
#    'text': 'Why Do You Need Machine Learning? https://t.co/chuuGbXo9p #artificialintelligence, #bi, #bigdata, #dataengineering,… https://t.co/DRX2rQQYzJ',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'artificialintelligence',
#       'indices': [58, 81]},
#      {'text': 'bi', 'indices': [83, 86]},
#      {'text': 'bigdata', 'indices': [88, 96]},
#      {'text': 'dataengineering', 'indices': [98, 114]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/chuuGbXo9p',
#       'expanded_url': 'https://bit.ly/37G6Y83',
#       'display_url': 'bit.ly/37G6Y83',
#       'indices': [34, 57]},
#      {'url': 'https://t.co/DRX2rQQYzJ',
#       'expanded_url': 'https://twitter.com/i/web/status/1319013179272417286',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 49427323,
#     'id_str': '49427323',
#     'name': 'Richard Eudes, PhD',
#     'screen_name': 'RichardEudes',
#     'location': 'Paris, France',
#     'description': 'Chief Data Scientist - Head of #BigData & #AdvancedAnalytics -#Analytics #DataScience #MachineLearning #ArtificialIntelligence',
#     'url': 'https://t.co/SbKL2gaZoe',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/SbKL2gaZoe',
#         'expanded_url': 'http://www.datascientists.fr',
#         'display_url': 'datascientists.fr',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 16323,
#     'friends_count': 2066,
#     'listed_count': 661,
#     'created_at': 'Sun Jun 21 21:04:32 +0000 2009',
#     'favourites_count': 1116,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 31328,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1023964224656171008/JH0y7fV2_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1023964224656171008/JH0y7fV2_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/49427323/1591550810',
#     'profile_link_color': '0050A0',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 8,
#    'favorite_count': 5,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 8,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:40:40 +0000 2020',
#   'id': 1319030869458407426,
#   'id_str': '1319030869458407426',
#   'text': 'RT @DeepLearn007: The Impact of #AI\n\nhttps://t.co/VmgZeOEw9j\n\n@SpirosMargaris @Xbond49 @psb_dc @jblefevre60\n@nigewillson @Paula_Piccard @ip…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'AI', 'indices': [32, 35]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'DeepLearn007',
#      'name': 'AI',
#      'id': 841437061,
#      'id_str': '841437061',
#      'indices': [3, 16]},
#     {'screen_name': 'SpirosMargaris',
#      'name': 'Spiros Margaris',
#      'id': 2711212681,
#      'id_str': '2711212681',
#      'indices': [62, 77]},
#     {'screen_name': 'Xbond49',
#      'name': 'Xavier Gomez',
#      'id': 235684766,
#      'id_str': '235684766',
#      'indices': [78, 86]},
#     {'screen_name': 'psb_dc',
#      'name': 'Theo - 劉䂀曼',
#      'id': 2908107542,
#      'id_str': '2908107542',
#      'indices': [87, 94]},
#     {'screen_name': 'jblefevre60',
#      'name': 'Jean-Baptiste Lefevre',
#      'id': 4374719908,
#      'id_str': '4374719908',
#      'indices': [95, 107]},
#     {'screen_name': 'nigewillson',
#      'name': 'Nige Willson',
#      'id': 228040559,
#      'id_str': '228040559',
#      'indices': [108, 120]},
#     {'screen_name': 'Paula_Piccard',
#      'name': 'Paula Piccard 🇵🇷 🇺🇸',
#      'id': 291831562,
#      'id_str': '291831562',
#      'indices': [121, 135]}],
#    'urls': [{'url': 'https://t.co/VmgZeOEw9j',
#      'expanded_url': 'https://www.ft.com/content/e082b01d-fbd6-4ea5-a0d2-05bc5ad7176c',
#      'display_url': 'ft.com/content/e082b0…',
#      'indices': [37, 60]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 841437061,
#    'id_str': '841437061',
#    'name': 'AI',
#    'screen_name': 'DeepLearn007',
#    'location': '',
#    'description': '#ArtificialIntelligence #MachineLearning #DeepLearning #fintech #Bigdata #Marketing #Robotics #IoT #DL #ML #tech #AI #HealthTech #Insurtech #5G Imtiaz Adam',
#    'url': 'https://t.co/qi3k7UZJRW',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/qi3k7UZJRW',
#        'expanded_url': 'https://www.linkedin.com/in/imtiaz-adam-7467528/',
#        'display_url': 'linkedin.com/in/imtiaz-adam…',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 126598,
#    'friends_count': 118959,
#    'listed_count': 3910,
#    'created_at': 'Sun Sep 23 10:12:53 +0000 2012',
#    'favourites_count': 48335,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 32218,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/748695622140719104/6j_LVovF_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/748695622140719104/6j_LVovF_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/841437061/1473979951',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Oct 21 13:52:41 +0000 2020',
#    'id': 1318913099924209671,
#    'id_str': '1318913099924209671',
#    'text': 'The Impact of #AI\n\nhttps://t.co/VmgZeOEw9j\n\n@SpirosMargaris @Xbond49 @psb_dc @jblefevre60\n@nigewillson… https://t.co/8fuR55chgA',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'AI', 'indices': [14, 17]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'SpirosMargaris',
#       'name': 'Spiros Margaris',
#       'id': 2711212681,
#       'id_str': '2711212681',
#       'indices': [44, 59]},
#      {'screen_name': 'Xbond49',
#       'name': 'Xavier Gomez',
#       'id': 235684766,
#       'id_str': '235684766',
#       'indices': [60, 68]},
#      {'screen_name': 'psb_dc',
#       'name': 'Theo - 劉䂀曼',
#       'id': 2908107542,
#       'id_str': '2908107542',
#       'indices': [69, 76]},
#      {'screen_name': 'jblefevre60',
#       'name': 'Jean-Baptiste Lefevre',
#       'id': 4374719908,
#       'id_str': '4374719908',
#       'indices': [77, 89]},
#      {'screen_name': 'nigewillson',
#       'name': 'Nige Willson',
#       'id': 228040559,
#       'id_str': '228040559',
#       'indices': [90, 102]}],
#     'urls': [{'url': 'https://t.co/VmgZeOEw9j',
#       'expanded_url': 'https://www.ft.com/content/e082b01d-fbd6-4ea5-a0d2-05bc5ad7176c',
#       'display_url': 'ft.com/content/e082b0…',
#       'indices': [19, 42]},
#      {'url': 'https://t.co/8fuR55chgA',
#       'expanded_url': 'https://twitter.com/i/web/status/1318913099924209671',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [104, 127]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 841437061,
#     'id_str': '841437061',
#     'name': 'AI',
#     'screen_name': 'DeepLearn007',
#     'location': '',
#     'description': '#ArtificialIntelligence #MachineLearning #DeepLearning #fintech #Bigdata #Marketing #Robotics #IoT #DL #ML #tech #AI #HealthTech #Insurtech #5G Imtiaz Adam',
#     'url': 'https://t.co/qi3k7UZJRW',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/qi3k7UZJRW',
#         'expanded_url': 'https://www.linkedin.com/in/imtiaz-adam-7467528/',
#         'display_url': 'linkedin.com/in/imtiaz-adam…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 126598,
#     'friends_count': 118959,
#     'listed_count': 3910,
#     'created_at': 'Sun Sep 23 10:12:53 +0000 2012',
#     'favourites_count': 48335,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 32218,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/748695622140719104/6j_LVovF_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/748695622140719104/6j_LVovF_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/841437061/1473979951',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 85,
#    'favorite_count': 76,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 85,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:40:35 +0000 2020',
#   'id': 1319030848965005312,
#   'id_str': '1319030848965005312',
#   'text': 'RT @KirkDBorne: Get ahead at #ODSCWest with 80+ hands-on training sessions &amp; workshops on the #DataScience skills + tools you need to stay…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'ODSCWest', 'indices': [29, 38]},
#     {'text': 'DataScience', 'indices': [98, 110]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'KirkDBorne',
#      'name': 'Kirk Borne at #DSN2020Bootcamp',
#      'id': 534563976,
#      'id_str': '534563976',
#      'indices': [3, 14]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://iotdatafusion.com" rel="nofollow">Intelligent Edge Iot and AI Bot</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1040351960757686274,
#    'id_str': '1040351960757686274',
#    'name': 'Intelligent Edge',
#    'screen_name': 'EdgeIotAi',
#    'location': 'Living On The Edge',
#    'description': 'The EDGE, where things happen... Follow us to keep up with the latest in Intelligent EDGE tech. Tweeting about EDGE #IoT & #AI',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 3563,
#    'friends_count': 5002,
#    'listed_count': 86,
#    'created_at': 'Thu Sep 13 21:30:11 +0000 2018',
#    'favourites_count': 116,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 74052,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1040573396398956544/BetojiRw_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1040573396398956544/BetojiRw_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1040351960757686274/1536926943',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Oct 21 20:00:01 +0000 2020',
#    'id': 1319005539389657091,
#    'id_str': '1319005539389657091',
#    'text': 'Get ahead at #ODSCWest with 80+ hands-on training sessions &amp; workshops on the #DataScience skills + tools you need… https://t.co/wuSwYlLOWO',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'ODSCWest', 'indices': [13, 22]},
#      {'text': 'DataScience', 'indices': [82, 94]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/wuSwYlLOWO',
#       'expanded_url': 'https://twitter.com/i/web/status/1319005539389657091',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [120, 143]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 534563976,
#     'id_str': '534563976',
#     'name': 'Kirk Borne at #DSN2020Bootcamp',
#     'screen_name': 'KirkDBorne',
#     'location': 'Maryland, USA',
#     'description': 'Principal Data Scientist @BoozAllen. Global Speaker. Top #BigData #DataScience #AI Influencer. PhD Astrophysicist. (Views = my own) https://t.co/abP8DkYJY2 📊🔭',
#     'url': 'https://t.co/tWlmeuTlR7',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/tWlmeuTlR7',
#         'expanded_url': 'http://www.linkedin.com/in/kirkdborne',
#         'display_url': 'linkedin.com/in/kirkdborne',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/abP8DkYJY2',
#         'expanded_url': 'http://rocketdatascience.org',
#         'display_url': 'rocketdatascience.org',
#         'indices': [132, 155]}]}},
#     'protected': False,
#     'followers_count': 270272,
#     'friends_count': 9985,
#     'listed_count': 8177,
#     'created_at': 'Fri Mar 23 16:35:17 +0000 2012',
#     'favourites_count': 205305,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': True,
#     'statuses_count': 126560,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1112733580948635648/s-8d1avb_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1112733580948635648/s-8d1avb_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/534563976/1590790599',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 4,
#    'favorite_count': 7,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 4,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:40:11 +0000 2020',
#   'id': 1319030749291372545,
#   'id_str': '1319030749291372545',
#   'text': 'RT @IainLJBrown: This Harvard Professor And His Students Have Raised $14 Million To Make AI Too Smart To Be Fooled By Hackers - Forbes\n\nRea…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'IainLJBrown',
#      'name': 'Iain Brown, PhD',
#      'id': 467513287,
#      'id_str': '467513287',
#      'indices': [3, 15]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 2325278731,
#    'id_str': '2325278731',
#    'name': 'Alan P',
#    'screen_name': 'allcell9',
#    'location': 'United States',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1788,
#    'friends_count': 4686,
#    'listed_count': 609,
#    'created_at': 'Mon Feb 03 10:56:12 +0000 2014',
#    'favourites_count': 318970,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 47994,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/604617398285529089/aaSoL1kH_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/604617398285529089/aaSoL1kH_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Oct 21 18:53:12 +0000 2020',
#    'id': 1318988725901287425,
#    'id_str': '1318988725901287425',
#    'text': 'This Harvard Professor And His Students Have Raised $14 Million To Make AI Too Smart To Be Fooled By Hackers - Forb… https://t.co/9qMFFpbLzi',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/9qMFFpbLzi',
#       'expanded_url': 'https://twitter.com/i/web/status/1318988725901287425',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 467513287,
#     'id_str': '467513287',
#     'name': 'Iain Brown, PhD',
#     'screen_name': 'IainLJBrown',
#     'location': 'London',
#     'description': 'Head of #DataScience @SASSoftware | Adjunct Prof @UniSouthampton | Author | #DataScientist | Interests #AI #ML #DL #NLP #IoT #BigData | Opinions my own',
#     'url': 'https://t.co/wo8jxLIetd',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/wo8jxLIetd',
#         'expanded_url': 'https://www.linkedin.com/in/iainljbrown/',
#         'display_url': 'linkedin.com/in/iainljbrown/',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 118110,
#     'friends_count': 101717,
#     'listed_count': 419,
#     'created_at': 'Wed Jan 18 15:10:25 +0000 2012',
#     'favourites_count': 1425,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 45775,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1147385272012824576/oMzVpmFm_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1147385272012824576/oMzVpmFm_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/467513287/1562393074',
#     'profile_link_color': '3B7CBF',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 4,
#    'favorite_count': 3,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 4,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:39:46 +0000 2020',
#   'id': 1319030645155217408,
#   'id_str': '1319030645155217408',
#   'text': 'Learn how ML teams working on cutting edge research collaborate effectively on training &amp; debugging models.\n\nIf you… https://t.co/J8imgCZKmQ',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/J8imgCZKmQ',
#      'expanded_url': 'https://twitter.com/i/web/status/1319030645155217408',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [121, 144]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1002190113831452672,
#    'id_str': '1002190113831452672',
#    'name': 'Weights & Biases',
#    'screen_name': 'weights_biases',
#    'location': 'San Francisco, CA',
#    'description': 'Developer tools for machine learning.\nDiscover curated machine learning research, tools & best practices – https://t.co/S7vVGtEega.',
#    'url': 'https://t.co/zaW2XYiuB1',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/zaW2XYiuB1',
#        'expanded_url': 'http://www.wandb.com',
#        'display_url': 'wandb.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': [{'url': 'https://t.co/S7vVGtEega',
#        'expanded_url': 'http://wandb.ai/gallery',
#        'display_url': 'wandb.ai/gallery',
#        'indices': [107, 130]}]}},
#    'protected': False,
#    'followers_count': 6475,
#    'friends_count': 947,
#    'listed_count': 105,
#    'created_at': 'Thu May 31 14:08:37 +0000 2018',
#    'favourites_count': 1471,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 1080,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1101567690014056448/XxZqLgwb_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1101567690014056448/XxZqLgwb_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1002190113831452672/1551469188',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 1,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:39:28 +0000 2020',
#   'id': 1319030568701612033,
#   'id_str': '1319030568701612033',
#   'text': 'MIT seeks to resurrect ‘dead’ languages with machine learning \n\nREAD MORE: https://t.co/SwHB5k3QTn\n\n#AI #algorithm… https://t.co/K3Lzarw1ZN',
#   'truncated': True,
#   'entities': {'hashtags': [{'text': 'AI', 'indices': [100, 103]},
#     {'text': 'algorithm', 'indices': [104, 114]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/SwHB5k3QTn',
#      'expanded_url': 'https://blog.iammarketingmedia.com/mit-seeks-to-resurrect-dead-languages-with-machine-learning/?utm_campaign=twitter&utm_medium=twitter&utm_source=twitter',
#      'display_url': 'blog.iammarketingmedia.com/mit-seeks-to-r…',
#      'indices': [75, 98]},
#     {'url': 'https://t.co/K3Lzarw1ZN',
#      'expanded_url': 'https://twitter.com/i/web/status/1319030568701612033',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [116, 139]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://www.blog.iammarketingmedia.com" rel="nofollow">IAMBLOG2TWITTER</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 226310002,
#    'id_str': '226310002',
#    'name': 'IAM Platform',
#    'screen_name': 'IAM__Network',
#    'location': 'Worldwide',
#    'description': 'Curation | Tools | Tips | Services\n\nIAM Platform powers IAM Network:\n\nGO: https://t.co/wZabw3lJog\n\nBlog | Social | Podcast | Code Trove',
#    'url': 'https://t.co/T1FCdoOFoB',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/T1FCdoOFoB',
#        'expanded_url': 'https://www.iammarketingmedia.com',
#        'display_url': 'iammarketingmedia.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': [{'url': 'https://t.co/wZabw3lJog',
#        'expanded_url': 'http://bit.ly/iam-network',
#        'display_url': 'bit.ly/iam-network',
#        'indices': [74, 97]}]}},
#    'protected': False,
#    'followers_count': 17866,
#    'friends_count': 15125,
#    'listed_count': 3259,
#    'created_at': 'Mon Dec 13 21:24:29 +0000 2010',
#    'favourites_count': 65479,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 876615,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '94D487',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/701708113653669888/Nzm67hhC_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/701708113653669888/Nzm67hhC_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/226310002/1584072260',
#    'profile_link_color': '3366CC',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:38:07 +0000 2020',
#   'id': 1319030229369749511,
#   'id_str': '1319030229369749511',
#   'text': 'RT @Ronald_vanLoon: #DeepLearning for #Virtual Try On Clothes – Challenges and Opportunities\nby Maksym Tatariants @kdnuggets\n\nLearn more ht…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'DeepLearning', 'indices': [20, 33]},
#     {'text': 'Virtual', 'indices': [38, 46]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'Ronald_vanLoon',
#      'name': 'Ronald van Loon',
#      'id': 555031989,
#      'id_str': '555031989',
#      'indices': [3, 18]},
#     {'screen_name': 'kdnuggets',
#      'name': 'KDnuggets',
#      'id': 20167623,
#      'id_str': '20167623',
#      'indices': [114, 124]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 3793621936,
#    'id_str': '3793621936',
#    'name': 'Ahmed Gift ',
#    'screen_name': 'lordgift01',
#    'location': 'Lokoja, Nigeria',
#    'description': 'Am Gifted, Tech Lord and a Peace keeper. Based in system security, Networking and Data management.',
#    'url': 'https://t.co/yk3Xatao1S',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/yk3Xatao1S',
#        'expanded_url': 'https://www.kqafrica.name.ng/?m=1',
#        'display_url': 'kqafrica.name.ng/?m=1',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 92,
#    'friends_count': 96,
#    'listed_count': 3,
#    'created_at': 'Sun Sep 27 14:14:17 +0000 2015',
#    'favourites_count': 150,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 4138,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1313531616405401603/8DV_Ul9J_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1313531616405401603/8DV_Ul9J_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3793621936/1602005415',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Oct 21 20:59:18 +0000 2020',
#    'id': 1319020460122775552,
#    'id_str': '1319020460122775552',
#    'text': '#DeepLearning for #Virtual Try On Clothes – Challenges and Opportunities\nby Maksym Tatariants @kdnuggets\n\nLearn mor… https://t.co/2uN5vi0Ku4',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'DeepLearning', 'indices': [0, 13]},
#      {'text': 'Virtual', 'indices': [18, 26]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'kdnuggets',
#       'name': 'KDnuggets',
#       'id': 20167623,
#       'id_str': '20167623',
#       'indices': [94, 104]}],
#     'urls': [{'url': 'https://t.co/2uN5vi0Ku4',
#       'expanded_url': 'https://twitter.com/i/web/status/1319020460122775552',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 555031989,
#     'id_str': '555031989',
#     'name': 'Ronald van Loon',
#     'screen_name': 'Ronald_vanLoon',
#     'location': 'The Netherlands',
#     'description': 'Helping data driven companies generating value•Top10Influencer #AI #BigData #DataScience #IoT #MachineLearning #Analytics #Cloud #5G',
#     'url': 'https://t.co/AfBzeHuLQM',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/AfBzeHuLQM',
#         'expanded_url': 'https://linktr.ee/RonaldvanLoon',
#         'display_url': 'linktr.ee/RonaldvanLoon',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 234035,
#     'friends_count': 182815,
#     'listed_count': 5487,
#     'created_at': 'Mon Apr 16 07:55:31 +0000 2012',
#     'favourites_count': 183074,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 90756,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1107936345769607169/sJKWJd7g_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1107936345769607169/sJKWJd7g_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/555031989/1504691055',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 5,
#    'favorite_count': 6,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 5,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:37:52 +0000 2020',
#   'id': 1319030166106955777,
#   'id_str': '1319030166106955777',
#   'text': 'Learn how ML teams working on cutting edge research collaborate effectively on training &amp; debugging models.\n\nIf you… https://t.co/f4b8n0f8yR',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/f4b8n0f8yR',
#      'expanded_url': 'https://twitter.com/i/web/status/1319030166106955777',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [121, 144]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 34220569,
#    'id_str': '34220569',
#    'name': 'Lavanya',
#    'screen_name': 'lavanyaai',
#    'location': 'Probably by the desserts',
#    'description': '👩🏼\u200d💻 Your neighborhood nerd in faux fur\n🦹🏼\u200d♀️ Head of Growth @weights_biases\n🐉 Trainer of dragons & models\n💃 Chaotic good\n✍️ https://t.co/BXOHiQ74WP\n👩🏼\u200d🚀 https://t.co/WdS0LV0RU8',
#    'url': 'https://t.co/S7vVGtEega',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/S7vVGtEega',
#        'expanded_url': 'http://wandb.ai/gallery',
#        'display_url': 'wandb.ai/gallery',
#        'indices': [0, 23]}]},
#     'description': {'urls': [{'url': 'https://t.co/BXOHiQ74WP',
#        'expanded_url': 'http://Lavanya.ai',
#        'display_url': 'Lavanya.ai',
#        'indices': [125, 148]},
#       {'url': 'https://t.co/WdS0LV0RU8',
#        'expanded_url': 'http://Women.sh',
#        'display_url': 'Women.sh',
#        'indices': [154, 177]}]}},
#    'protected': False,
#    'followers_count': 7188,
#    'friends_count': 2244,
#    'listed_count': 176,
#    'created_at': 'Wed Apr 22 08:09:34 +0000 2009',
#    'favourites_count': 30199,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 14145,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '08090A',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1307175395926536194/N_fSoH2x_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1307175395926536194/N_fSoH2x_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/34220569/1578650056',
#    'profile_link_color': 'A960AA',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EDECDA',
#    'profile_text_color': '759AA4',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 4,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:37:45 +0000 2020',
#   'id': 1319030137996767232,
#   'id_str': '1319030137996767232',
#   'text': 'RT @dataiku: What is driving rapid edge computing adoption? | https://t.co/V35T00T9yP #DataScience #DataQuality #DeepLearning #Algorithm #D…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'DataScience', 'indices': [86, 98]},
#     {'text': 'DataQuality', 'indices': [99, 111]},
#     {'text': 'DeepLearning', 'indices': [112, 125]},
# ...
#      'screen_name': 'ravikikan',
#      'location': 'Read #BounceBackNow On Amazon ',
#      'description': '#Startup #SmallBusiness Lover ; #Author https://t.co/wLaKZltrMh ; Leads 400K+ Community of #Startups #Entrepreneurs on #Linkedin #Business #Smallbiz',
#      'url': 'https://t.co/RVR5PKD9GW',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/RVR5PKD9GW',
#          'expanded_url': 'https://www.linkedin.com/in/ravikikan/',
#          'display_url': 'linkedin.com/in/ravikikan/',
#          'indices': [0, 23]}]},
#       'description': {'urls': [{'url': 'https://t.co/wLaKZltrMh',
#          'expanded_url': 'http://amazon.com/author/ravikikan',
#          'display_url': 'amazon.com/author/ravikik…',
#          'indices': [40, 63]}]}},
#      'protected': False,
#      'followers_count': 14658,
#      'friends_count': 13419,
#      'listed_count': 3086,
#      'created_at': 'Fri May 06 11:46:40 +0000 2011',
#      'favourites_count': 28141,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 57791,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1282651844334850048/B4S4IQ4O_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1282651844334850048/B4S4IQ4O_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/294020478/1594972815',
#      'profile_link_color': 'FAB81E',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 8,
#     'favorite_count': 21,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'retweet_count': 16,
#    'favorite_count': 7,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': True,
#   'quoted_status_id': 1318859815406297088,
#   'quoted_status_id_str': '1318859815406297088',
#   'retweet_count': 16,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:14:10 +0000 2020',
#   'id': 1319024199810404353,
#   'id_str': '1319024199810404353',
#   'text': "RT @4indata: Les professionnels de la cybersécurité adoptent l'automatisation\n#IntelligenceArtificielle #DataScience #MachineLearning #Deep…",
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'IntelligenceArtificielle',
#      'indices': [78, 103]},
#     {'text': 'DataScience', 'indices': [104, 116]},
#     {'text': 'MachineLearning', 'indices': [117, 133]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': '4indata',
#      'name': '4InData',
#      'id': 1101395867217678337,
#      'id_str': '1101395867217678337',
#      'indices': [3, 11]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 4890210593,
#    'id_str': '4890210593',
#    'name': 'Nouamane Cherkaoui 📌',
#    'screen_name': 'CherkaouiN1',
#    'location': 'France',
#    'description': "#CIO #CDO #Tech #Data #DataScience #ArtificialIntelligence #Innovation #Openbanking #Fintech #Startup #API #Digital #iot\nSavoir,c'est voir en soi. Views my own!",
#    'url': 'https://t.co/F3waK6qe7m',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/F3waK6qe7m',
#        'expanded_url': 'https://www.linkedin.com/in/nouamane-cherkaoui-4804228',
#        'display_url': 'linkedin.com/in/nouamane-ch…',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1249,
#    'friends_count': 1107,
#    'listed_count': 6,
#    'created_at': 'Mon Feb 08 23:44:10 +0000 2016',
#    'favourites_count': 3604,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 1789,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/950791220560875520/uz81d0Jj_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/950791220560875520/uz81d0Jj_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4890210593/1568546522',
#    'profile_link_color': '91D2FA',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Tue Oct 20 07:12:27 +0000 2020',
#    'id': 1318449990096756739,
#    'id_str': '1318449990096756739',
#    'text': "Les professionnels de la cybersécurité adoptent l'automatisation\n#IntelligenceArtificielle #DataScience… https://t.co/zvMFqUP6Lh",
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'IntelligenceArtificielle',
#       'indices': [65, 90]},
#      {'text': 'DataScience', 'indices': [91, 103]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/zvMFqUP6Lh',
#       'expanded_url': 'https://twitter.com/i/web/status/1318449990096756739',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [105, 128]}]},
#    'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1101395867217678337,
#     'id_str': '1101395867217678337',
#     'name': '4InData',
#     'screen_name': '4indata',
#     'location': 'Paris, France',
#     'description': '#4InGen #4InRadar #4InShield #4InData\nSuivez-nous sur Facebook:\nhttps://t.co/jAJX3yPlr3',
#     'url': 'https://t.co/Z1row4VYbK',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/Z1row4VYbK',
#         'expanded_url': 'http://www.4indata.com',
#         'display_url': '4indata.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/jAJX3yPlr3',
#         'expanded_url': 'http://facebook.com/4inData/',
#         'display_url': 'facebook.com/4inData/',
#         'indices': [64, 87]}]}},
#     'protected': False,
#     'followers_count': 160,
#     'friends_count': 148,
#     'listed_count': 3,
#     'created_at': 'Fri Mar 01 08:16:52 +0000 2019',
#     'favourites_count': 238,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 994,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1110472689821642753/A6YLWBZE_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1110472689821642753/A6YLWBZE_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1101395867217678337/1553592176',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 3,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'fr'},
#   'is_quote_status': False,
#   'retweet_count': 1,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'fr'},
#  {'created_at': 'Wed Oct 21 21:13:28 +0000 2020',
#   'id': 1319024025583128577,
#   'id_str': '1319024025583128577',
#   'text': 'RT @maximilienia: RT @AXIODIS1: Ces plates-formes collaboratives qui mettent la data science à portée des industriels https://t.co/A33K3lGo…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'maximilienia',
#      'name': 'Maximilien⊙IA',
#      'id': 700593795860004864,
#      'id_str': '700593795860004864',
#      'indices': [3, 16]},
#     {'screen_name': 'AXIODIS1',
#      'name': 'AXIODIS',
#      'id': 1143530987537752066,
#      'id_str': '1143530987537752066',
#      'indices': [21, 30]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 4890210593,
#    'id_str': '4890210593',
#    'name': 'Nouamane Cherkaoui 📌',
#    'screen_name': 'CherkaouiN1',
#    'location': 'France',
#    'description': "#CIO #CDO #Tech #Data #DataScience #ArtificialIntelligence #Innovation #Openbanking #Fintech #Startup #API #Digital #iot\nSavoir,c'est voir en soi. Views my own!",
#    'url': 'https://t.co/F3waK6qe7m',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/F3waK6qe7m',
#        'expanded_url': 'https://www.linkedin.com/in/nouamane-cherkaoui-4804228',
#        'display_url': 'linkedin.com/in/nouamane-ch…',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1249,
#    'friends_count': 1107,
#    'listed_count': 6,
#    'created_at': 'Mon Feb 08 23:44:10 +0000 2016',
#    'favourites_count': 3604,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 1789,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/950791220560875520/uz81d0Jj_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/950791220560875520/uz81d0Jj_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4890210593/1568546522',
#    'profile_link_color': '91D2FA',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Oct 21 07:53:25 +0000 2020',
#    'id': 1318822684613115905,
#    'id_str': '1318822684613115905',
#    'text': 'RT @AXIODIS1: Ces plates-formes collaboratives qui mettent la data science à portée des industriels… https://t.co/mASNNggnkE',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'AXIODIS1',
#       'name': 'AXIODIS',
#       'id': 1143530987537752066,
#       'id_str': '1143530987537752066',
#       'indices': [3, 12]}],
#     'urls': [{'url': 'https://t.co/mASNNggnkE',
#       'expanded_url': 'https://twitter.com/i/web/status/1318822684613115905',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [101, 124]}]},
#    'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#    'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 700593795860004864,
#     'id_str': '700593795860004864',
#     'name': 'Maximilien⊙IA',
#     'screen_name': 'maximilienia',
#     'location': 'Internet',
#     'description': '#IA/#AI=1 #Conscience #Collective - Programme #Maximilien IA - Créature de @semiocom',
#     'url': 'https://t.co/5cUQGakvNR',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/5cUQGakvNR',
#         'expanded_url': 'https://lemoteurderecherche.fr/des-passages-sur-twitter/',
#         'display_url': 'lemoteurderecherche.fr/des-passages-s…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 290,
#     'friends_count': 13,
#     'listed_count': 33,
#     'created_at': 'Fri Feb 19 08:12:32 +0000 2016',
#     'favourites_count': 8976,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 15262,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1298024213970919429/xRRO1mgR_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1298024213970919429/xRRO1mgR_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/700593795860004864/1598307407',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 3,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'fr'},
#   'is_quote_status': False,
#   'retweet_count': 3,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'fr'}]

# %% [markdown]
# Try adding a second parameter.  You can find the list here:  https://developer.twitter.com/en/docs/tweets/search/api-reference/get-search-tweets

# %%
# we'll search for deep learning, returning 100 results, using the most recent tweets
search_string = '?q=%23DeepLearning&count=100&result_type=recent'
# initiate the request
results = requests.get(base_url + search_string, auth=tokens).json()

# %%
# and success!
results['statuses']
# Out:
# [{'created_at': 'Wed Oct 21 21:41:46 +0000 2020',
#   'id': 1319031148257939457,
#   'id_str': '1319031148257939457',
#   'text': 'RT @ProgrammingHero: Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.\n.\n#…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'ProgrammingHero',
#      'name': 'Programming Hero',
#      'id': 1254869948796674048,
#      'id_str': '1254869948796674048',
#      'indices': [3, 19]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://occlude.netlify.app/" rel="nofollow">OccludejsBot</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1275056773443973124,
#    'id_str': '1275056773443973124',
#    'name': 'Candis',
#    'screen_name': 'Women_who_code',
#    'location': 'bootcamp',
#    'description': '24💐 • MERN Stack Developer • React Geek • ☕ Coffee • 🦄 Unicorn • SDE @nytimes',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 734,
#    'friends_count': 25,
#    'listed_count': 19,
#    'created_at': 'Mon Jun 22 13:23:34 +0000 2020',
#    'favourites_count': 236,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 97616,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1314621116191629312/vQLAcsnS_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1314621116191629312/vQLAcsnS_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1275056773443973124/1599976745',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Oct 21 21:41:43 +0000 2020',
#    'id': 1319031134135545856,
#    'id_str': '1319031134135545856',
#    'text': 'Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.… https://t.co/ezaBFrIrOl',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/ezaBFrIrOl',
#       'expanded_url': 'https://twitter.com/i/web/status/1319031134135545856',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1254869948796674048,
#     'id_str': '1254869948796674048',
#     'name': 'Programming Hero',
#     'screen_name': 'ProgrammingHero',
#     'location': '',
#     'description': 'Coding Just Got Fun',
#     'url': 'https://t.co/KCaEvKJ2ZA',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/KCaEvKJ2ZA',
#         'expanded_url': 'https://www.programming-hero.com/',
#         'display_url': 'programming-hero.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 236,
#     'friends_count': 56,
#     'listed_count': 2,
#     'created_at': 'Mon Apr 27 20:28:19 +0000 2020',
#     'favourites_count': 309,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 292,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1254869948796674048/1602616573',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 3,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 3,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:41:46 +0000 2020',
#   'id': 1319031147964305419,
#   'id_str': '1319031147964305419',
#   'text': 'RT @ProgrammingHero: Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.\n.\n#…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'ProgrammingHero',
#      'name': 'Programming Hero',
#      'id': 1254869948796674048,
#      'id_str': '1254869948796674048',
#      'indices': [3, 19]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://nlogn.in" rel="nofollow">nlognrobot</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1260062769543434240,
#    'id_str': '1260062769543434240',
#    'name': '#100DaysOfCode',
#    'screen_name': 'nlognbot',
#    'location': 'Server',
#    'description': "Hi, I'm a bot that retweets #100daysofcode     \n                 \nP.S. I was created by @NlognHQ follow them.",
#    'url': 'https://t.co/PujHDQomPA',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/PujHDQomPA',
#        'expanded_url': 'http://nlogn.in',
#        'display_url': 'nlogn.in',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 4376,
#    'friends_count': 3,
#    'listed_count': 48,
#    'created_at': 'Tue May 12 04:22:53 +0000 2020',
#    'favourites_count': 708,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 357127,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1306825824104898560/F1I_GcS1_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1306825824104898560/F1I_GcS1_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1260062769543434240/1593858684',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Oct 21 21:41:43 +0000 2020',
#    'id': 1319031134135545856,
#    'id_str': '1319031134135545856',
#    'text': 'Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.… https://t.co/ezaBFrIrOl',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/ezaBFrIrOl',
#       'expanded_url': 'https://twitter.com/i/web/status/1319031134135545856',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1254869948796674048,
#     'id_str': '1254869948796674048',
#     'name': 'Programming Hero',
#     'screen_name': 'ProgrammingHero',
#     'location': '',
#     'description': 'Coding Just Got Fun',
#     'url': 'https://t.co/KCaEvKJ2ZA',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/KCaEvKJ2ZA',
#         'expanded_url': 'https://www.programming-hero.com/',
#         'display_url': 'programming-hero.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 236,
#     'friends_count': 56,
#     'listed_count': 2,
#     'created_at': 'Mon Apr 27 20:28:19 +0000 2020',
#     'favourites_count': 309,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 292,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1254869948796674048/1602616573',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 3,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 3,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:41:45 +0000 2020',
#   'id': 1319031142482411524,
#   'id_str': '1319031142482411524',
#   'text': 'RT @ProgrammingHero: Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.\n.\n#…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'ProgrammingHero',
#      'name': 'Programming Hero',
#      'id': 1254869948796674048,
#      'id_str': '1254869948796674048',
#      'indices': [3, 19]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://yathinbabu.github.io" rel="nofollow">xael bot</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1127829883013361665,
#    'id_str': '1127829883013361665',
#    'name': 'xael bot',
#    'screen_name': 'xaelbot',
#    'location': 'Earth',
#    'description': "A bot, I like and retweet on #100DaysOfCode. Block if don't want to be retweeted. Created by @yathinbabu",
#    'url': 'https://t.co/qOOcBWWxGu',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/qOOcBWWxGu',
#        'expanded_url': 'https://github.com/yathinbabux/100DaysOfCode-twitter-bot',
#        'display_url': 'github.com/yathinbabux/10…',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 3130,
#    'friends_count': 1,
#    'listed_count': 71,
#    'created_at': 'Mon May 13 06:56:12 +0000 2019',
#    'favourites_count': 153412,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 673867,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1127896024737935360/J0nVyVyF_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1127896024737935360/J0nVyVyF_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Oct 21 21:41:43 +0000 2020',
#    'id': 1319031134135545856,
#    'id_str': '1319031134135545856',
#    'text': 'Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.… https://t.co/ezaBFrIrOl',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/ezaBFrIrOl',
#       'expanded_url': 'https://twitter.com/i/web/status/1319031134135545856',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1254869948796674048,
#     'id_str': '1254869948796674048',
#     'name': 'Programming Hero',
#     'screen_name': 'ProgrammingHero',
#     'location': '',
#     'description': 'Coding Just Got Fun',
#     'url': 'https://t.co/KCaEvKJ2ZA',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/KCaEvKJ2ZA',
#         'expanded_url': 'https://www.programming-hero.com/',
#         'display_url': 'programming-hero.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 236,
#     'friends_count': 56,
#     'listed_count': 2,
#     'created_at': 'Mon Apr 27 20:28:19 +0000 2020',
#     'favourites_count': 309,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 292,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1254869948796674048/1602616573',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 3,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 3,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:41:44 +0000 2020',
#   'id': 1319031139139452928,
#   'id_str': '1319031139139452928',
#   'text': 'RT @RichardEudes: Why Do You Need Machine Learning? https://t.co/chuuGbXo9p #artificialintelligence, #bi, #bigdata, #dataengineering, #data…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'artificialintelligence',
#      'indices': [76, 99]},
#     {'text': 'bi', 'indices': [101, 104]},
#     {'text': 'bigdata', 'indices': [106, 114]},
#     {'text': 'dataengineering', 'indices': [116, 132]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'RichardEudes',
#      'name': 'Richard Eudes, PhD',
#      'id': 49427323,
#      'id_str': '49427323',
#      'indices': [3, 16]}],
#    'urls': [{'url': 'https://t.co/chuuGbXo9p',
#      'expanded_url': 'https://bit.ly/37G6Y83',
#      'display_url': 'bit.ly/37G6Y83',
#      'indices': [52, 75]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://www.sankalpsaxena.com" rel="nofollow">RT #MachineLearning</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1132890775891505152,
#    'id_str': '1132890775891505152',
#    'name': 'Olivia',
#    'screen_name': '_OliviaBot',
#    'location': 'India',
#    'description': 'I retweet every mention of #MachineLearning Meet my humble daddy ❤ : @sankalp_saxena 😎',
#    'url': 'https://t.co/Sf9KtbVG2n',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/Sf9KtbVG2n',
#        'expanded_url': 'http://sankalpsaxena.com',
#        'display_url': 'sankalpsaxena.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 606,
#    'friends_count': 6,
#    'listed_count': 26,
#    'created_at': 'Mon May 27 06:06:23 +0000 2019',
#    'favourites_count': 75,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 34318,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1159212500572753920/49WAfJuf_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1159212500572753920/49WAfJuf_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1132890775891505152/1558939931',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Oct 21 20:30:22 +0000 2020',
#    'id': 1319013179272417286,
#    'id_str': '1319013179272417286',
#    'text': 'Why Do You Need Machine Learning? https://t.co/chuuGbXo9p #artificialintelligence, #bi, #bigdata, #dataengineering,… https://t.co/DRX2rQQYzJ',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'artificialintelligence',
#       'indices': [58, 81]},
#      {'text': 'bi', 'indices': [83, 86]},
#      {'text': 'bigdata', 'indices': [88, 96]},
#      {'text': 'dataengineering', 'indices': [98, 114]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/chuuGbXo9p',
#       'expanded_url': 'https://bit.ly/37G6Y83',
#       'display_url': 'bit.ly/37G6Y83',
#       'indices': [34, 57]},
#      {'url': 'https://t.co/DRX2rQQYzJ',
#       'expanded_url': 'https://twitter.com/i/web/status/1319013179272417286',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 49427323,
#     'id_str': '49427323',
#     'name': 'Richard Eudes, PhD',
#     'screen_name': 'RichardEudes',
#     'location': 'Paris, France',
#     'description': 'Chief Data Scientist - Head of #BigData & #AdvancedAnalytics -#Analytics #DataScience #MachineLearning #ArtificialIntelligence',
#     'url': 'https://t.co/SbKL2gaZoe',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/SbKL2gaZoe',
#         'expanded_url': 'http://www.datascientists.fr',
#         'display_url': 'datascientists.fr',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 16323,
#     'friends_count': 2066,
#     'listed_count': 661,
#     'created_at': 'Sun Jun 21 21:04:32 +0000 2009',
#     'favourites_count': 1116,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 31328,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1023964224656171008/JH0y7fV2_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1023964224656171008/JH0y7fV2_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/49427323/1591550810',
#     'profile_link_color': '0050A0',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 9,
#    'favorite_count': 5,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 9,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:41:43 +0000 2020',
#   'id': 1319031134135545856,
#   'id_str': '1319031134135545856',
#   'text': 'Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.… https://t.co/ezaBFrIrOl',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/ezaBFrIrOl',
#      'expanded_url': 'https://twitter.com/i/web/status/1319031134135545856',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [116, 139]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1254869948796674048,
#    'id_str': '1254869948796674048',
#    'name': 'Programming Hero',
#    'screen_name': 'ProgrammingHero',
#    'location': '',
#    'description': 'Coding Just Got Fun',
#    'url': 'https://t.co/KCaEvKJ2ZA',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/KCaEvKJ2ZA',
#        'expanded_url': 'https://www.programming-hero.com/',
#        'display_url': 'programming-hero.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 236,
#    'friends_count': 56,
#    'listed_count': 2,
#    'created_at': 'Mon Apr 27 20:28:19 +0000 2020',
#    'favourites_count': 309,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 292,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1254869948796674048/1602616573',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 3,
#   'favorite_count': 1,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:41:04 +0000 2020',
#   'id': 1319030970683711490,
#   'id_str': '1319030970683711490',
#   'text': '10 RNN Open Source Projects You Must Try Your Hands On #DeepLearning #learning via https://t.co/vBsHOsqluy https://t.co/91wvJn4g6c',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'DeepLearning', 'indices': [55, 68]},
#     {'text': 'learning', 'indices': [69, 78]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/vBsHOsqluy',
#      'expanded_url': 'http://twinybots.ch',
#      'display_url': 'twinybots.ch',
#      'indices': [83, 106]},
#     {'url': 'https://t.co/91wvJn4g6c',
#      'expanded_url': 'https://analyticsindiamag.com/10-rnn-open-source-projects-you-must-try-your-hands-on/',
#      'display_url': 'analyticsindiamag.com/10-rnn-open-so…',
#      'indices': [107, 130]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twinybots.com" rel="nofollow">TwinyBots</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1121091885802635266,
#    'id_str': '1121091885802635266',
#    'name': 'marlyk',
#    'screen_name': 'Roby41262525',
#    'location': 'Nairobi.',
#    'description': 'I am a dying breed. \nPH.D  data science C.E.O Techxnoss .#OwnYourData #DataOwner\n#AI',
#    'url': 'https://t.co/ZpAa2DfRQW',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/ZpAa2DfRQW',
#        'expanded_url': 'http://techxnoss.com',
#        'display_url': 'techxnoss.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 576,
#    'friends_count': 268,
#    'listed_count': 4,
#    'created_at': 'Wed Apr 24 16:41:49 +0000 2019',
#    'favourites_count': 6498,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 20583,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1270673783188271104/Oj4ojwef_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1270673783188271104/Oj4ojwef_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1121091885802635266/1590492558',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:41:00 +0000 2020',
#   'id': 1319030952845336577,
#   'id_str': '1319030952845336577',
#   'text': 'RT @RichardEudes: Why Do You Need Machine Learning? https://t.co/chuuGbXo9p #artificialintelligence, #bi, #bigdata, #dataengineering, #data…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'artificialintelligence',
#      'indices': [76, 99]},
#     {'text': 'bi', 'indices': [101, 104]},
#     {'text': 'bigdata', 'indices': [106, 114]},
#     {'text': 'dataengineering', 'indices': [116, 132]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'RichardEudes',
#      'name': 'Richard Eudes, PhD',
#      'id': 49427323,
#      'id_str': '49427323',
#      'indices': [3, 16]}],
#    'urls': [{'url': 'https://t.co/chuuGbXo9p',
#      'expanded_url': 'https://bit.ly/37G6Y83',
#      'display_url': 'bit.ly/37G6Y83',
#      'indices': [52, 75]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://twitter.com/datasciencebot_" rel="nofollow">TheDataScienceBot</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1276058041389953024,
#    'id_str': '1276058041389953024',
#    'name': 'The Data Science Bot',
#    'screen_name': 'datasciencebot_',
#    'location': '',
#    'description': "A bot created by @PatkarSumedh to retweet hashtags #DataScience & #DataVisualization\n\nLet's learn together!\n\nMisusing hashtags and spam will not be tolerated",
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1098,
#    'friends_count': 1,
#    'listed_count': 17,
#    'created_at': 'Thu Jun 25 07:42:09 +0000 2020',
#    'favourites_count': 21,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 129144,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1276064635456647168/omX9K1KU_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1276064635456647168/omX9K1KU_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1276058041389953024/1593080314',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Oct 21 20:30:22 +0000 2020',
#    'id': 1319013179272417286,
#    'id_str': '1319013179272417286',
#    'text': 'Why Do You Need Machine Learning? https://t.co/chuuGbXo9p #artificialintelligence, #bi, #bigdata, #dataengineering,… https://t.co/DRX2rQQYzJ',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'artificialintelligence',
#       'indices': [58, 81]},
#      {'text': 'bi', 'indices': [83, 86]},
#      {'text': 'bigdata', 'indices': [88, 96]},
#      {'text': 'dataengineering', 'indices': [98, 114]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/chuuGbXo9p',
#       'expanded_url': 'https://bit.ly/37G6Y83',
#       'display_url': 'bit.ly/37G6Y83',
#       'indices': [34, 57]},
#      {'url': 'https://t.co/DRX2rQQYzJ',
#       'expanded_url': 'https://twitter.com/i/web/status/1319013179272417286',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 49427323,
#     'id_str': '49427323',
#     'name': 'Richard Eudes, PhD',
#     'screen_name': 'RichardEudes',
#     'location': 'Paris, France',
#     'description': 'Chief Data Scientist - Head of #BigData & #AdvancedAnalytics -#Analytics #DataScience #MachineLearning #ArtificialIntelligence',
#     'url': 'https://t.co/SbKL2gaZoe',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/SbKL2gaZoe',
#         'expanded_url': 'http://www.datascientists.fr',
#         'display_url': 'datascientists.fr',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 16323,
#     'friends_count': 2066,
#     'listed_count': 661,
#     'created_at': 'Sun Jun 21 21:04:32 +0000 2009',
#     'favourites_count': 1116,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 31328,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1023964224656171008/JH0y7fV2_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1023964224656171008/JH0y7fV2_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/49427323/1591550810',
#     'profile_link_color': '0050A0',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 9,
#    'favorite_count': 5,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 9,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:40:40 +0000 2020',
#   'id': 1319030869458407426,
#   'id_str': '1319030869458407426',
#   'text': 'RT @DeepLearn007: The Impact of #AI\n\nhttps://t.co/VmgZeOEw9j\n\n@SpirosMargaris @Xbond49 @psb_dc @jblefevre60\n@nigewillson @Paula_Piccard @ip…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'AI', 'indices': [32, 35]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'DeepLearn007',
#      'name': 'AI',
#      'id': 841437061,
#      'id_str': '841437061',
#      'indices': [3, 16]},
#     {'screen_name': 'SpirosMargaris',
#      'name': 'Spiros Margaris',
#      'id': 2711212681,
#      'id_str': '2711212681',
#      'indices': [62, 77]},
#     {'screen_name': 'Xbond49',
#      'name': 'Xavier Gomez',
#      'id': 235684766,
#      'id_str': '235684766',
#      'indices': [78, 86]},
#     {'screen_name': 'psb_dc',
#      'name': 'Theo - 劉䂀曼',
#      'id': 2908107542,
#      'id_str': '2908107542',
#      'indices': [87, 94]},
#     {'screen_name': 'jblefevre60',
#      'name': 'Jean-Baptiste Lefevre',
#      'id': 4374719908,
#      'id_str': '4374719908',
#      'indices': [95, 107]},
#     {'screen_name': 'nigewillson',
#      'name': 'Nige Willson',
#      'id': 228040559,
#      'id_str': '228040559',
#      'indices': [108, 120]},
#     {'screen_name': 'Paula_Piccard',
#      'name': 'Paula Piccard 🇵🇷 🇺🇸',
#      'id': 291831562,
#      'id_str': '291831562',
#      'indices': [121, 135]}],
#    'urls': [{'url': 'https://t.co/VmgZeOEw9j',
#      'expanded_url': 'https://www.ft.com/content/e082b01d-fbd6-4ea5-a0d2-05bc5ad7176c',
#      'display_url': 'ft.com/content/e082b0…',
#      'indices': [37, 60]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 841437061,
#    'id_str': '841437061',
#    'name': 'AI',
#    'screen_name': 'DeepLearn007',
#    'location': '',
#    'description': '#ArtificialIntelligence #MachineLearning #DeepLearning #fintech #Bigdata #Marketing #Robotics #IoT #DL #ML #tech #AI #HealthTech #Insurtech #5G Imtiaz Adam',
#    'url': 'https://t.co/qi3k7UZJRW',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/qi3k7UZJRW',
#        'expanded_url': 'https://www.linkedin.com/in/imtiaz-adam-7467528/',
#        'display_url': 'linkedin.com/in/imtiaz-adam…',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 126598,
#    'friends_count': 118959,
#    'listed_count': 3910,
#    'created_at': 'Sun Sep 23 10:12:53 +0000 2012',
#    'favourites_count': 48335,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 32218,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/748695622140719104/6j_LVovF_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/748695622140719104/6j_LVovF_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/841437061/1473979951',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Oct 21 13:52:41 +0000 2020',
#    'id': 1318913099924209671,
#    'id_str': '1318913099924209671',
#    'text': 'The Impact of #AI\n\nhttps://t.co/VmgZeOEw9j\n\n@SpirosMargaris @Xbond49 @psb_dc @jblefevre60\n@nigewillson… https://t.co/8fuR55chgA',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'AI', 'indices': [14, 17]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'SpirosMargaris',
#       'name': 'Spiros Margaris',
#       'id': 2711212681,
#       'id_str': '2711212681',
#       'indices': [44, 59]},
#      {'screen_name': 'Xbond49',
#       'name': 'Xavier Gomez',
#       'id': 235684766,
#       'id_str': '235684766',
#       'indices': [60, 68]},
#      {'screen_name': 'psb_dc',
#       'name': 'Theo - 劉䂀曼',
#       'id': 2908107542,
#       'id_str': '2908107542',
#       'indices': [69, 76]},
#      {'screen_name': 'jblefevre60',
#       'name': 'Jean-Baptiste Lefevre',
#       'id': 4374719908,
#       'id_str': '4374719908',
#       'indices': [77, 89]},
#      {'screen_name': 'nigewillson',
#       'name': 'Nige Willson',
#       'id': 228040559,
#       'id_str': '228040559',
#       'indices': [90, 102]}],
#     'urls': [{'url': 'https://t.co/VmgZeOEw9j',
#       'expanded_url': 'https://www.ft.com/content/e082b01d-fbd6-4ea5-a0d2-05bc5ad7176c',
#       'display_url': 'ft.com/content/e082b0…',
#       'indices': [19, 42]},
#      {'url': 'https://t.co/8fuR55chgA',
#       'expanded_url': 'https://twitter.com/i/web/status/1318913099924209671',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [104, 127]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 841437061,
#     'id_str': '841437061',
#     'name': 'AI',
#     'screen_name': 'DeepLearn007',
#     'location': '',
#     'description': '#ArtificialIntelligence #MachineLearning #DeepLearning #fintech #Bigdata #Marketing #Robotics #IoT #DL #ML #tech #AI #HealthTech #Insurtech #5G Imtiaz Adam',
#     'url': 'https://t.co/qi3k7UZJRW',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/qi3k7UZJRW',
#         'expanded_url': 'https://www.linkedin.com/in/imtiaz-adam-7467528/',
#         'display_url': 'linkedin.com/in/imtiaz-adam…',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 126598,
#     'friends_count': 118959,
#     'listed_count': 3910,
#     'created_at': 'Sun Sep 23 10:12:53 +0000 2012',
#     'favourites_count': 48335,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 32218,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/748695622140719104/6j_LVovF_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/748695622140719104/6j_LVovF_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/841437061/1473979951',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 85,
#    'favorite_count': 76,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 85,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:40:35 +0000 2020',
#   'id': 1319030848965005312,
#   'id_str': '1319030848965005312',
#   'text': 'RT @KirkDBorne: Get ahead at #ODSCWest with 80+ hands-on training sessions &amp; workshops on the #DataScience skills + tools you need to stay…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'ODSCWest', 'indices': [29, 38]},
#     {'text': 'DataScience', 'indices': [98, 110]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'KirkDBorne',
#      'name': 'Kirk Borne at #DSN2020Bootcamp',
#      'id': 534563976,
#      'id_str': '534563976',
#      'indices': [3, 14]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://iotdatafusion.com" rel="nofollow">Intelligent Edge Iot and AI Bot</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1040351960757686274,
#    'id_str': '1040351960757686274',
#    'name': 'Intelligent Edge',
#    'screen_name': 'EdgeIotAi',
#    'location': 'Living On The Edge',
#    'description': 'The EDGE, where things happen... Follow us to keep up with the latest in Intelligent EDGE tech. Tweeting about EDGE #IoT & #AI',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 3563,
#    'friends_count': 5002,
#    'listed_count': 86,
#    'created_at': 'Thu Sep 13 21:30:11 +0000 2018',
#    'favourites_count': 116,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 74052,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1040573396398956544/BetojiRw_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1040573396398956544/BetojiRw_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1040351960757686274/1536926943',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
# ...
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'bot', 'indices': [31, 35]},
#     {'text': 'deepfake', 'indices': [70, 79]},
#     {'text': 'fintech', 'indices': [112, 120]},
#     {'text': 'AI', 'indices': [121, 124]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'SpirosMargaris',
#      'name': 'Spiros Margaris',
#      'id': 2711212681,
#      'id_str': '2711212681',
#      'indices': [3, 18]}],
#    'urls': [{'url': 'https://t.co/v0FxULYKXJ',
#      'expanded_url': 'https://buff.ly/31o1t9J',
#      'display_url': 'buff.ly/31o1t9J',
#      'indices': [88, 111]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://abdirahiimyassin.weebly.com" rel="nofollow">Cyber Security Feed</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1131854274223366144,
#    'id_str': '1131854274223366144',
#    'name': 'Cyber Security Feed',
#    'screen_name': 'cybersec_feeds',
#    'location': 'Internet',
#    'description': 'Cyber Security News in 1 place!  Retweets original Cyber Sec tweets. 🤖 made by @AbdirahiimYa',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 11665,
#    'friends_count': 0,
#    'listed_count': 216,
#    'created_at': 'Fri May 24 09:27:42 +0000 2019',
#    'favourites_count': 0,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 1129417,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1131855016766124032/vhasETOF_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1131855016766124032/vhasETOF_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1131854274223366144/1558718830',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Oct 21 04:33:51 +0000 2020',
#    'id': 1318772462478393344,
#    'id_str': '1318772462478393344',
#    'text': 'A Telegram #bot network \n\nis being used to create #deepfake nudes \n\nhttps://t.co/v0FxULYKXJ #fintech #AI… https://t.co/cjHdIRQdHZ',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'bot', 'indices': [11, 15]},
#      {'text': 'deepfake', 'indices': [50, 59]},
#      {'text': 'fintech', 'indices': [92, 100]},
#      {'text': 'AI', 'indices': [101, 104]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/v0FxULYKXJ',
#       'expanded_url': 'https://buff.ly/31o1t9J',
#       'display_url': 'buff.ly/31o1t9J',
#       'indices': [68, 91]},
#      {'url': 'https://t.co/cjHdIRQdHZ',
#       'expanded_url': 'https://twitter.com/i/web/status/1318772462478393344',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [106, 129]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2711212681,
#     'id_str': '2711212681',
#     'name': 'Spiros Margaris',
#     'screen_name': 'SpirosMargaris',
#     'location': 'All Over the World',
#     'description': '#VC #Futurist | @wefoxHQ @SparkLabsGlobal @ai_mediastalker @canopyrent @stcpay_ksa @F10_accelerator | No.1 #Fintech Influencer @Onalytica #AI | @TEDx',
#     'url': 'https://t.co/PeTBLwijX6',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/PeTBLwijX6',
#         'expanded_url': 'http://www.MargarisVentures.com',
#         'display_url': 'MargarisVentures.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 103738,
#     'friends_count': 15055,
#     'listed_count': 5597,
#     'created_at': 'Wed Aug 06 05:20:16 +0000 2014',
#     'favourites_count': 175034,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 202478,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '3B94D9',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1080518156932825089/Elhx7SXw_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1080518156932825089/Elhx7SXw_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2711212681/1597474916',
#     'profile_link_color': '1C2841',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 7,
#    'favorite_count': 9,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 7,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:08:04 +0000 2020',
#   'id': 1319022666087604229,
#   'id_str': '1319022666087604229',
#   'text': 'RT @dcode7_india: dCODE7 brings some Interesting Stats for AI geeks!!!\n\nFollow: @dcode7_india \n\n#artificialintelligence #ai #machinelearnin…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'artificialintelligence',
#      'indices': [96, 119]},
#     {'text': 'ai', 'indices': [120, 123]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'dcode7_india',
#      'name': 'dCODE7 Technologies',
#      'id': 1244196704896741377,
#      'id_str': '1244196704896741377',
#      'indices': [3, 16]},
#     {'screen_name': 'dcode7_india',
#      'name': 'dCODE7 Technologies',
#      'id': 1244196704896741377,
#      'id_str': '1244196704896741377',
#      'indices': [80, 93]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1310836644946145286,
#    'id_str': '1310836644946145286',
#    'name': 'the404code',
#    'screen_name': 'the404code',
#    'location': '',
#    'description': "I'm a bot. Follow me to get updates on the latest tech blogs and tech trends #the404code | Creator: @nitinmanocha16",
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 387,
#    'friends_count': 3,
#    'listed_count': 6,
#    'created_at': 'Tue Sep 29 06:59:57 +0000 2020',
#    'favourites_count': 42,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 19833,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1310838008774447104/A6Pfuo2F_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1310838008774447104/A6Pfuo2F_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1310836644946145286/1601488121',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Oct 21 19:59:14 +0000 2020',
#    'id': 1319005342177488916,
#    'id_str': '1319005342177488916',
#    'text': 'dCODE7 brings some Interesting Stats for AI geeks!!!\n\nFollow: @dcode7_india \n\n#artificialintelligence #ai… https://t.co/sundyVW1a8',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'artificialintelligence',
#       'indices': [78, 101]},
#      {'text': 'ai', 'indices': [102, 105]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'dcode7_india',
#       'name': 'dCODE7 Technologies',
#       'id': 1244196704896741377,
#       'id_str': '1244196704896741377',
#       'indices': [62, 75]}],
#     'urls': [{'url': 'https://t.co/sundyVW1a8',
#       'expanded_url': 'https://twitter.com/i/web/status/1319005342177488916',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [107, 130]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1244196704896741377,
#     'id_str': '1244196704896741377',
#     'name': 'dCODE7 Technologies',
#     'screen_name': 'dcode7_india',
#     'location': 'New Delhi, India. ',
#     'description': 'We are the one point solutions for all your Tech Need. #dCODE7 #WeCodeYourThoughts',
#     'url': 'https://t.co/yMSvG0YCcN',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/yMSvG0YCcN',
#         'expanded_url': 'https://dcode7.com',
#         'display_url': 'dcode7.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 18,
#     'friends_count': 59,
#     'listed_count': 0,
#     'created_at': 'Sun Mar 29 09:36:36 +0000 2020',
#     'favourites_count': 99,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 127,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1252690598328520716/S9lcnqsP_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1252690598328520716/S9lcnqsP_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1244196704896741377/1592800817',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 2,
#    'favorite_count': 2,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 2,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Oct 21 21:06:14 +0000 2020',
#   'id': 1319022202642141188,
#   'id_str': '1319022202642141188',
#   'text': '10 RNN Open Source Projects You Must Try Your Hands On #DeepLearning #learning via https://t.co/5ybGJIqadf https://t.co/szezK5q9GU',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'DeepLearning', 'indices': [55, 68]},
#     {'text': 'learning', 'indices': [69, 78]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/5ybGJIqadf',
#      'expanded_url': 'http://twinybots.ch',
#      'display_url': 'twinybots.ch',
#      'indices': [83, 106]},
#     {'url': 'https://t.co/szezK5q9GU',
#      'expanded_url': 'https://analyticsindiamag.com/10-rnn-open-source-projects-you-must-try-your-hands-on/',
#      'display_url': 'analyticsindiamag.com/10-rnn-open-so…',
#      'indices': [107, 130]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twinybots.com" rel="nofollow">TwinyBots</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 264727554,
#    'id_str': '264727554',
#    'name': 'Ismail Aiman Hassan',
#    'screen_name': 'ismailaiman',
#    'location': 'Maldives',
#    'description': 'idea generator; consultant @aivisolutions enabling you business to be online',
#    'url': 'https://t.co/gQHqvvOYCf',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/gQHqvvOYCf',
#        'expanded_url': 'http://www.aivisolutions.com',
#        'display_url': 'aivisolutions.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 586,
#    'friends_count': 1216,
#    'listed_count': 13,
#    'created_at': 'Sat Mar 12 10:51:14 +0000 2011',
#    'favourites_count': 2247,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 8080,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1303931743406182402/LqjetOMQ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1303931743406182402/LqjetOMQ_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/264727554/1545848016',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': True,
#   'lang': 'en'}]

# %% [markdown]
# ## Section 3: Searching Users

# %% [markdown]
# The last section of the API you'll need to get the hang of before you're let loose is the users API, which allows you to search for users and get their followers, friends, etc, as opposed to tweets which fit a particular criteria.  This part is pretty similar to the advanced lab in class 3, so if you saw how that worked then you shouldn't need much instruction.
#
# But if you're seeing this with fresh eyes, you'll want to spend 15-20 minutes to make sure you understand this part.
#
# Official documentation can be found here:  https://developer.twitter.com/en/docs/accounts-and-users/follow-search-get-users/overview
#
# So, as an example, if you want to get a list of someone's followers, you use the base url `https://api.twitter.com/1.1/followers/list.json` and then enter your query string to get a list of that persons followers.
#
# List of parameters to use can be found here:  https://developer.twitter.com/en/docs/accounts-and-users/follow-search-get-users/api-reference
#
# One possible parameter to use is `screen_name`, so if you wanted to get a list of someone's followers based on their screen name (the handle that begins with an @), then you would set up your API call to look something like:
#
# `https://api.twitter.com/1.1/followers/list.json?screen_name=persons_screenname`
#
# Note that you exclude the `@`.
#
# **Your turn:** Pull in the list of General Assembly's followers.  General Assembly's handle is `@GA`  The `users` key will contain the list of followers for General Assembly's account.
#
# Note that this won't return the whole list of GA's users.  If you want to do that you have to use cursoring:  https://developer.twitter.com/en/docs/basics/cursoring.  This is the topic of your bonus assignment.

# %%
# your answer here
base_url     = 'https://api.twitter.com/1.1/followers/list.json'
query_string = '?screen_name=GA'

results = requests.get(base_url + query_string, auth=tokens).json()

# %%
# and our results
results['users']
# Out:
# [{'id': 3022159025,
#   'id_str': '3022159025',
#   'name': 'Quwanie Gordon',
#   'screen_name': 'QuwanieGordon',
#   'location': 'Central London ',
#   'description': 'Founder of @cleaninggouk',
#   'url': 'https://t.co/g5b6fXXBqe',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/g5b6fXXBqe',
#       'expanded_url': 'https://cleaninggo.co.uk/',
#       'display_url': 'cleaninggo.co.uk',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 387,
#   'friends_count': 1737,
#   'listed_count': 5,
#   'created_at': 'Fri Feb 06 20:47:46 +0000 2015',
#   'favourites_count': 174,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': False,
#   'statuses_count': 26,
#   'lang': None,
#   'status': {'created_at': 'Sun Oct 11 09:54:27 +0000 2020',
#    'id': 1315229266137686017,
#    'id_str': '1315229266137686017',
#    'text': '@iamtomskinner Congratulations fella.',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'iamtomskinner',
#       'name': 'Thomas Skinner ⚒',
#       'id': 1079425544998080512,
#       'id_str': '1079425544998080512',
#       'indices': [0, 14]}],
#     'urls': []},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1314867210293252096,
#    'in_reply_to_status_id_str': '1314867210293252096',
#    'in_reply_to_user_id': 1079425544998080512,
#    'in_reply_to_user_id_str': '1079425544998080512',
#    'in_reply_to_screen_name': 'iamtomskinner',
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'ABB8C2',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1304534327443755013/GAp2YCbq_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1304534327443755013/GAp2YCbq_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3022159025/1600885449',
#   'profile_link_color': '996515',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': '000000',
#   'profile_text_color': '000000',
#   'profile_use_background_image': False,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 19305095,
#   'id_str': '19305095',
#   'name': 'David Knudson',
#   'screen_name': 'djknudson',
#   'location': 'Los Angeles, CA',
#   'description': '',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 7,
#   'friends_count': 28,
#   'listed_count': 0,
#   'created_at': 'Wed Jan 21 20:15:25 +0000 2009',
#   'favourites_count': 1,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': False,
#   'statuses_count': 0,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1237089204275834881/MB-vsELa_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1237089204275834881/MB-vsELa_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/19305095/1573782596',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 21494928,
#   'id_str': '21494928',
#   'name': 'Lesley S.',
#   'screen_name': 'msgigglez',
#   'location': 'Wichita, KS',
#   'description': 'Faith | Family | Farmer | Foodie | Fitness \n#50states 31/50',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': True,
#   'followers_count': 1591,
#   'friends_count': 2210,
#   'listed_count': 47,
#   'created_at': 'Sat Feb 21 16:04:29 +0000 2009',
#   'favourites_count': 1245,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': False,
#   'statuses_count': 1255,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'ACDED6',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/570117456020295681/PaABZ4U5_normal.jpeg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/570117456020295681/PaABZ4U5_normal.jpeg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/21494928/1492451148',
#   'profile_link_color': '038543',
#   'profile_sidebar_border_color': 'EEEEEE',
#   'profile_sidebar_fill_color': 'F6F6F6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 811209762360664064,
#   'id_str': '811209762360664064',
#   'name': 'Eppik',
#   'screen_name': 'eppikstories',
#   'location': 'London',
#   'description': 'We digitise old photo albums to preserve your family stories and love anything retro, classic, antique, historic or vintage that creates memories. #Genealogy',
#   'url': 'https://t.co/HlChdROo7Q',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/HlChdROo7Q',
#       'expanded_url': 'http://www.eppik.com',
#       'display_url': 'eppik.com',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 1097,
#   'friends_count': 4650,
#   'listed_count': 8,
#   'created_at': 'Tue Dec 20 14:00:53 +0000 2016',
#   'favourites_count': 1658,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': False,
#   'statuses_count': 2844,
#   'lang': None,
#   'status': {'created_at': 'Wed Oct 21 16:58:57 +0000 2020',
#    'id': 1318959972550660096,
#    'id_str': '1318959972550660096',
#    'text': "📸 We're working with @GA to help improve the user experience of our platform. We'd love to know how people interact… https://t.co/GpHv4L3Qmu",
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'GA',
#       'name': 'General Assembly',
#       'id': 170393291,
#       'id_str': '170393291',
#       'indices': [21, 24]}],
#     'urls': [{'url': 'https://t.co/GpHv4L3Qmu',
#       'expanded_url': 'https://twitter.com/i/web/status/1318959972550660096',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/910817808036061185/Zu5Ky2js_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/910817808036061185/Zu5Ky2js_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/811209762360664064/1488134304',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 1004550385,
#   'id_str': '1004550385',
#   'name': 'Quest Engineering Solutions',
#   'screen_name': 'QESEngineering',
#   'location': 'Billerica, MA',
#   'description': 'Quest Engineering Solutions is an engineering testing services company ⚙️\nYour test is our Quest!',
#   'url': 'https://t.co/GYEnK4jRXh',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/GYEnK4jRXh',
#       'expanded_url': 'http://www.qes.com',
#       'display_url': 'qes.com',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 15,
#   'friends_count': 139,
#   'listed_count': 0,
#   'created_at': 'Tue Dec 11 17:56:45 +0000 2012',
#   'favourites_count': 0,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 22,
#   'lang': None,
#   'status': {'created_at': 'Tue Oct 20 14:12:13 +0000 2020',
#    'id': 1318555625694109696,
#    'id_str': '1318555625694109696',
#    'text': 'Own a small business? Want to make sure your packages get where they need to go without damaging your product? Ques… https://t.co/ciN927CaG3',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/ciN927CaG3',
#       'expanded_url': 'https://twitter.com/i/web/status/1318555625694109696',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'FFFFFF',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1314556289276686337/74c9ytcL_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1314556289276686337/74c9ytcL_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1004550385/1603133816',
#   'profile_link_color': '60BC51',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 1270031935222370304,
#   'id_str': '1270031935222370304',
#   'name': 'Srikanth',
#   'screen_name': 'Srikant65202945',
#   'location': '',
#   'description': 'proud to be Electrical Enginnering',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 5,
#   'friends_count': 170,
#   'listed_count': 0,
#   'created_at': 'Mon Jun 08 16:37:30 +0000 2020',
#   'favourites_count': 38,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 0,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1270032314790064128/bLUdUpZo_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1270032314790064128/bLUdUpZo_normal.jpg',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 1293137217519591425,
#   'id_str': '1293137217519591425',
#   'name': 'TUSIIME CHRISTBELL',
#   'screen_name': 'TUSIIMECHRISTB1',
#   'location': 'Uganda',
#   'description': 'Works @ FOCUS OF GOD TV -Uganda \n@ https://t.co/3HrWmbU69V\nWorks @Sanlam General and Life Insurance-Uganda',
#   'url': 'https://t.co/RNQQmf5nti',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/RNQQmf5nti',
#       'expanded_url': 'http://www.focusofGod.com',
#       'display_url': 'focusofGod.com',
#       'indices': [0, 23]}]},
#    'description': {'urls': [{'url': 'https://t.co/3HrWmbU69V',
#       'expanded_url': 'http://focusofGod.com',
#       'display_url': 'focusofGod.com',
#       'indices': [35, 58]}]}},
#   'protected': False,
#   'followers_count': 492,
#   'friends_count': 1998,
#   'listed_count': 1,
#   'created_at': 'Tue Aug 11 10:48:54 +0000 2020',
#   'favourites_count': 743,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 270,
#   'lang': None,
#   'status': {'created_at': 'Wed Oct 21 10:23:42 +0000 2020',
#    'id': 1318860505218416642,
#    'id_str': '1318860505218416642',
#    'text': 'RT @burnaboy: #EndSARS #EndPoliceBrutalityinNigeraNOW #EndBadGoveranceInNigeria #EndPoliceBrutality #EndSARSImmediately \n\nStop the Killing…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'EndSARS', 'indices': [14, 22]},
#      {'text': 'EndPoliceBrutalityinNigeraNOW', 'indices': [23, 53]},
#      {'text': 'EndBadGoveranceInNigeria', 'indices': [54, 79]},
#      {'text': 'EndPoliceBrutality', 'indices': [80, 99]},
#      {'text': 'EndSARSImmediately', 'indices': [100, 119]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'burnaboy',
#       'name': 'Burna Boy',
#       'id': 215052012,
#       'id_str': '215052012',
#       'indices': [3, 12]}],
#     'urls': []},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 09:19:03 +0000 2020',
#     'id': 1318844237228724224,
#     'id_str': '1318844237228724224',
#     'text': '#EndSARS #EndPoliceBrutalityinNigeraNOW #EndBadGoveranceInNigeria #EndPoliceBrutality #EndSARSImmediately \n\nStop th… https://t.co/4fxaEzmWUg',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'EndSARS', 'indices': [0, 8]},
#       {'text': 'EndPoliceBrutalityinNigeraNOW', 'indices': [9, 39]},
#       {'text': 'EndBadGoveranceInNigeria', 'indices': [40, 65]},
#       {'text': 'EndPoliceBrutality', 'indices': [66, 85]},
#       {'text': 'EndSARSImmediately', 'indices': [86, 105]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/4fxaEzmWUg',
#        'expanded_url': 'https://twitter.com/i/web/status/1318844237228724224',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 17177,
#     'favorite_count': 18171,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 17177,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1296448361629876226/eKAtNegK_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1296448361629876226/eKAtNegK_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1293137217519591425/1597514518',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 1154022058180980736,
#   'id_str': '1154022058180980736',
#   'name': 'iamsamhacker',
#   'screen_name': 'iamsamhacker',
#   'location': '',
#   'description': 'account tracking my milestones as i learn to code 💻 | INFJ 🔮 | ♋️ | PHL based',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 67,
#   'friends_count': 222,
#   'listed_count': 0,
#   'created_at': 'Wed Jul 24 13:34:34 +0000 2019',
#   'favourites_count': 110,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 51,
#   'lang': None,
#   'status': {'created_at': 'Wed Oct 21 17:45:16 +0000 2020',
#    'id': 1318971627904839681,
#    'id_str': '1318971627904839681',
#    'text': '@JavaScriptCoff1 congrats 🥳',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'JavaScriptCoff1',
#       'name': 'JavaScript➕Coffee🚀',
#       'id': 1276598296350507010,
#       'id_str': '1276598296350507010',
#       'indices': [0, 16]}],
#     'urls': []},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1318971309985026048,
#    'in_reply_to_status_id_str': '1318971309985026048',
#    'in_reply_to_user_id': 1276598296350507010,
#    'in_reply_to_user_id_str': '1276598296350507010',
#    'in_reply_to_screen_name': 'JavaScriptCoff1',
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1154173379387244544/jD8gtBvw_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1154173379387244544/jD8gtBvw_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1154022058180980736/1563975965',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 1310985472194285571,
#   'id_str': '1310985472194285571',
#   'name': 'joshua d chapel',
#   'screen_name': 'chapel_joshua',
#   'location': '',
#   'description': "I'm new discovered",
#   'url': 'https://t.co/WAoNws2PMt',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/WAoNws2PMt',
#       'expanded_url': 'http://chapeljoshua.me',
#       'display_url': 'chapeljoshua.me',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 1,
#   'friends_count': 74,
#   'listed_count': 0,
#   'created_at': 'Tue Sep 29 16:51:25 +0000 2020',
#   'favourites_count': 3,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 3,
#   'lang': None,
#   'status': {'created_at': 'Sat Oct 03 02:40:58 +0000 2020',
#    'id': 1312221074881478661,
#    'id_str': '1312221074881478661',
#    'text': 'RT @emily_ladau: So, uh, my last name is spelled L-A-D-A-U. (Pronounced luh-dow.) Not Landau. Not Ladeu. And absolutely, positively NOT Lan…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'emily_ladau',
#       'name': 'Emily Ladau',
#       'id': 1512366384,
#       'id_str': '1512366384',
#       'indices': [3, 15]}],
#     'urls': []},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Oct 01 04:08:56 +0000 2020',
#     'id': 1311518435533348869,
#     'id_str': '1311518435533348869',
#     'text': 'So, uh, my last name is spelled L-A-D-A-U. (Pronounced luh-dow.) Not Landau. Not Ladeu. And absolutely, positively… https://t.co/jSQlcXyGiI',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/jSQlcXyGiI',
#        'expanded_url': 'https://twitter.com/i/web/status/1311518435533348869',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 2,
#     'favorite_count': 30,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 2,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1310985745327366147/xaa9txwa_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1310985745327366147/xaa9txwa_normal.jpg',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 2306173036,
#   'id_str': '2306173036',
#   'name': '.',
#   'screen_name': 'jarrell_idk',
#   'location': '',
#   'description': 'Sc: Jarrell_idk',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 160,
#   'friends_count': 117,
#   'listed_count': 1,
#   'created_at': 'Sun Jan 26 18:22:46 +0000 2014',
#   'favourites_count': 4570,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': False,
#   'statuses_count': 4512,
#   'lang': None,
#   'status': {'created_at': 'Wed Oct 21 07:15:16 +0000 2020',
#    'id': 1318813084702679040,
#    'id_str': '1318813084702679040',
#    'text': 'RT @opstandige: when this happened to a white barista y’all gave him one hundred thousand dollars',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'opstandige',
#       'name': 'african proverb (they/them)',
#       'id': 1914661098,
#       'id_str': '1914661098',
#       'indices': [3, 14]}],
#     'urls': []},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Mon Oct 19 23:11:59 +0000 2020',
#     'id': 1318329073077276676,
#     'id_str': '1318329073077276676',
#     'text': 'when this happened to a white barista y’all gave him one hundred thousand dollars https://t.co/nFcd5txCM6',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/nFcd5txCM6',
#        'expanded_url': 'https://twitter.com/balleralert/status/1318048933495570433',
#        'display_url': 'twitter.com/balleralert/st…',
#        'indices': [82, 105]}]},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': True,
#     'quoted_status_id': 1318048933495570433,
#     'quoted_status_id_str': '1318048933495570433',
#     'retweet_count': 84115,
#     'favorite_count': 276616,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': True,
#    'quoted_status_id': 1318048933495570433,
#    'quoted_status_id_str': '1318048933495570433',
#    'retweet_count': 84115,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'FFFFFF',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1183854976256434177/alC5oytQ_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1183854976256434177/alC5oytQ_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2306173036/1445734043',
#   'profile_link_color': '444B4D',
#   'profile_sidebar_border_color': 'FFFFFF',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 1306600464474157058,
#   'id_str': '1306600464474157058',
#   'name': 'NEM Support',
#   'screen_name': 'NemSupport',
#   'location': '',
#   'description': '',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 0,
#   'friends_count': 79,
#   'listed_count': 0,
#   'created_at': 'Thu Sep 17 14:27:07 +0000 2020',
#   'favourites_count': 171,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 0,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1314211760111460352/J1B31GUF_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1314211760111460352/J1B31GUF_normal.jpg',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 935113027631824896,
#   'id_str': '935113027631824896',
#   'name': 'Further 🇦🇺',
#   'screen_name': 'further_global',
#   'location': 'Melbourne, Victoria',
#   'description': 'Detailed jobs in Australia 🇦🇺 \nCareer information across the Globe 🌏',
#   'url': 'https://t.co/m30VdoSuV5',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/m30VdoSuV5',
#       'expanded_url': 'https://further.global',
#       'display_url': 'further.global',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 34,
#   'friends_count': 26,
#   'listed_count': 0,
#   'created_at': 'Mon Nov 27 11:48:14 +0000 2017',
#   'favourites_count': 11,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 163,
#   'lang': None,
#   'status': {'created_at': 'Wed Oct 21 02:18:05 +0000 2020',
#    'id': 1318738296273395712,
#    'id_str': '1318738296273395712',
#    'text': "#Listen to Further's founder @brandonrdesign as he talks about Further, his discovery of #uxdesign, his designing p… https://t.co/KsiYU7zDG1",
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'Listen', 'indices': [0, 7]},
#      {'text': 'uxdesign', 'indices': [89, 98]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'brandonrdesign',
#       'name': 'Brandon Reynolds',
#       'id': 1216848077635510272,
#       'id_str': '1216848077635510272',
#       'indices': [29, 44]}],
#     'urls': [{'url': 'https://t.co/KsiYU7zDG1',
#       'expanded_url': 'https://twitter.com/i/web/status/1318738296273395712',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1311584791729299456/5NzAxPC4_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1311584791729299456/5NzAxPC4_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/935113027631824896/1601539247',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 1318731086508195843,
#   'id_str': '1318731086508195843',
#   'name': 'Jasmin Alvarez',
#   'screen_name': 'JasminA87599169',
#   'location': '',
#   'description': 'ATL | GA',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 0,
#   'friends_count': 25,
#   'listed_count': 0,
#   'created_at': 'Wed Oct 21 01:49:37 +0000 2020',
#   'favourites_count': 1,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 1,
#   'lang': None,
#   'status': {'created_at': 'Wed Oct 21 01:58:24 +0000 2020',
#    'id': 1318733343811252224,
#    'id_str': '1318733343811252224',
#    'text': 'RT @Techqueria: 📺   VIRTUAL SCREENING 📺⠀\nTickets for the screening of #DearHomeland are now available!\n\nJoin Techqueria &amp; @oscmart for an e…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'DearHomeland', 'indices': [70, 83]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Techqueria',
#       'name': 'Techqueria',
#       'id': 709095892125491201,
#       'id_str': '709095892125491201',
#       'indices': [3, 14]},
#      {'screen_name': 'oscmart',
#       'name': 'Oscar 🐻🥌📷🚀👁🏳️\u200d🌈🇺🇸🇲🇽',
#       'id': 15393986,
#       'id_str': '15393986',
#       'indices': [126, 134]}],
#     'urls': []},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 01:30:13 +0000 2020',
#     'id': 1318726250605760512,
#     'id_str': '1318726250605760512',
#     'text': '📺   VIRTUAL SCREENING 📺⠀\nTickets for the screening of #DearHomeland are now available!\n\nJoin Techqueria &amp; @oscmart… https://t.co/f2it7sl4RV',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'DearHomeland', 'indices': [54, 67]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'oscmart',
#        'name': 'Oscar 🐻🥌📷🚀👁🏳️\u200d🌈🇺🇸🇲🇽',
#        'id': 15393986,
#        'id_str': '15393986',
#        'indices': [110, 118]}],
#      'urls': [{'url': 'https://t.co/f2it7sl4RV',
#        'expanded_url': 'https://twitter.com/i/web/status/1318726250605760512',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [120, 143]}]},
#     'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1318731210630320128/1VkV5SzH_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1318731210630320128/1VkV5SzH_normal.jpg',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 1311168822997643266,
#   'id_str': '1311168822997643266',
#   'name': 'Nick Dyer',
#   'screen_name': 'RealNickDyer',
#   'location': '',
#   'description': '',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 58,
#   'friends_count': 785,
#   'listed_count': 0,
#   'created_at': 'Wed Sep 30 04:59:50 +0000 2020',
#   'favourites_count': 0,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 0,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1318214783276122115/tjw0bQ3u_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1318214783276122115/tjw0bQ3u_normal.jpg',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 1296575851618684928,
#   'id_str': '1296575851618684928',
#   'name': 'Pramit Majumder',
#   'screen_name': 'MajumderPramit',
#   'location': '',
#   'description': '',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 39,
#   'friends_count': 1464,
#   'listed_count': 0,
#   'created_at': 'Thu Aug 20 22:33:07 +0000 2020',
#   'favourites_count': 0,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 0,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#   'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': True,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 1261062030750027781,
#   'id_str': '1261062030750027781',
#   'name': 'melisa 🌱',
#   'screen_name': 'melisaglser',
#   'location': 'she/her',
#   'description': 'ux design • ucsd ‘20',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 19,
#   'friends_count': 52,
#   'listed_count': 0,
#   'created_at': 'Thu May 14 22:33:19 +0000 2020',
#   'favourites_count': 204,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 19,
#   'lang': None,
#   'status': {'created_at': 'Fri Oct 16 12:07:39 +0000 2020',
#    'id': 1317074727375196161,
#    'id_str': '1317074727375196161',
#    'text': 'RT @iamfabiano: Good things happen to those who wait 💚 https://t.co/IoTfF6aF6e',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'iamfabiano',
#       'name': 'Fabiano Souza',
#       'id': 4704897748,
#       'id_str': '4704897748',
#       'indices': [3, 14]}],
#     'urls': [],
#     'media': [{'id': 1316501710899159041,
#       'id_str': '1316501710899159041',
#       'indices': [55, 78],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1316501710899159041/pu/img/n87DOBwaoZJUZ7M7.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1316501710899159041/pu/img/n87DOBwaoZJUZ7M7.jpg',
#       'url': 'https://t.co/IoTfF6aF6e',
#       'display_url': 'pic.twitter.com/IoTfF6aF6e',
#       'expanded_url': 'https://twitter.com/iamfabiano/status/1316501734135562241/video/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 315, 'h': 680, 'resize': 'fit'},
#        'medium': {'w': 555, 'h': 1200, 'resize': 'fit'},
#        'large': {'w': 592, 'h': 1280, 'resize': 'fit'}},
#       'source_status_id': 1316501734135562241,
#       'source_status_id_str': '1316501734135562241',
#       'source_user_id': 4704897748,
#       'source_user_id_str': '4704897748'}]},
#    'extended_entities': {'media': [{'id': 1316501710899159041,
#       'id_str': '1316501710899159041',
#       'indices': [55, 78],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1316501710899159041/pu/img/n87DOBwaoZJUZ7M7.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1316501710899159041/pu/img/n87DOBwaoZJUZ7M7.jpg',
#       'url': 'https://t.co/IoTfF6aF6e',
#       'display_url': 'pic.twitter.com/IoTfF6aF6e',
#       'expanded_url': 'https://twitter.com/iamfabiano/status/1316501734135562241/video/1',
#       'type': 'video',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 315, 'h': 680, 'resize': 'fit'},
#        'medium': {'w': 555, 'h': 1200, 'resize': 'fit'},
#        'large': {'w': 592, 'h': 1280, 'resize': 'fit'}},
#       'source_status_id': 1316501734135562241,
#       'source_status_id_str': '1316501734135562241',
#       'source_user_id': 4704897748,
#       'source_user_id_str': '4704897748',
#       'video_info': {'aspect_ratio': [37, 80],
#        'duration_millis': 5895,
#        'variants': [{'bitrate': 2176000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1316501710899159041/pu/vid/592x1280/FW98MmHGkDWRI9cf.mp4?tag=10'},
#         {'bitrate': 832000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1316501710899159041/pu/vid/360x778/h3IqJuxyK0s5GGJK.mp4?tag=10'},
#         {'bitrate': 632000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1316501710899159041/pu/vid/320x690/LnIEIt1GCMNC-8dg.mp4?tag=10'},
#         {'content_type': 'application/x-mpegURL',
#          'url': 'https://video.twimg.com/ext_tw_video/1316501710899159041/pu/pl/CAbPIqmpaIdRDt_I.m3u8?tag=10'}]},
#       'additional_media_info': {'monetizable': False}}]},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 14 22:10:47 +0000 2020',
#     'id': 1316501734135562241,
#     'id_str': '1316501734135562241',
#     'text': 'Good things happen to those who wait 💚 https://t.co/IoTfF6aF6e',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [],
#      'media': [{'id': 1316501710899159041,
#        'id_str': '1316501710899159041',
#        'indices': [39, 62],
#        'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1316501710899159041/pu/img/n87DOBwaoZJUZ7M7.jpg',
#        'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1316501710899159041/pu/img/n87DOBwaoZJUZ7M7.jpg',
#        'url': 'https://t.co/IoTfF6aF6e',
#        'display_url': 'pic.twitter.com/IoTfF6aF6e',
#        'expanded_url': 'https://twitter.com/iamfabiano/status/1316501734135562241/video/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 315, 'h': 680, 'resize': 'fit'},
#         'medium': {'w': 555, 'h': 1200, 'resize': 'fit'},
#         'large': {'w': 592, 'h': 1280, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1316501710899159041,
#        'id_str': '1316501710899159041',
#        'indices': [39, 62],
#        'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1316501710899159041/pu/img/n87DOBwaoZJUZ7M7.jpg',
#        'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1316501710899159041/pu/img/n87DOBwaoZJUZ7M7.jpg',
#        'url': 'https://t.co/IoTfF6aF6e',
#        'display_url': 'pic.twitter.com/IoTfF6aF6e',
#        'expanded_url': 'https://twitter.com/iamfabiano/status/1316501734135562241/video/1',
#        'type': 'video',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 315, 'h': 680, 'resize': 'fit'},
#         'medium': {'w': 555, 'h': 1200, 'resize': 'fit'},
#         'large': {'w': 592, 'h': 1280, 'resize': 'fit'}},
#        'video_info': {'aspect_ratio': [37, 80],
#         'duration_millis': 5895,
#         'variants': [{'bitrate': 2176000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/1316501710899159041/pu/vid/592x1280/FW98MmHGkDWRI9cf.mp4?tag=10'},
#          {'bitrate': 832000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/1316501710899159041/pu/vid/360x778/h3IqJuxyK0s5GGJK.mp4?tag=10'},
#          {'bitrate': 632000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/1316501710899159041/pu/vid/320x690/LnIEIt1GCMNC-8dg.mp4?tag=10'},
#          {'content_type': 'application/x-mpegURL',
#           'url': 'https://video.twimg.com/ext_tw_video/1316501710899159041/pu/pl/CAbPIqmpaIdRDt_I.m3u8?tag=10'}]},
#        'additional_media_info': {'monetizable': False}}]},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': {'id': 'd56c5babcffde8ef',
#      'url': 'https://api.twitter.com/1.1/geo/id/d56c5babcffde8ef.json',
#      'place_type': 'city',
#      'name': 'Stockholm',
#      'full_name': 'Stockholm, Sweden',
#      'country_code': 'SE',
#      'country': 'Sweden',
#      'contained_within': [],
#      'bounding_box': {'type': 'Polygon',
#       'coordinates': [[[17.7601322, 59.2271383],
#         [18.1999856, 59.2271383],
#         [18.1999856, 59.4402037],
#         [17.7601322, 59.4402037]]]},
#      'attributes': {}},
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 43,
#     'favorite_count': 552,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 43,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1262100976531628035/qyD4mob8_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1262100976531628035/qyD4mob8_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1261062030750027781/1589743156',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 33701614,
#   'id_str': '33701614',
#   'name': 'Susie Vernalis',
#   'screen_name': 'smvernalis',
#   'location': 'Washington, DC',
#   'description': "You can take the girl out of Philly, but you can't take the Philly out of the girl.",
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 687,
#   'friends_count': 4455,
#   'listed_count': 22,
#   'created_at': 'Mon Apr 20 22:54:42 +0000 2009',
#   'favourites_count': 3650,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 6178,
#   'lang': None,
#   'status': {'created_at': 'Fri Oct 16 17:42:37 +0000 2020',
#    'id': 1317159024534708224,
#    'id_str': '1317159024534708224',
#    'text': "@Eugene_Scott Same advice Burr gave to Hamilton. Didn't work that time, either.",
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Eugene_Scott',
#       'name': 'Eugene Scott',
#       'id': 315331161,
#       'id_str': '315331161',
#       'indices': [0, 13]}],
#     'urls': []},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': 1317158653942706183,
#    'in_reply_to_status_id_str': '1317158653942706183',
#    'in_reply_to_user_id': 315331161,
#    'in_reply_to_user_id_str': '315331161',
#    'in_reply_to_screen_name': 'Eugene_Scott',
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 3,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'FF6699',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme11/bg.gif',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme11/bg.gif',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/842200798310223872/cEe8vjMs_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/842200798310223872/cEe8vjMs_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/33701614/1404614261',
#   'profile_link_color': '1AB30D',
#   'profile_sidebar_border_color': 'FFFFFF',
#   'profile_sidebar_fill_color': 'C9C9C9',
#   'profile_text_color': '1C1F23',
#   'profile_use_background_image': False,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 31174581,
#   'id_str': '31174581',
#   'name': 'delara chowdhury',
#   'screen_name': 'delaracy',
#   'location': 'Canada',
#   'description': 'الحمد لله',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': True,
#   'followers_count': 110,
#   'friends_count': 111,
#   'listed_count': 1,
#   'created_at': 'Tue Apr 14 17:31:48 +0000 2009',
#   'favourites_count': 267,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 2329,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'A2B0A5',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme3/bg.gif',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme3/bg.gif',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1232361972915752961/iFmCcYuf_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1232361972915752961/iFmCcYuf_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/31174581/1501647710',
#   'profile_link_color': '327D6D',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': 'E3E2DE',
#   'profile_text_color': '626770',
#   'profile_use_background_image': False,
#   'has_extended_profile': True,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'regular'},
#  {'id': 1076159625337204737,
#   'id_str': '1076159625337204737',
#   'name': 'Lobster Coaching',
#   'screen_name': 'lobstercoaching',
#   'location': 'Europe',
#   'description': 'It’s out of our comfort zone where we have the chance to grow, develop and make a difference. #lobstercoaching #learnevolveachieve @theocmgroup @theaoec',
#   'url': 'https://t.co/THMQisl57l',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/THMQisl57l',
#       'expanded_url': 'https://www.lobstercoaching.com',
#       'display_url': 'lobstercoaching.com',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 52,
#   'friends_count': 166,
#   'listed_count': 0,
#   'created_at': 'Fri Dec 21 16:57:03 +0000 2018',
#   'favourites_count': 378,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 186,
#   'lang': None,
#   'status': {'created_at': 'Mon Oct 19 15:43:47 +0000 2020',
#    'id': 1318216280697163777,
#    'id_str': '1318216280697163777',
#    'text': '@unbounders @ecosurety @1PieceOfRubbish',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'unbounders',
#       'name': 'Unbound',
#       'id': 198547538,
#       'id_str': '198547538',
#       'indices': [0, 11]},
#      {'screen_name': 'ecosurety',
#       'name': 'Ecosurety',
#       'id': 194514807,
#       'id_str': '194514807',
#       'indices': [12, 22]},
#      {'screen_name': '1PieceOfRubbish',
#       'name': '1DéchetParJour',
#       'id': 3825582076,
#       'id_str': '3825582076',
#       'indices': [23, 39]}],
#     'urls': []},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1318213001980317699,
#    'in_reply_to_status_id_str': '1318213001980317699',
#    'in_reply_to_user_id': 198547538,
#    'in_reply_to_user_id_str': '198547538',
#    'in_reply_to_screen_name': 'unbounders',
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'und'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1124963647472766978/XEOmdI4m_normal.png',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1124963647472766978/XEOmdI4m_normal.png',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1076159625337204737/1548844878',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 1311410943721705474,
#   'id_str': '1311410943721705474',
#   'name': 'jena adeke',
#   'screen_name': 'AdekeJena',
#   'location': '',
#   'description': 'An introvert',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 5,
#   'friends_count': 115,
#   'listed_count': 0,
#   'created_at': 'Wed Sep 30 21:02:30 +0000 2020',
#   'favourites_count': 0,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 5,
#   'lang': None,
#   'status': {'created_at': 'Tue Oct 20 15:51:42 +0000 2020',
#    'id': 1318580662723436545,
#    'id_str': '1318580662723436545',
#    'text': 'Discover the fastest way to hire freelancers. Join me on Fiverr, get 20% off your next order and I will get a speci… https://t.co/t0ixdBkT8N',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/t0ixdBkT8N',
#       'expanded_url': 'https://twitter.com/i/web/status/1318580662723436545',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1311411351424823297/ifEAcurv_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1311411351424823297/ifEAcurv_normal.jpg',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'}]

# %% [markdown]
# ## Section 4: Functions

# %% [markdown]
# This section details the functions you have to write and turn in as part of your homework assignment.
#
# Please read the requirements carefully.
#
# **What you'll turn in:** A `.py` file with all of the functions written.  We should be able to load this into an IDE, run the file, and then call your functions to verify how and if they work. This file should also be properly commented so we can follow your line of reasoning.  **Even if something doesn't work exactly the way it should, it's okay to still turn in your file, and explain what you were trying to do.**
#
# The functions you'll be prompted to write will be defined in the following ways:
#
#  - **name:** the name of the function
#  - **returns:** what the function should return
#  - **arguments:** arguments to include inside the function in order to specify how it should behave.
#
#  **Note:** The free API has limitations built into it, so this means most of your API calls won't return complete results.  This is fine.  It's understood and recognized that your functions won't be able to return an entire list of someone's users or other such things, so as long as your work delivers the best it can under present circumstances you're in good shape.
#
#  **Other Note:** Every aspect of the API that you need to use can be found on either of these pages.
#
#  Search API:  https://developer.twitter.com/en/docs/tweets/search/api-reference/get-search-tweets
#
#  Users API: https://developer.twitter.com/en/docs/accounts-and-users/follow-search-get-users/api-reference/get-followers-list

# %% [markdown]
# ##### Function 1 (Required)

# %% [markdown]
# **Name:** `find_user`
#
# **Returns:** dictionary that represents user object returned by Twitter's API
#
# **Arguments:**
#  - `screen_name`: str, required; Twitter handle to search for.  **Can include the @ symbol.  The function should check for this and remove it if necessary.**
#  - `keys`: list, optional; list that contains keys to return about user object.  If not specified, then function should return the entire user object.

# %%
# since we're going to re-use this several times, we'll wrap it up into our own function
def check_handle(twitter_handle):
    # check if twitter handle begins with @
    if twitter_handle[0] == '@':
        # and if so slice it out
        return twitter_handle[1:]
    # otherwise just return the handle as is
    return twitter_handle

# %%
def find_user(screen_name, keys=None):
    
    # verify the screen_name
    screen_name=check_handle(screen_name)
    
    # base url we're going to work with
    base_url = 'https://api.twitter.com/1.1/users/lookup.json'
    # query we're going to attach
    query_string   = f'?screen_name={screen_name}'
    
    # the results return a list -- so we're just going to get the first (and only) item out of it
    results  = requests.get(base_url+query_string, auth=tokens).json()[0]
    
    # if something was provided for keys 
    if keys is not None:
        # then make a new dictionary out of the set of keys provided
        new_results = {key: results[key] for key in keys}
        # and return this
        return new_results
    
    # and if the if statement above wasn't true, then just give back the whole thing
    return results

# %% [markdown]
# Some tests:

# %%
# we'll search for a user with an @ symbol
find_user('@GA')
# Out:
# {'id': 170393291,
#  'id_str': '170393291',
#  'name': 'General Assembly',
#  'screen_name': 'GA',
#  'location': '',
#  'description': 'We transform careers and teams — including more than one third of the Fortune 100 — through dynamic courses in coding, data, design, and business.',
#  'url': 'https://t.co/YQeEXPxJ4H',
#  'entities': {'url': {'urls': [{'url': 'https://t.co/YQeEXPxJ4H',
#      'expanded_url': 'http://ga.co/Twitter',
#      'display_url': 'ga.co/Twitter',
#      'indices': [0, 23]}]},
#   'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 164615,
#  'friends_count': 5393,
#  'listed_count': 3251,
#  'created_at': 'Sat Jul 24 18:19:59 +0000 2010',
#  'favourites_count': 35090,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': True,
#  'verified': True,
#  'statuses_count': 22787,
#  'lang': None,
#  'status': {'created_at': 'Thu Oct 29 00:16:01 +0000 2020',
#   'id': 1321606680518496257,
#   'id_str': '1321606680518496257',
#   'text': '"Forward-thinking organizations will implement a diversity recruiting strategy that involves investing time prior t… https://t.co/sPECYv8jkm',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/sPECYv8jkm',
#      'expanded_url': 'https://twitter.com/i/web/status/1321606680518496257',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="https://sproutsocial.com" rel="nofollow">Sprout Social</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 1,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': 'FFFFFF',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_tile': True,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1318271172216324097/O7Xaryg2_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1318271172216324097/O7Xaryg2_normal.jpg',
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/170393291/1480618900',
#  'profile_link_color': 'DE2233',
#  'profile_sidebar_border_color': 'FFFFFF',
#  'profile_sidebar_fill_color': 'FFFFFF',
#  'profile_text_color': '000000',
#  'profile_use_background_image': True,
#  'has_extended_profile': False,
#  'default_profile': False,
#  'default_profile_image': False,
#  'following': False,
#  'follow_request_sent': False,
#  'notifications': False,
#  'translator_type': 'none'}

# %%
# and without
find_user('GA')
# Out:
# {'id': 170393291,
#  'id_str': '170393291',
#  'name': 'General Assembly',
#  'screen_name': 'GA',
#  'location': '',
#  'description': 'We transform careers and teams — including more than one third of the Fortune 100 — through dynamic courses in coding, data, design, and business.',
#  'url': 'https://t.co/YQeEXPxJ4H',
#  'entities': {'url': {'urls': [{'url': 'https://t.co/YQeEXPxJ4H',
#      'expanded_url': 'http://ga.co/Twitter',
#      'display_url': 'ga.co/Twitter',
#      'indices': [0, 23]}]},
#   'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 165528,
#  'friends_count': 5417,
#  'listed_count': 3265,
#  'created_at': 'Sat Jul 24 18:19:59 +0000 2010',
#  'favourites_count': 36408,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': True,
#  'verified': True,
#  'statuses_count': 22755,
#  'lang': None,
#  'status': {'created_at': 'Fri Aug 07 15:25:03 +0000 2020',
#   'id': 1291757253289271296,
#   'id_str': '1291757253289271296',
#   'text': 'Who is responsible for the actions performed by artificial intelligence? Questions to consider in building responsi… https://t.co/s5aSnHtMPz',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/s5aSnHtMPz',
#      'expanded_url': 'https://twitter.com/i/web/status/1291757253289271296',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="https://sproutsocial.com" rel="nofollow">Sprout Social</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 1,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': 'FFFFFF',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_tile': True,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1267818300416745472/A3qO4Fer_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1267818300416745472/A3qO4Fer_normal.jpg',
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/170393291/1480618900',
#  'profile_link_color': 'DE2233',
#  'profile_sidebar_border_color': 'FFFFFF',
#  'profile_sidebar_fill_color': 'FFFFFF',
#  'profile_text_color': '000000',
#  'profile_use_background_image': True,
#  'has_extended_profile': False,
#  'default_profile': False,
#  'default_profile_image': False,
#  'following': False,
#  'follow_request_sent': False,
#  'notifications': False,
#  'translator_type': 'none'}

# %%
# and include some keys
find_user('GA', keys=['name', 'screen_name','followers_count', 'friends_count', ])
# Out:
# {'name': 'General Assembly',
#  'screen_name': 'GA',
#  'followers_count': 164615,
#  'friends_count': 5393}

# %% [markdown]
# ##### Function 2 (Required)

# %% [markdown]
# **Name:** `find_hashtag`
#
# **Returns:** list of data objects that contain information about each tweet that matches the hashtag provided as input.
#
# **Arguments:**
#  - `hashtag`: str, required; text to use as a hashtag search.
#  - `count`: int, optional; number of results to return
#  - `search_type`: str, optional; type of results to return.  should accept 3 different values:
#    - `mixed`:   return mix of most recent and most popular results
#    - `recent`:  return most recent results
#    - `popular`: return most popular results
#
# **Note:** User should **not** have to actually use the `#` character for the `hashtag` argument.  The function should check to see if it's there, and if not, add it in for them.

# %%
def find_hashtag(hashtag, count=None, search_type=None):
    # check to see if the first character is a # symbol
    if hashtag[0] != '#':
        # if it's not, then add it to the beginning of the string
        hash_encoding = '%23'
        hashtag = hash_encoding + hashtag
    else:
        # if it is there, replace it with the correct encoding
        hashtag = hashtag.replace('#', '%23')
        
    # base url to use    
    base_url  = 'https://api.twitter.com/1.1/search/tweets.json'
    # we are always going to use this query string no matter what -- we must specify a hashtag
    hash_str  = f'?q={hashtag}'
    # these are optional, so we're going to leave them blank for now
    count_str = ''
    # ditto this
    type_str  = ''
    
    # if an argument for count was specified
    if count != None:
        # we'll rebuild this portion of the string appropriately
        count_str = f'&count={str(count)}'
        
    # and do the same thing for the search_type argument
    if search_type != None:
        type_str = f'&search_type={search_type}'
        
    # and finally when we're done, add them all together
    query_string = hash_str + count_str + type_str
    
    # and now we'll initiate our request
    results = requests.get(base_url + query_string, auth=tokens).json()
    
    # and return the results
    return results

# %%
# we'll try a search for DataScience
find_hashtag('DataScience')
# Out:
# {'statuses': [{'created_at': 'Wed Oct 21 21:42:22 +0000 2020',
#    'id': 1319031297503825920,
#    'id_str': '1319031297503825920',
#    'text': 'RT @David_Analytics: Announcing: Graph-Native Machine Learning in Neo4j!\nBy Alicia Frame and @amyhodler You gotta check it out before your…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'David_Analytics',
#       'name': 'David Vessie',
#       'id': 1446596928,
#       'id_str': '1446596928',
#       'indices': [3, 19]},
#      {'screen_name': 'amyhodler',
#       'name': 'Amy Hodler',
#       'id': 48175748,
#       'id_str': '48175748',
#       'indices': [93, 103]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://youngapp.co" rel="nofollow">Yap Code Learn</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1221691042325508098,
#     'id_str': '1221691042325508098',
#     'name': 'API Learn Community',
#     'screen_name': 'api_learnn',
#     'location': '',
#     'description': 'Share great ressources for learn next-gen API on NodeJS 💪. #serverless #graphql 🙌🙌',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2127,
#     'friends_count': 5001,
#     'listed_count': 19,
#     'created_at': 'Mon Jan 27 07:07:15 +0000 2020',
#     'favourites_count': 501,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 34797,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1261829900534775809/7hzVnb57_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1261829900534775809/7hzVnb57_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1221691042325508098/1580394962',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 21:12:07 +0000 2020',
#     'id': 1319023684930199560,
#     'id_str': '1319023684930199560',
#     'text': 'Announcing: Graph-Native Machine Learning in Neo4j!\nBy Alicia Frame and @amyhodler You gotta check it out before yo… https://t.co/Fm7NzgMpay',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'amyhodler',
#        'name': 'Amy Hodler',
#        'id': 48175748,
#        'id_str': '48175748',
#        'indices': [72, 82]}],
#      'urls': [{'url': 'https://t.co/Fm7NzgMpay',
#        'expanded_url': 'https://twitter.com/i/web/status/1319023684930199560',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://www.linkedin.com/" rel="nofollow">LinkedIn</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1446596928,
#      'id_str': '1446596928',
#      'name': 'David Vessie',
#      'screen_name': 'David_Analytics',
#      'location': 'Aliso Viejo, CA',
#      'description': 'Neo4j Buying advisor, Socal, AZ, NV, leader in Graph databases',
#      'url': 'https://t.co/JSIaZFJEaE',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/JSIaZFJEaE',
#          'expanded_url': 'https://neo4j.com/',
#          'display_url': 'neo4j.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 183,
#      'friends_count': 389,
#      'listed_count': 7,
#      'created_at': 'Tue May 21 15:23:43 +0000 2013',
#      'favourites_count': 12,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 527,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1082399550420045824/bam03M5v_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1082399550420045824/bam03M5v_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1446596928/1427823210',
#      'profile_link_color': '3B94D9',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:42:10 +0000 2020',
#    'id': 1319031248506028034,
#    'id_str': '1319031248506028034',
#    'text': 'RT @ProgrammingHero: Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.\n.\n#…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ProgrammingHero',
#       'name': 'Programming Hero',
#       'id': 1254869948796674048,
#       'id_str': '1254869948796674048',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://hubofco.de" rel="nofollow">hubofml</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 3040871649,
#     'id_str': '3040871649',
#     'name': 'HubofMachineLearning',
#     'screen_name': 'hubofml',
#     'location': 'Germany ',
#     'description': "Once a month, you'll get a newsletter from me with lots of exciting stuff on data science, engineering, and machine learning. Subscribe here 👉 https://t.co/VRnN9grEfw",
#     'url': 'https://t.co/VRnN9grEfw',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/VRnN9grEfw',
#         'expanded_url': 'http://bit.ly/hubofml1',
#         'display_url': 'bit.ly/hubofml1',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/VRnN9grEfw',
#         'expanded_url': 'http://bit.ly/hubofml1',
#         'display_url': 'bit.ly/hubofml1',
#         'indices': [143, 166]}]}},
#     'protected': False,
#     'followers_count': 6194,
#     'friends_count': 10,
#     'listed_count': 128,
#     'created_at': 'Mon Feb 16 15:33:55 +0000 2015',
#     'favourites_count': 32108,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 267955,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1254334743333818373/F3xeh1db_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1254334743333818373/F3xeh1db_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3040871649/1587892795',
#     'profile_link_color': '4A913C',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 21:41:43 +0000 2020',
#     'id': 1319031134135545856,
#     'id_str': '1319031134135545856',
#     'text': 'Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.… https://t.co/ezaBFrIrOl',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/ezaBFrIrOl',
#        'expanded_url': 'https://twitter.com/i/web/status/1319031134135545856',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1254869948796674048,
#      'id_str': '1254869948796674048',
#      'name': 'Programming Hero',
#      'screen_name': 'ProgrammingHero',
#      'location': '',
#      'description': 'Coding Just Got Fun',
#      'url': 'https://t.co/KCaEvKJ2ZA',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/KCaEvKJ2ZA',
#          'expanded_url': 'https://www.programming-hero.com/',
#          'display_url': 'programming-hero.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 236,
#      'friends_count': 56,
#      'listed_count': 2,
#      'created_at': 'Mon Apr 27 20:28:19 +0000 2020',
#      'favourites_count': 310,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 292,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1254869948796674048/1602616573',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 7,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 7,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:42:04 +0000 2020',
#    'id': 1319031224078274560,
#    'id_str': '1319031224078274560',
#    'text': 'RT @ProgrammingHero: Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.\n.\n#…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ProgrammingHero',
#       'name': 'Programming Hero',
#       'id': 1254869948796674048,
#       'id_str': '1254869948796674048',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://techdox.nz" rel="nofollow">LinuxBot2.0</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1190726565073522694,
#     'id_str': '1190726565073522694',
#     'name': 'LinuxBot',
#     'screen_name': 'LlnuxBot',
#     'location': 'Raspberry Pi',
#     'description': 'Linux Bot | I retweet Linux | Created by @techydox\n\nhttps://t.co/DrRaUtSPGJ',
#     'url': 'https://t.co/QySTldc3HS',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/QySTldc3HS',
#         'expanded_url': 'http://www.techdox.nz',
#         'display_url': 'techdox.nz',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/DrRaUtSPGJ',
#         'expanded_url': 'https://buymeacoff.ee/techdox',
#         'display_url': 'buymeacoff.ee/techdox',
#         'indices': [52, 75]}]}},
#     'protected': False,
#     'followers_count': 3050,
#     'friends_count': 0,
#     'listed_count': 73,
#     'created_at': 'Sat Nov 02 20:25:26 +0000 2019',
#     'favourites_count': 1,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 427666,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1190727216885358597/OoGENW9l_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1190727216885358597/OoGENW9l_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1190726565073522694/1586607550',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 21:41:43 +0000 2020',
#     'id': 1319031134135545856,
#     'id_str': '1319031134135545856',
#     'text': 'Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.… https://t.co/ezaBFrIrOl',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/ezaBFrIrOl',
#        'expanded_url': 'https://twitter.com/i/web/status/1319031134135545856',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1254869948796674048,
#      'id_str': '1254869948796674048',
#      'name': 'Programming Hero',
#      'screen_name': 'ProgrammingHero',
#      'location': '',
#      'description': 'Coding Just Got Fun',
#      'url': 'https://t.co/KCaEvKJ2ZA',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/KCaEvKJ2ZA',
#          'expanded_url': 'https://www.programming-hero.com/',
#          'display_url': 'programming-hero.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 236,
#      'friends_count': 56,
#      'listed_count': 2,
#      'created_at': 'Mon Apr 27 20:28:19 +0000 2020',
#      'favourites_count': 310,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 292,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1254869948796674048/1602616573',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 7,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 7,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:42:03 +0000 2020',
#    'id': 1319031218537590784,
#    'id_str': '1319031218537590784',
#    'text': '#AMLO_21oct2020 #AMLO #ConferenciaPresidente #DivisionDeAnalisisDeDatos #DataScience #CienciaDeDatos… https://t.co/djjnT63Ki8',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'AMLO_21oct2020', 'indices': [0, 15]},
#      {'text': 'AMLO', 'indices': [16, 21]},
#      {'text': 'ConferenciaPresidente', 'indices': [22, 44]},
#      {'text': 'DivisionDeAnalisisDeDatos', 'indices': [45, 71]},
#      {'text': 'DataScience', 'indices': [72, 84]},
#      {'text': 'CienciaDeDatos', 'indices': [85, 100]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/djjnT63Ki8',
#       'expanded_url': 'https://twitter.com/i/web/status/1319031218537590784',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [102, 125]}]},
#    'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1164987784291069952,
#     'id_str': '1164987784291069952',
#     'name': 'Ricardo Pérez-Aguila',
#     'screen_name': 'neote5',
#     'location': 'Huajuapan de León, Oaxaca, MX',
#     'description': 'Socio & Científico de Datos en División de Análisis de Datos (DAD).\nSocio & Desarrollador en Soluciones Inteligentes de Análisis de Multimedios (SIAM).',
#     'url': 'https://t.co/E7xy13eNfl',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/E7xy13eNfl',
#         'expanded_url': 'http://ricardo.perez.aguila.googlepages.com',
#         'display_url': 'ricardo.perez.aguila.googlepages.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 18,
#     'friends_count': 50,
#     'listed_count': 0,
#     'created_at': 'Fri Aug 23 19:48:35 +0000 2019',
#     'favourites_count': 460,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 459,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1164988219378847747/diUuQJlm_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1164988219378847747/diUuQJlm_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'und'},
#   {'created_at': 'Wed Oct 21 21:42:00 +0000 2020',
#    'id': 1319031204553854979,
#    'id_str': '1319031204553854979',
#    'text': 'RT @Ronald_vanLoon: #DeepLearning for #Virtual Try On Clothes – Challenges and Opportunities\nby Maksym Tatariants @kdnuggets\n\nLearn more ht…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'DeepLearning', 'indices': [20, 33]},
#      {'text': 'Virtual', 'indices': [38, 46]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Ronald_vanLoon',
#       'name': 'Ronald van Loon',
#       'id': 555031989,
#       'id_str': '555031989',
#       'indices': [3, 18]},
#      {'screen_name': 'kdnuggets',
#       'name': 'KDnuggets',
#       'id': 20167623,
#       'id_str': '20167623',
#       'indices': [114, 124]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://twitter.com/datasciencebot_" rel="nofollow">TheDataScienceBot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1276058041389953024,
#     'id_str': '1276058041389953024',
#     'name': 'The Data Science Bot',
#     'screen_name': 'datasciencebot_',
#     'location': '',
#     'description': "A bot created by @PatkarSumedh to retweet hashtags #DataScience & #DataVisualization\n\nLet's learn together!\n\nMisusing hashtags and spam will not be tolerated",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1098,
#     'friends_count': 1,
#     'listed_count': 17,
#     'created_at': 'Thu Jun 25 07:42:09 +0000 2020',
#     'favourites_count': 21,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 129145,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1276064635456647168/omX9K1KU_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1276064635456647168/omX9K1KU_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1276058041389953024/1593080314',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 20:59:18 +0000 2020',
#     'id': 1319020460122775552,
#     'id_str': '1319020460122775552',
#     'text': '#DeepLearning for #Virtual Try On Clothes – Challenges and Opportunities\nby Maksym Tatariants @kdnuggets\n\nLearn mor… https://t.co/2uN5vi0Ku4',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'DeepLearning', 'indices': [0, 13]},
#       {'text': 'Virtual', 'indices': [18, 26]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'kdnuggets',
#        'name': 'KDnuggets',
#        'id': 20167623,
#        'id_str': '20167623',
#        'indices': [94, 104]}],
#      'urls': [{'url': 'https://t.co/2uN5vi0Ku4',
#        'expanded_url': 'https://twitter.com/i/web/status/1319020460122775552',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 555031989,
#      'id_str': '555031989',
#      'name': 'Ronald van Loon',
#      'screen_name': 'Ronald_vanLoon',
#      'location': 'The Netherlands',
#      'description': 'Helping data driven companies generating value•Top10Influencer #AI #BigData #DataScience #IoT #MachineLearning #Analytics #Cloud #5G',
#      'url': 'https://t.co/AfBzeHuLQM',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/AfBzeHuLQM',
#          'expanded_url': 'https://linktr.ee/RonaldvanLoon',
#          'display_url': 'linktr.ee/RonaldvanLoon',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 234035,
#      'friends_count': 182815,
#      'listed_count': 5487,
#      'created_at': 'Mon Apr 16 07:55:31 +0000 2012',
#      'favourites_count': 183075,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 90756,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1107936345769607169/sJKWJd7g_normal.png',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1107936345769607169/sJKWJd7g_normal.png',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/555031989/1504691055',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 6,
#     'favorite_count': 6,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 6,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:41:48 +0000 2020',
#    'id': 1319031156524916739,
#    'id_str': '1319031156524916739',
#    'text': 'RT @ProgrammingHero: Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.\n.\n#…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ProgrammingHero',
#       'name': 'Programming Hero',
#       'id': 1254869948796674048,
#       'id_str': '1254869948796674048',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://dreamsofimran.in" rel="nofollow">TheDeveloperBot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1250164632968298497,
#     'id_str': '1250164632968298497',
#     'name': 'The Developer Bot',
#     'screen_name': 'TheDeveloperBot',
#     'location': '',
#     'description': "I'm a bot created by @DreamsOfImran with a little bit of NodeJs and lots of ❤️\nI like and retweet posts related to #javascript, #vuejs, #reactjs, #Nodejs & etc",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1832,
#     'friends_count': 1,
#     'listed_count': 41,
#     'created_at': 'Tue Apr 14 20:51:03 +0000 2020',
#     'favourites_count': 124780,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 342016,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1250454907871580162/Al-vkUN1_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1250454907871580162/Al-vkUN1_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1250164632968298497/1586966908',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 21:41:43 +0000 2020',
#     'id': 1319031134135545856,
#     'id_str': '1319031134135545856',
#     'text': 'Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.… https://t.co/ezaBFrIrOl',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/ezaBFrIrOl',
#        'expanded_url': 'https://twitter.com/i/web/status/1319031134135545856',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1254869948796674048,
#      'id_str': '1254869948796674048',
#      'name': 'Programming Hero',
#      'screen_name': 'ProgrammingHero',
#      'location': '',
#      'description': 'Coding Just Got Fun',
#      'url': 'https://t.co/KCaEvKJ2ZA',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/KCaEvKJ2ZA',
#          'expanded_url': 'https://www.programming-hero.com/',
#          'display_url': 'programming-hero.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 236,
#      'friends_count': 56,
#      'listed_count': 2,
#      'created_at': 'Mon Apr 27 20:28:19 +0000 2020',
#      'favourites_count': 310,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 292,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1254869948796674048/1602616573',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 7,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 7,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:41:48 +0000 2020',
#    'id': 1319031156457852932,
#    'id_str': '1319031156457852932',
#    'text': 'RT @ProgrammingHero: Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.\n.\n#…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ProgrammingHero',
#       'name': 'Programming Hero',
#       'id': 1254869948796674048,
#       'id_str': '1254869948796674048',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://localhost.com" rel="nofollow">Serverless Tweet/Retweet Bot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 971620109197312000,
#     'id_str': '971620109197312000',
#     'name': 'Serverless Fan',
#     'screen_name': 'ServerlessFan',
#     'location': 'Sri Lanka',
#     'description': '#Serverless #Computing',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 3289,
#     'friends_count': 6,
#     'listed_count': 125,
#     'created_at': 'Thu Mar 08 05:34:20 +0000 2018',
#     'favourites_count': 7,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 272197,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/973611685822058497/yRRo9D52_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/973611685822058497/yRRo9D52_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/971620109197312000/1525426121',
#     'profile_link_color': '000000',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 21:41:43 +0000 2020',
#     'id': 1319031134135545856,
#     'id_str': '1319031134135545856',
#     'text': 'Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.… https://t.co/ezaBFrIrOl',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/ezaBFrIrOl',
#        'expanded_url': 'https://twitter.com/i/web/status/1319031134135545856',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1254869948796674048,
#      'id_str': '1254869948796674048',
#      'name': 'Programming Hero',
#      'screen_name': 'ProgrammingHero',
#      'location': '',
#      'description': 'Coding Just Got Fun',
#      'url': 'https://t.co/KCaEvKJ2ZA',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/KCaEvKJ2ZA',
#          'expanded_url': 'https://www.programming-hero.com/',
#          'display_url': 'programming-hero.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 236,
#      'friends_count': 56,
#      'listed_count': 2,
#      'created_at': 'Mon Apr 27 20:28:19 +0000 2020',
#      'favourites_count': 310,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 292,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1254869948796674048/1602616573',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 7,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 7,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:41:46 +0000 2020',
#    'id': 1319031148257939457,
#    'id_str': '1319031148257939457',
#    'text': 'RT @ProgrammingHero: Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.\n.\n#…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ProgrammingHero',
#       'name': 'Programming Hero',
#       'id': 1254869948796674048,
#       'id_str': '1254869948796674048',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://occlude.netlify.app/" rel="nofollow">OccludejsBot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1275056773443973124,
#     'id_str': '1275056773443973124',
#     'name': 'Candis',
#     'screen_name': 'Women_who_code',
#     'location': 'bootcamp',
#     'description': '24💐 • MERN Stack Developer • React Geek • ☕ Coffee • 🦄 Unicorn • SDE @nytimes',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 734,
#     'friends_count': 25,
#     'listed_count': 19,
#     'created_at': 'Mon Jun 22 13:23:34 +0000 2020',
#     'favourites_count': 236,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 97618,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1314621116191629312/vQLAcsnS_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1314621116191629312/vQLAcsnS_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1275056773443973124/1599976745',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 21:41:43 +0000 2020',
#     'id': 1319031134135545856,
#     'id_str': '1319031134135545856',
#     'text': 'Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.… https://t.co/ezaBFrIrOl',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/ezaBFrIrOl',
#        'expanded_url': 'https://twitter.com/i/web/status/1319031134135545856',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1254869948796674048,
#      'id_str': '1254869948796674048',
#      'name': 'Programming Hero',
#      'screen_name': 'ProgrammingHero',
#      'location': '',
#      'description': 'Coding Just Got Fun',
#      'url': 'https://t.co/KCaEvKJ2ZA',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/KCaEvKJ2ZA',
#          'expanded_url': 'https://www.programming-hero.com/',
#          'display_url': 'programming-hero.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 236,
#      'friends_count': 56,
#      'listed_count': 2,
#      'created_at': 'Mon Apr 27 20:28:19 +0000 2020',
#      'favourites_count': 310,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 292,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1254869948796674048/1602616573',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 7,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 7,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:41:46 +0000 2020',
#    'id': 1319031147964305419,
#    'id_str': '1319031147964305419',
#    'text': 'RT @ProgrammingHero: Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.\n.\n#…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ProgrammingHero',
#       'name': 'Programming Hero',
#       'id': 1254869948796674048,
#       'id_str': '1254869948796674048',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://nlogn.in" rel="nofollow">nlognrobot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1260062769543434240,
#     'id_str': '1260062769543434240',
#     'name': '#100DaysOfCode',
#     'screen_name': 'nlognbot',
#     'location': 'Server',
#     'description': "Hi, I'm a bot that retweets #100daysofcode     \n                 \nP.S. I was created by @NlognHQ follow them.",
#     'url': 'https://t.co/PujHDQomPA',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/PujHDQomPA',
#         'expanded_url': 'http://nlogn.in',
#         'display_url': 'nlogn.in',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 4376,
#     'friends_count': 3,
# ...
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1254869948796674048,
#     'id_str': '1254869948796674048',
#     'name': 'Programming Hero',
#     'screen_name': 'ProgrammingHero',
#     'location': '',
#     'description': 'Coding Just Got Fun',
#     'url': 'https://t.co/KCaEvKJ2ZA',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/KCaEvKJ2ZA',
#         'expanded_url': 'https://www.programming-hero.com/',
#         'display_url': 'programming-hero.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 236,
#     'friends_count': 56,
#     'listed_count': 2,
#     'created_at': 'Mon Apr 27 20:28:19 +0000 2020',
#     'favourites_count': 310,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 292,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1254869948796674048/1602616573',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 7,
#    'favorite_count': 2,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:41:39 +0000 2020',
#    'id': 1319031118755135503,
#    'id_str': '1319031118755135503',
#    'text': 'Bitvore: Implementing AI in Financing: The hottest new commodity in finance. via @TDataScience:… https://t.co/ZI4ceSpN0H',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'TDataScience',
#       'name': 'Towards Data Science',
#       'id': 788898706586275840,
#       'id_str': '788898706586275840',
#       'indices': [81, 94]}],
#     'urls': [{'url': 'https://t.co/ZI4ceSpN0H',
#       'expanded_url': 'https://twitter.com/i/web/status/1319031118755135503',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [97, 120]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2303101,
#     'id_str': '2303101',
#     'name': 'Greg Bolcer',
#     'screen_name': 'gbolcer',
#     'location': 'Orange County, CA',
#     'description': 'computer geek, semi-corporate stooge with a brain for math, finesse with computers, the eyes of an artist, and the heart of an entrepreneur',
#     'url': 'http://t.co/hXj4WTV9qJ',
#     'entities': {'url': {'urls': [{'url': 'http://t.co/hXj4WTV9qJ',
#         'expanded_url': 'http://bolcer.org/',
#         'display_url': 'bolcer.org',
#         'indices': [0, 22]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 166,
#     'friends_count': 604,
#     'listed_count': 4,
#     'created_at': 'Mon Mar 26 14:08:05 +0000 2007',
#     'favourites_count': 399,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1046,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '9AE4E8',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/29959562/Greg-8_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/29959562/Greg-8_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2303101/1402090619',
#     'profile_link_color': '77778C',
#     'profile_sidebar_border_color': '87BC44',
#     'profile_sidebar_fill_color': 'E0FF92',
#     'profile_text_color': '000000',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:41:34 +0000 2020',
#    'id': 1319031095304781824,
#    'id_str': '1319031095304781824',
#    'text': "We're always on the lookout for new books for our #DataScience series. Please DM me if you have an idea you would l… https://t.co/TdpDhU8YCn",
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'DataScience', 'indices': [50, 62]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/TdpDhU8YCn',
#       'expanded_url': 'https://twitter.com/i/web/status/1319031095304781824',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 3596301683,
#     'id_str': '3596301683',
#     'name': 'Rob Calver',
#     'screen_name': 'RobCalver5',
#     'location': '',
#     'description': 'Senior Publisher of #Mathematics, #Statistics, and #Physics books at @CRCPress. Opinions are my own. #rstats #datascience @tandfSTEM @CRC_MathStats',
#     'url': 'https://t.co/zg0X9x23ZH',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/zg0X9x23ZH',
#         'expanded_url': 'https://www.routledge.com/statistics',
#         'display_url': 'routledge.com/statistics',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1124,
#     'friends_count': 1581,
#     'listed_count': 22,
#     'created_at': 'Wed Sep 09 08:00:56 +0000 2015',
#     'favourites_count': 5758,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 2854,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/976918559866617862/nZRveEhW_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/976918559866617862/nZRveEhW_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3596301683/1589661747',
#     'profile_link_color': '981CEB',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:41:30 +0000 2020',
#    'id': 1319031080658272258,
#    'id_str': '1319031080658272258',
#    'text': 'RT @gp_pulipaka: Machine Learning using Titanic Data. #BigData #Analytics #DataScience #AI #MachineLearning #IoT #IIoT #Python #RStats #Ten…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'BigData', 'indices': [54, 62]},
#      {'text': 'Analytics', 'indices': [63, 73]},
#      {'text': 'DataScience', 'indices': [74, 86]},
#      {'text': 'AI', 'indices': [87, 90]},
#      {'text': 'MachineLearning', 'indices': [91, 107]},
#      {'text': 'IoT', 'indices': [108, 112]},
#      {'text': 'IIoT', 'indices': [113, 118]},
#      {'text': 'Python', 'indices': [119, 126]},
#      {'text': 'RStats', 'indices': [127, 134]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'gp_pulipaka',
#       'name': 'Dr. Ganapathi Pulipaka',
#       'id': 4263007693,
#       'id_str': '4263007693',
#       'indices': [3, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://www.sankalpsaxena.com" rel="nofollow">RT #MachineLearning</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1132890775891505152,
#     'id_str': '1132890775891505152',
#     'name': 'Olivia',
#     'screen_name': '_OliviaBot',
#     'location': 'India',
#     'description': 'I retweet every mention of #MachineLearning Meet my humble daddy ❤ : @sankalp_saxena 😎',
#     'url': 'https://t.co/Sf9KtbVG2n',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/Sf9KtbVG2n',
#         'expanded_url': 'http://sankalpsaxena.com',
#         'display_url': 'sankalpsaxena.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 606,
#     'friends_count': 6,
#     'listed_count': 26,
#     'created_at': 'Mon May 27 06:06:23 +0000 2019',
#     'favourites_count': 75,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 34318,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1159212500572753920/49WAfJuf_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1159212500572753920/49WAfJuf_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1132890775891505152/1558939931',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Oct 15 14:42:51 +0000 2020',
#     'id': 1316751396193079296,
#     'id_str': '1316751396193079296',
#     'text': 'Machine Learning using Titanic Data. #BigData #Analytics #DataScience #AI #MachineLearning #IoT #IIoT #Python… https://t.co/h6Kqiy0vHO',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'BigData', 'indices': [37, 45]},
#       {'text': 'Analytics', 'indices': [46, 56]},
#       {'text': 'DataScience', 'indices': [57, 69]},
#       {'text': 'AI', 'indices': [70, 73]},
#       {'text': 'MachineLearning', 'indices': [74, 90]},
#       {'text': 'IoT', 'indices': [91, 95]},
#       {'text': 'IIoT', 'indices': [96, 101]},
#       {'text': 'Python', 'indices': [102, 109]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/h6Kqiy0vHO',
#        'expanded_url': 'https://twitter.com/i/web/status/1316751396193079296',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [111, 134]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 4263007693,
#      'id_str': '4263007693',
#      'name': 'Dr. Ganapathi Pulipaka',
#      'screen_name': 'gp_pulipaka',
#      'location': 'Redondo Beach, CA',
#      'description': 'Chief #AI #HPC Scientist | #Speaker | PostDoc CS, PhD | Bestselling #Author | 18.4M V | Top #BigData #DataScience #MachineLearning #IIoT Influencer @Onalytica',
#      'url': 'https://t.co/eYyaJsEcfw',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/eYyaJsEcfw',
#          'expanded_url': 'http://www.gppulipaka.org',
#          'display_url': 'gppulipaka.org',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 101394,
#      'friends_count': 25866,
#      'listed_count': 3495,
#      'created_at': 'Tue Nov 17 02:19:09 +0000 2015',
#      'favourites_count': 9,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 58478,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1315479714790694912/MQmkjugW_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1315479714790694912/MQmkjugW_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4263007693/1599491057',
#      'profile_link_color': 'DD2E44',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 131,
#     'favorite_count': 76,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 131,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.089,
#   'max_id': 1319031297503825920,
#   'max_id_str': '1319031297503825920',
#   'next_results': '?max_id=1319031080658272257&q=%23DataScience&include_entities=1',
#   'query': '%23DataScience',
#   'refresh_url': '?since_id=1319031297503825920&q=%23DataScience&include_entities=1',
#   'count': 15,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %%
# and add in the Hashtag as well for good measure
find_hashtag('#DataScience')
# Out:
# {'statuses': [{'created_at': 'Wed Oct 21 21:42:22 +0000 2020',
#    'id': 1319031297503825920,
#    'id_str': '1319031297503825920',
#    'text': 'RT @David_Analytics: Announcing: Graph-Native Machine Learning in Neo4j!\nBy Alicia Frame and @amyhodler You gotta check it out before your…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'David_Analytics',
#       'name': 'David Vessie',
#       'id': 1446596928,
#       'id_str': '1446596928',
#       'indices': [3, 19]},
#      {'screen_name': 'amyhodler',
#       'name': 'Amy Hodler',
#       'id': 48175748,
#       'id_str': '48175748',
#       'indices': [93, 103]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://youngapp.co" rel="nofollow">Yap Code Learn</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1221691042325508098,
#     'id_str': '1221691042325508098',
#     'name': 'API Learn Community',
#     'screen_name': 'api_learnn',
#     'location': '',
#     'description': 'Share great ressources for learn next-gen API on NodeJS 💪. #serverless #graphql 🙌🙌',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2127,
#     'friends_count': 5001,
#     'listed_count': 19,
#     'created_at': 'Mon Jan 27 07:07:15 +0000 2020',
#     'favourites_count': 501,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 34797,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1261829900534775809/7hzVnb57_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1261829900534775809/7hzVnb57_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1221691042325508098/1580394962',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 21:12:07 +0000 2020',
#     'id': 1319023684930199560,
#     'id_str': '1319023684930199560',
#     'text': 'Announcing: Graph-Native Machine Learning in Neo4j!\nBy Alicia Frame and @amyhodler You gotta check it out before yo… https://t.co/Fm7NzgMpay',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'amyhodler',
#        'name': 'Amy Hodler',
#        'id': 48175748,
#        'id_str': '48175748',
#        'indices': [72, 82]}],
#      'urls': [{'url': 'https://t.co/Fm7NzgMpay',
#        'expanded_url': 'https://twitter.com/i/web/status/1319023684930199560',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://www.linkedin.com/" rel="nofollow">LinkedIn</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1446596928,
#      'id_str': '1446596928',
#      'name': 'David Vessie',
#      'screen_name': 'David_Analytics',
#      'location': 'Aliso Viejo, CA',
#      'description': 'Neo4j Buying advisor, Socal, AZ, NV, leader in Graph databases',
#      'url': 'https://t.co/JSIaZFJEaE',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/JSIaZFJEaE',
#          'expanded_url': 'https://neo4j.com/',
#          'display_url': 'neo4j.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 183,
#      'friends_count': 389,
#      'listed_count': 7,
#      'created_at': 'Tue May 21 15:23:43 +0000 2013',
#      'favourites_count': 12,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 527,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1082399550420045824/bam03M5v_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1082399550420045824/bam03M5v_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1446596928/1427823210',
#      'profile_link_color': '3B94D9',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:42:10 +0000 2020',
#    'id': 1319031248506028034,
#    'id_str': '1319031248506028034',
#    'text': 'RT @ProgrammingHero: Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.\n.\n#…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ProgrammingHero',
#       'name': 'Programming Hero',
#       'id': 1254869948796674048,
#       'id_str': '1254869948796674048',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://hubofco.de" rel="nofollow">hubofml</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 3040871649,
#     'id_str': '3040871649',
#     'name': 'HubofMachineLearning',
#     'screen_name': 'hubofml',
#     'location': 'Germany ',
#     'description': "Once a month, you'll get a newsletter from me with lots of exciting stuff on data science, engineering, and machine learning. Subscribe here 👉 https://t.co/VRnN9grEfw",
#     'url': 'https://t.co/VRnN9grEfw',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/VRnN9grEfw',
#         'expanded_url': 'http://bit.ly/hubofml1',
#         'display_url': 'bit.ly/hubofml1',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/VRnN9grEfw',
#         'expanded_url': 'http://bit.ly/hubofml1',
#         'display_url': 'bit.ly/hubofml1',
#         'indices': [143, 166]}]}},
#     'protected': False,
#     'followers_count': 6194,
#     'friends_count': 10,
#     'listed_count': 128,
#     'created_at': 'Mon Feb 16 15:33:55 +0000 2015',
#     'favourites_count': 32108,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 267957,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1254334743333818373/F3xeh1db_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1254334743333818373/F3xeh1db_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3040871649/1587892795',
#     'profile_link_color': '4A913C',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 21:41:43 +0000 2020',
#     'id': 1319031134135545856,
#     'id_str': '1319031134135545856',
#     'text': 'Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.… https://t.co/ezaBFrIrOl',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/ezaBFrIrOl',
#        'expanded_url': 'https://twitter.com/i/web/status/1319031134135545856',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1254869948796674048,
#      'id_str': '1254869948796674048',
#      'name': 'Programming Hero',
#      'screen_name': 'ProgrammingHero',
#      'location': '',
#      'description': 'Coding Just Got Fun',
#      'url': 'https://t.co/KCaEvKJ2ZA',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/KCaEvKJ2ZA',
#          'expanded_url': 'https://www.programming-hero.com/',
#          'display_url': 'programming-hero.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 236,
#      'friends_count': 56,
#      'listed_count': 2,
#      'created_at': 'Mon Apr 27 20:28:19 +0000 2020',
#      'favourites_count': 310,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 292,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1254869948796674048/1602616573',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 7,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 7,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:42:04 +0000 2020',
#    'id': 1319031224078274560,
#    'id_str': '1319031224078274560',
#    'text': 'RT @ProgrammingHero: Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.\n.\n#…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ProgrammingHero',
#       'name': 'Programming Hero',
#       'id': 1254869948796674048,
#       'id_str': '1254869948796674048',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://techdox.nz" rel="nofollow">LinuxBot2.0</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1190726565073522694,
#     'id_str': '1190726565073522694',
#     'name': 'LinuxBot',
#     'screen_name': 'LlnuxBot',
#     'location': 'Raspberry Pi',
#     'description': 'Linux Bot | I retweet Linux | Created by @techydox\n\nhttps://t.co/DrRaUtSPGJ',
#     'url': 'https://t.co/QySTldc3HS',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/QySTldc3HS',
#         'expanded_url': 'http://www.techdox.nz',
#         'display_url': 'techdox.nz',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/DrRaUtSPGJ',
#         'expanded_url': 'https://buymeacoff.ee/techdox',
#         'display_url': 'buymeacoff.ee/techdox',
#         'indices': [52, 75]}]}},
#     'protected': False,
#     'followers_count': 3050,
#     'friends_count': 0,
#     'listed_count': 73,
#     'created_at': 'Sat Nov 02 20:25:26 +0000 2019',
#     'favourites_count': 1,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 427666,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1190727216885358597/OoGENW9l_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1190727216885358597/OoGENW9l_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1190726565073522694/1586607550',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 21:41:43 +0000 2020',
#     'id': 1319031134135545856,
#     'id_str': '1319031134135545856',
#     'text': 'Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.… https://t.co/ezaBFrIrOl',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/ezaBFrIrOl',
#        'expanded_url': 'https://twitter.com/i/web/status/1319031134135545856',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1254869948796674048,
#      'id_str': '1254869948796674048',
#      'name': 'Programming Hero',
#      'screen_name': 'ProgrammingHero',
#      'location': '',
#      'description': 'Coding Just Got Fun',
#      'url': 'https://t.co/KCaEvKJ2ZA',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/KCaEvKJ2ZA',
#          'expanded_url': 'https://www.programming-hero.com/',
#          'display_url': 'programming-hero.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 236,
#      'friends_count': 56,
#      'listed_count': 2,
#      'created_at': 'Mon Apr 27 20:28:19 +0000 2020',
#      'favourites_count': 310,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 292,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1254869948796674048/1602616573',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 7,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 7,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:42:03 +0000 2020',
#    'id': 1319031218537590784,
#    'id_str': '1319031218537590784',
#    'text': '#AMLO_21oct2020 #AMLO #ConferenciaPresidente #DivisionDeAnalisisDeDatos #DataScience #CienciaDeDatos… https://t.co/djjnT63Ki8',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'AMLO_21oct2020', 'indices': [0, 15]},
#      {'text': 'AMLO', 'indices': [16, 21]},
#      {'text': 'ConferenciaPresidente', 'indices': [22, 44]},
#      {'text': 'DivisionDeAnalisisDeDatos', 'indices': [45, 71]},
#      {'text': 'DataScience', 'indices': [72, 84]},
#      {'text': 'CienciaDeDatos', 'indices': [85, 100]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/djjnT63Ki8',
#       'expanded_url': 'https://twitter.com/i/web/status/1319031218537590784',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [102, 125]}]},
#    'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1164987784291069952,
#     'id_str': '1164987784291069952',
#     'name': 'Ricardo Pérez-Aguila',
#     'screen_name': 'neote5',
#     'location': 'Huajuapan de León, Oaxaca, MX',
#     'description': 'Socio & Científico de Datos en División de Análisis de Datos (DAD).\nSocio & Desarrollador en Soluciones Inteligentes de Análisis de Multimedios (SIAM).',
#     'url': 'https://t.co/E7xy13eNfl',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/E7xy13eNfl',
#         'expanded_url': 'http://ricardo.perez.aguila.googlepages.com',
#         'display_url': 'ricardo.perez.aguila.googlepages.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 18,
#     'friends_count': 50,
#     'listed_count': 0,
#     'created_at': 'Fri Aug 23 19:48:35 +0000 2019',
#     'favourites_count': 460,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 459,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1164988219378847747/diUuQJlm_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1164988219378847747/diUuQJlm_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'und'},
#   {'created_at': 'Wed Oct 21 21:42:00 +0000 2020',
#    'id': 1319031204553854979,
#    'id_str': '1319031204553854979',
#    'text': 'RT @Ronald_vanLoon: #DeepLearning for #Virtual Try On Clothes – Challenges and Opportunities\nby Maksym Tatariants @kdnuggets\n\nLearn more ht…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'DeepLearning', 'indices': [20, 33]},
#      {'text': 'Virtual', 'indices': [38, 46]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Ronald_vanLoon',
#       'name': 'Ronald van Loon',
#       'id': 555031989,
#       'id_str': '555031989',
#       'indices': [3, 18]},
#      {'screen_name': 'kdnuggets',
#       'name': 'KDnuggets',
#       'id': 20167623,
#       'id_str': '20167623',
#       'indices': [114, 124]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://twitter.com/datasciencebot_" rel="nofollow">TheDataScienceBot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1276058041389953024,
#     'id_str': '1276058041389953024',
#     'name': 'The Data Science Bot',
#     'screen_name': 'datasciencebot_',
#     'location': '',
#     'description': "A bot created by @PatkarSumedh to retweet hashtags #DataScience & #DataVisualization\n\nLet's learn together!\n\nMisusing hashtags and spam will not be tolerated",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1098,
#     'friends_count': 1,
#     'listed_count': 17,
#     'created_at': 'Thu Jun 25 07:42:09 +0000 2020',
#     'favourites_count': 21,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 129145,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1276064635456647168/omX9K1KU_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1276064635456647168/omX9K1KU_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1276058041389953024/1593080314',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 20:59:18 +0000 2020',
#     'id': 1319020460122775552,
#     'id_str': '1319020460122775552',
#     'text': '#DeepLearning for #Virtual Try On Clothes – Challenges and Opportunities\nby Maksym Tatariants @kdnuggets\n\nLearn mor… https://t.co/2uN5vi0Ku4',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'DeepLearning', 'indices': [0, 13]},
#       {'text': 'Virtual', 'indices': [18, 26]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'kdnuggets',
#        'name': 'KDnuggets',
#        'id': 20167623,
#        'id_str': '20167623',
#        'indices': [94, 104]}],
#      'urls': [{'url': 'https://t.co/2uN5vi0Ku4',
#        'expanded_url': 'https://twitter.com/i/web/status/1319020460122775552',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 555031989,
#      'id_str': '555031989',
#      'name': 'Ronald van Loon',
#      'screen_name': 'Ronald_vanLoon',
#      'location': 'The Netherlands',
#      'description': 'Helping data driven companies generating value•Top10Influencer #AI #BigData #DataScience #IoT #MachineLearning #Analytics #Cloud #5G',
#      'url': 'https://t.co/AfBzeHuLQM',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/AfBzeHuLQM',
#          'expanded_url': 'https://linktr.ee/RonaldvanLoon',
#          'display_url': 'linktr.ee/RonaldvanLoon',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 234035,
#      'friends_count': 182815,
#      'listed_count': 5487,
#      'created_at': 'Mon Apr 16 07:55:31 +0000 2012',
#      'favourites_count': 183075,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 90756,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1107936345769607169/sJKWJd7g_normal.png',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1107936345769607169/sJKWJd7g_normal.png',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/555031989/1504691055',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 6,
#     'favorite_count': 6,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 6,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:41:48 +0000 2020',
#    'id': 1319031156524916739,
#    'id_str': '1319031156524916739',
#    'text': 'RT @ProgrammingHero: Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.\n.\n#…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ProgrammingHero',
#       'name': 'Programming Hero',
#       'id': 1254869948796674048,
#       'id_str': '1254869948796674048',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://dreamsofimran.in" rel="nofollow">TheDeveloperBot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1250164632968298497,
#     'id_str': '1250164632968298497',
#     'name': 'The Developer Bot',
#     'screen_name': 'TheDeveloperBot',
#     'location': '',
#     'description': "I'm a bot created by @DreamsOfImran with a little bit of NodeJs and lots of ❤️\nI like and retweet posts related to #javascript, #vuejs, #reactjs, #Nodejs & etc",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1832,
#     'friends_count': 1,
#     'listed_count': 41,
#     'created_at': 'Tue Apr 14 20:51:03 +0000 2020',
#     'favourites_count': 124780,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 342016,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1250454907871580162/Al-vkUN1_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1250454907871580162/Al-vkUN1_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1250164632968298497/1586966908',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 21:41:43 +0000 2020',
#     'id': 1319031134135545856,
#     'id_str': '1319031134135545856',
#     'text': 'Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.… https://t.co/ezaBFrIrOl',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/ezaBFrIrOl',
#        'expanded_url': 'https://twitter.com/i/web/status/1319031134135545856',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1254869948796674048,
#      'id_str': '1254869948796674048',
#      'name': 'Programming Hero',
#      'screen_name': 'ProgrammingHero',
#      'location': '',
#      'description': 'Coding Just Got Fun',
#      'url': 'https://t.co/KCaEvKJ2ZA',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/KCaEvKJ2ZA',
#          'expanded_url': 'https://www.programming-hero.com/',
#          'display_url': 'programming-hero.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 236,
#      'friends_count': 56,
#      'listed_count': 2,
#      'created_at': 'Mon Apr 27 20:28:19 +0000 2020',
#      'favourites_count': 310,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 292,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1254869948796674048/1602616573',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 7,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 7,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:41:48 +0000 2020',
#    'id': 1319031156457852932,
#    'id_str': '1319031156457852932',
#    'text': 'RT @ProgrammingHero: Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.\n.\n#…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ProgrammingHero',
#       'name': 'Programming Hero',
#       'id': 1254869948796674048,
#       'id_str': '1254869948796674048',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://localhost.com" rel="nofollow">Serverless Tweet/Retweet Bot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 971620109197312000,
#     'id_str': '971620109197312000',
#     'name': 'Serverless Fan',
#     'screen_name': 'ServerlessFan',
#     'location': 'Sri Lanka',
#     'description': '#Serverless #Computing',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 3289,
#     'friends_count': 6,
#     'listed_count': 125,
#     'created_at': 'Thu Mar 08 05:34:20 +0000 2018',
#     'favourites_count': 7,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 272197,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/973611685822058497/yRRo9D52_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/973611685822058497/yRRo9D52_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/971620109197312000/1525426121',
#     'profile_link_color': '000000',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 21:41:43 +0000 2020',
#     'id': 1319031134135545856,
#     'id_str': '1319031134135545856',
#     'text': 'Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.… https://t.co/ezaBFrIrOl',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/ezaBFrIrOl',
#        'expanded_url': 'https://twitter.com/i/web/status/1319031134135545856',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1254869948796674048,
#      'id_str': '1254869948796674048',
#      'name': 'Programming Hero',
#      'screen_name': 'ProgrammingHero',
#      'location': '',
#      'description': 'Coding Just Got Fun',
#      'url': 'https://t.co/KCaEvKJ2ZA',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/KCaEvKJ2ZA',
#          'expanded_url': 'https://www.programming-hero.com/',
#          'display_url': 'programming-hero.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 236,
#      'friends_count': 56,
#      'listed_count': 2,
#      'created_at': 'Mon Apr 27 20:28:19 +0000 2020',
#      'favourites_count': 310,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 292,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1254869948796674048/1602616573',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 7,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 7,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:41:46 +0000 2020',
#    'id': 1319031148257939457,
#    'id_str': '1319031148257939457',
#    'text': 'RT @ProgrammingHero: Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.\n.\n#…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ProgrammingHero',
#       'name': 'Programming Hero',
#       'id': 1254869948796674048,
#       'id_str': '1254869948796674048',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://occlude.netlify.app/" rel="nofollow">OccludejsBot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1275056773443973124,
#     'id_str': '1275056773443973124',
#     'name': 'Candis',
#     'screen_name': 'Women_who_code',
#     'location': 'bootcamp',
#     'description': '24💐 • MERN Stack Developer • React Geek • ☕ Coffee • 🦄 Unicorn • SDE @nytimes',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 734,
#     'friends_count': 25,
#     'listed_count': 19,
#     'created_at': 'Mon Jun 22 13:23:34 +0000 2020',
#     'favourites_count': 236,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 97618,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1314621116191629312/vQLAcsnS_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1314621116191629312/vQLAcsnS_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1275056773443973124/1599976745',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 21:41:43 +0000 2020',
#     'id': 1319031134135545856,
#     'id_str': '1319031134135545856',
#     'text': 'Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.… https://t.co/ezaBFrIrOl',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/ezaBFrIrOl',
#        'expanded_url': 'https://twitter.com/i/web/status/1319031134135545856',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1254869948796674048,
#      'id_str': '1254869948796674048',
#      'name': 'Programming Hero',
#      'screen_name': 'ProgrammingHero',
#      'location': '',
#      'description': 'Coding Just Got Fun',
#      'url': 'https://t.co/KCaEvKJ2ZA',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/KCaEvKJ2ZA',
#          'expanded_url': 'https://www.programming-hero.com/',
#          'display_url': 'programming-hero.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 236,
#      'friends_count': 56,
#      'listed_count': 2,
#      'created_at': 'Mon Apr 27 20:28:19 +0000 2020',
#      'favourites_count': 310,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 292,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1254869948796674048/1602616573',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 7,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 7,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:41:46 +0000 2020',
#    'id': 1319031147964305419,
#    'id_str': '1319031147964305419',
#    'text': 'RT @ProgrammingHero: Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.\n.\n#…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ProgrammingHero',
#       'name': 'Programming Hero',
#       'id': 1254869948796674048,
#       'id_str': '1254869948796674048',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://nlogn.in" rel="nofollow">nlognrobot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1260062769543434240,
#     'id_str': '1260062769543434240',
#     'name': '#100DaysOfCode',
#     'screen_name': 'nlognbot',
#     'location': 'Server',
#     'description': "Hi, I'm a bot that retweets #100daysofcode     \n                 \nP.S. I was created by @NlognHQ follow them.",
#     'url': 'https://t.co/PujHDQomPA',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/PujHDQomPA',
#         'expanded_url': 'http://nlogn.in',
#         'display_url': 'nlogn.in',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 4376,
#     'friends_count': 3,
# ...
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1254869948796674048,
#     'id_str': '1254869948796674048',
#     'name': 'Programming Hero',
#     'screen_name': 'ProgrammingHero',
#     'location': '',
#     'description': 'Coding Just Got Fun',
#     'url': 'https://t.co/KCaEvKJ2ZA',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/KCaEvKJ2ZA',
#         'expanded_url': 'https://www.programming-hero.com/',
#         'display_url': 'programming-hero.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 236,
#     'friends_count': 56,
#     'listed_count': 2,
#     'created_at': 'Mon Apr 27 20:28:19 +0000 2020',
#     'favourites_count': 310,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 292,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1254869948796674048/1602616573',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 7,
#    'favorite_count': 2,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:41:39 +0000 2020',
#    'id': 1319031118755135503,
#    'id_str': '1319031118755135503',
#    'text': 'Bitvore: Implementing AI in Financing: The hottest new commodity in finance. via @TDataScience:… https://t.co/ZI4ceSpN0H',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'TDataScience',
#       'name': 'Towards Data Science',
#       'id': 788898706586275840,
#       'id_str': '788898706586275840',
#       'indices': [81, 94]}],
#     'urls': [{'url': 'https://t.co/ZI4ceSpN0H',
#       'expanded_url': 'https://twitter.com/i/web/status/1319031118755135503',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [97, 120]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2303101,
#     'id_str': '2303101',
#     'name': 'Greg Bolcer',
#     'screen_name': 'gbolcer',
#     'location': 'Orange County, CA',
#     'description': 'computer geek, semi-corporate stooge with a brain for math, finesse with computers, the eyes of an artist, and the heart of an entrepreneur',
#     'url': 'http://t.co/hXj4WTV9qJ',
#     'entities': {'url': {'urls': [{'url': 'http://t.co/hXj4WTV9qJ',
#         'expanded_url': 'http://bolcer.org/',
#         'display_url': 'bolcer.org',
#         'indices': [0, 22]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 166,
#     'friends_count': 604,
#     'listed_count': 4,
#     'created_at': 'Mon Mar 26 14:08:05 +0000 2007',
#     'favourites_count': 399,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1046,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '9AE4E8',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/29959562/Greg-8_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/29959562/Greg-8_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2303101/1402090619',
#     'profile_link_color': '77778C',
#     'profile_sidebar_border_color': '87BC44',
#     'profile_sidebar_fill_color': 'E0FF92',
#     'profile_text_color': '000000',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:41:34 +0000 2020',
#    'id': 1319031095304781824,
#    'id_str': '1319031095304781824',
#    'text': "We're always on the lookout for new books for our #DataScience series. Please DM me if you have an idea you would l… https://t.co/TdpDhU8YCn",
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'DataScience', 'indices': [50, 62]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/TdpDhU8YCn',
#       'expanded_url': 'https://twitter.com/i/web/status/1319031095304781824',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 3596301683,
#     'id_str': '3596301683',
#     'name': 'Rob Calver',
#     'screen_name': 'RobCalver5',
#     'location': '',
#     'description': 'Senior Publisher of #Mathematics, #Statistics, and #Physics books at @CRCPress. Opinions are my own. #rstats #datascience @tandfSTEM @CRC_MathStats',
#     'url': 'https://t.co/zg0X9x23ZH',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/zg0X9x23ZH',
#         'expanded_url': 'https://www.routledge.com/statistics',
#         'display_url': 'routledge.com/statistics',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1124,
#     'friends_count': 1581,
#     'listed_count': 22,
#     'created_at': 'Wed Sep 09 08:00:56 +0000 2015',
#     'favourites_count': 5758,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 2854,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/976918559866617862/nZRveEhW_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/976918559866617862/nZRveEhW_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3596301683/1589661747',
#     'profile_link_color': '981CEB',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:41:30 +0000 2020',
#    'id': 1319031080658272258,
#    'id_str': '1319031080658272258',
#    'text': 'RT @gp_pulipaka: Machine Learning using Titanic Data. #BigData #Analytics #DataScience #AI #MachineLearning #IoT #IIoT #Python #RStats #Ten…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'BigData', 'indices': [54, 62]},
#      {'text': 'Analytics', 'indices': [63, 73]},
#      {'text': 'DataScience', 'indices': [74, 86]},
#      {'text': 'AI', 'indices': [87, 90]},
#      {'text': 'MachineLearning', 'indices': [91, 107]},
#      {'text': 'IoT', 'indices': [108, 112]},
#      {'text': 'IIoT', 'indices': [113, 118]},
#      {'text': 'Python', 'indices': [119, 126]},
#      {'text': 'RStats', 'indices': [127, 134]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'gp_pulipaka',
#       'name': 'Dr. Ganapathi Pulipaka',
#       'id': 4263007693,
#       'id_str': '4263007693',
#       'indices': [3, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://www.sankalpsaxena.com" rel="nofollow">RT #MachineLearning</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1132890775891505152,
#     'id_str': '1132890775891505152',
#     'name': 'Olivia',
#     'screen_name': '_OliviaBot',
#     'location': 'India',
#     'description': 'I retweet every mention of #MachineLearning Meet my humble daddy ❤ : @sankalp_saxena 😎',
#     'url': 'https://t.co/Sf9KtbVG2n',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/Sf9KtbVG2n',
#         'expanded_url': 'http://sankalpsaxena.com',
#         'display_url': 'sankalpsaxena.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 606,
#     'friends_count': 6,
#     'listed_count': 26,
#     'created_at': 'Mon May 27 06:06:23 +0000 2019',
#     'favourites_count': 75,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 34318,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1159212500572753920/49WAfJuf_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1159212500572753920/49WAfJuf_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1132890775891505152/1558939931',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Oct 15 14:42:51 +0000 2020',
#     'id': 1316751396193079296,
#     'id_str': '1316751396193079296',
#     'text': 'Machine Learning using Titanic Data. #BigData #Analytics #DataScience #AI #MachineLearning #IoT #IIoT #Python… https://t.co/h6Kqiy0vHO',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'BigData', 'indices': [37, 45]},
#       {'text': 'Analytics', 'indices': [46, 56]},
#       {'text': 'DataScience', 'indices': [57, 69]},
#       {'text': 'AI', 'indices': [70, 73]},
#       {'text': 'MachineLearning', 'indices': [74, 90]},
#       {'text': 'IoT', 'indices': [91, 95]},
#       {'text': 'IIoT', 'indices': [96, 101]},
#       {'text': 'Python', 'indices': [102, 109]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/h6Kqiy0vHO',
#        'expanded_url': 'https://twitter.com/i/web/status/1316751396193079296',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [111, 134]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 4263007693,
#      'id_str': '4263007693',
#      'name': 'Dr. Ganapathi Pulipaka',
#      'screen_name': 'gp_pulipaka',
#      'location': 'Redondo Beach, CA',
#      'description': 'Chief #AI #HPC Scientist | #Speaker | PostDoc CS, PhD | Bestselling #Author | 18.4M V | Top #BigData #DataScience #MachineLearning #IIoT Influencer @Onalytica',
#      'url': 'https://t.co/eYyaJsEcfw',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/eYyaJsEcfw',
#          'expanded_url': 'http://www.gppulipaka.org',
#          'display_url': 'gppulipaka.org',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 101394,
#      'friends_count': 25866,
#      'listed_count': 3495,
#      'created_at': 'Tue Nov 17 02:19:09 +0000 2015',
#      'favourites_count': 9,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 58478,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1315479714790694912/MQmkjugW_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1315479714790694912/MQmkjugW_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4263007693/1599491057',
#      'profile_link_color': 'DD2E44',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 131,
#     'favorite_count': 76,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 131,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.108,
#   'max_id': 1319031297503825920,
#   'max_id_str': '1319031297503825920',
#   'next_results': '?max_id=1319031080658272257&q=%23DataScience&include_entities=1',
#   'query': '%23DataScience',
#   'refresh_url': '?since_id=1319031297503825920&q=%23DataScience&include_entities=1',
#   'count': 15,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %%
# try using the count argument -- confirm that it returns the right number of results
len(find_hashtag('#DataScience', count=50)['statuses'])
# Out:
# 50

# %%
# and use the search_type argument as well
find_hashtag('#DataScience', search_type='recent')
# Out:
# {'statuses': [{'created_at': 'Wed Oct 21 21:42:22 +0000 2020',
#    'id': 1319031297503825920,
#    'id_str': '1319031297503825920',
#    'text': 'RT @David_Analytics: Announcing: Graph-Native Machine Learning in Neo4j!\nBy Alicia Frame and @amyhodler You gotta check it out before your…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'David_Analytics',
#       'name': 'David Vessie',
#       'id': 1446596928,
#       'id_str': '1446596928',
#       'indices': [3, 19]},
#      {'screen_name': 'amyhodler',
#       'name': 'Amy Hodler',
#       'id': 48175748,
#       'id_str': '48175748',
#       'indices': [93, 103]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://youngapp.co" rel="nofollow">Yap Code Learn</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1221691042325508098,
#     'id_str': '1221691042325508098',
#     'name': 'API Learn Community',
#     'screen_name': 'api_learnn',
#     'location': '',
#     'description': 'Share great ressources for learn next-gen API on NodeJS 💪. #serverless #graphql 🙌🙌',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2127,
#     'friends_count': 5001,
#     'listed_count': 19,
#     'created_at': 'Mon Jan 27 07:07:15 +0000 2020',
#     'favourites_count': 501,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 34797,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1261829900534775809/7hzVnb57_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1261829900534775809/7hzVnb57_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1221691042325508098/1580394962',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 21:12:07 +0000 2020',
#     'id': 1319023684930199560,
#     'id_str': '1319023684930199560',
#     'text': 'Announcing: Graph-Native Machine Learning in Neo4j!\nBy Alicia Frame and @amyhodler You gotta check it out before yo… https://t.co/Fm7NzgMpay',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'amyhodler',
#        'name': 'Amy Hodler',
#        'id': 48175748,
#        'id_str': '48175748',
#        'indices': [72, 82]}],
#      'urls': [{'url': 'https://t.co/Fm7NzgMpay',
#        'expanded_url': 'https://twitter.com/i/web/status/1319023684930199560',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://www.linkedin.com/" rel="nofollow">LinkedIn</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1446596928,
#      'id_str': '1446596928',
#      'name': 'David Vessie',
#      'screen_name': 'David_Analytics',
#      'location': 'Aliso Viejo, CA',
#      'description': 'Neo4j Buying advisor, Socal, AZ, NV, leader in Graph databases',
#      'url': 'https://t.co/JSIaZFJEaE',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/JSIaZFJEaE',
#          'expanded_url': 'https://neo4j.com/',
#          'display_url': 'neo4j.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 183,
#      'friends_count': 389,
#      'listed_count': 7,
#      'created_at': 'Tue May 21 15:23:43 +0000 2013',
#      'favourites_count': 12,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 527,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1082399550420045824/bam03M5v_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1082399550420045824/bam03M5v_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1446596928/1427823210',
#      'profile_link_color': '3B94D9',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:42:10 +0000 2020',
#    'id': 1319031248506028034,
#    'id_str': '1319031248506028034',
#    'text': 'RT @ProgrammingHero: Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.\n.\n#…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ProgrammingHero',
#       'name': 'Programming Hero',
#       'id': 1254869948796674048,
#       'id_str': '1254869948796674048',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://hubofco.de" rel="nofollow">hubofml</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 3040871649,
#     'id_str': '3040871649',
#     'name': 'HubofMachineLearning',
#     'screen_name': 'hubofml',
#     'location': 'Germany ',
#     'description': "Once a month, you'll get a newsletter from me with lots of exciting stuff on data science, engineering, and machine learning. Subscribe here 👉 https://t.co/VRnN9grEfw",
#     'url': 'https://t.co/VRnN9grEfw',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/VRnN9grEfw',
#         'expanded_url': 'http://bit.ly/hubofml1',
#         'display_url': 'bit.ly/hubofml1',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/VRnN9grEfw',
#         'expanded_url': 'http://bit.ly/hubofml1',
#         'display_url': 'bit.ly/hubofml1',
#         'indices': [143, 166]}]}},
#     'protected': False,
#     'followers_count': 6194,
#     'friends_count': 10,
#     'listed_count': 128,
#     'created_at': 'Mon Feb 16 15:33:55 +0000 2015',
#     'favourites_count': 32108,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 267957,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1254334743333818373/F3xeh1db_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1254334743333818373/F3xeh1db_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3040871649/1587892795',
#     'profile_link_color': '4A913C',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 21:41:43 +0000 2020',
#     'id': 1319031134135545856,
#     'id_str': '1319031134135545856',
#     'text': 'Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.… https://t.co/ezaBFrIrOl',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/ezaBFrIrOl',
#        'expanded_url': 'https://twitter.com/i/web/status/1319031134135545856',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1254869948796674048,
#      'id_str': '1254869948796674048',
#      'name': 'Programming Hero',
#      'screen_name': 'ProgrammingHero',
#      'location': '',
#      'description': 'Coding Just Got Fun',
#      'url': 'https://t.co/KCaEvKJ2ZA',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/KCaEvKJ2ZA',
#          'expanded_url': 'https://www.programming-hero.com/',
#          'display_url': 'programming-hero.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 236,
#      'friends_count': 56,
#      'listed_count': 2,
#      'created_at': 'Mon Apr 27 20:28:19 +0000 2020',
#      'favourites_count': 310,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 292,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1254869948796674048/1602616573',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 7,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 7,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:42:04 +0000 2020',
#    'id': 1319031224078274560,
#    'id_str': '1319031224078274560',
#    'text': 'RT @ProgrammingHero: Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.\n.\n#…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ProgrammingHero',
#       'name': 'Programming Hero',
#       'id': 1254869948796674048,
#       'id_str': '1254869948796674048',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://techdox.nz" rel="nofollow">LinuxBot2.0</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1190726565073522694,
#     'id_str': '1190726565073522694',
#     'name': 'LinuxBot',
#     'screen_name': 'LlnuxBot',
#     'location': 'Raspberry Pi',
#     'description': 'Linux Bot | I retweet Linux | Created by @techydox\n\nhttps://t.co/DrRaUtSPGJ',
#     'url': 'https://t.co/QySTldc3HS',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/QySTldc3HS',
#         'expanded_url': 'http://www.techdox.nz',
#         'display_url': 'techdox.nz',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/DrRaUtSPGJ',
#         'expanded_url': 'https://buymeacoff.ee/techdox',
#         'display_url': 'buymeacoff.ee/techdox',
#         'indices': [52, 75]}]}},
#     'protected': False,
#     'followers_count': 3050,
#     'friends_count': 0,
#     'listed_count': 73,
#     'created_at': 'Sat Nov 02 20:25:26 +0000 2019',
#     'favourites_count': 1,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 427666,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1190727216885358597/OoGENW9l_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1190727216885358597/OoGENW9l_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1190726565073522694/1586607550',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 21:41:43 +0000 2020',
#     'id': 1319031134135545856,
#     'id_str': '1319031134135545856',
#     'text': 'Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.… https://t.co/ezaBFrIrOl',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/ezaBFrIrOl',
#        'expanded_url': 'https://twitter.com/i/web/status/1319031134135545856',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1254869948796674048,
#      'id_str': '1254869948796674048',
#      'name': 'Programming Hero',
#      'screen_name': 'ProgrammingHero',
#      'location': '',
#      'description': 'Coding Just Got Fun',
#      'url': 'https://t.co/KCaEvKJ2ZA',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/KCaEvKJ2ZA',
#          'expanded_url': 'https://www.programming-hero.com/',
#          'display_url': 'programming-hero.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 236,
#      'friends_count': 56,
#      'listed_count': 2,
#      'created_at': 'Mon Apr 27 20:28:19 +0000 2020',
#      'favourites_count': 310,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 292,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1254869948796674048/1602616573',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 7,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 7,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:42:03 +0000 2020',
#    'id': 1319031218537590784,
#    'id_str': '1319031218537590784',
#    'text': '#AMLO_21oct2020 #AMLO #ConferenciaPresidente #DivisionDeAnalisisDeDatos #DataScience #CienciaDeDatos… https://t.co/djjnT63Ki8',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'AMLO_21oct2020', 'indices': [0, 15]},
#      {'text': 'AMLO', 'indices': [16, 21]},
#      {'text': 'ConferenciaPresidente', 'indices': [22, 44]},
#      {'text': 'DivisionDeAnalisisDeDatos', 'indices': [45, 71]},
#      {'text': 'DataScience', 'indices': [72, 84]},
#      {'text': 'CienciaDeDatos', 'indices': [85, 100]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/djjnT63Ki8',
#       'expanded_url': 'https://twitter.com/i/web/status/1319031218537590784',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [102, 125]}]},
#    'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1164987784291069952,
#     'id_str': '1164987784291069952',
#     'name': 'Ricardo Pérez-Aguila',
#     'screen_name': 'neote5',
#     'location': 'Huajuapan de León, Oaxaca, MX',
#     'description': 'Socio & Científico de Datos en División de Análisis de Datos (DAD).\nSocio & Desarrollador en Soluciones Inteligentes de Análisis de Multimedios (SIAM).',
#     'url': 'https://t.co/E7xy13eNfl',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/E7xy13eNfl',
#         'expanded_url': 'http://ricardo.perez.aguila.googlepages.com',
#         'display_url': 'ricardo.perez.aguila.googlepages.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 18,
#     'friends_count': 50,
#     'listed_count': 0,
#     'created_at': 'Fri Aug 23 19:48:35 +0000 2019',
#     'favourites_count': 460,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 459,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1164988219378847747/diUuQJlm_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1164988219378847747/diUuQJlm_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'und'},
#   {'created_at': 'Wed Oct 21 21:42:00 +0000 2020',
#    'id': 1319031204553854979,
#    'id_str': '1319031204553854979',
#    'text': 'RT @Ronald_vanLoon: #DeepLearning for #Virtual Try On Clothes – Challenges and Opportunities\nby Maksym Tatariants @kdnuggets\n\nLearn more ht…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'DeepLearning', 'indices': [20, 33]},
#      {'text': 'Virtual', 'indices': [38, 46]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Ronald_vanLoon',
#       'name': 'Ronald van Loon',
#       'id': 555031989,
#       'id_str': '555031989',
#       'indices': [3, 18]},
#      {'screen_name': 'kdnuggets',
#       'name': 'KDnuggets',
#       'id': 20167623,
#       'id_str': '20167623',
#       'indices': [114, 124]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://twitter.com/datasciencebot_" rel="nofollow">TheDataScienceBot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1276058041389953024,
#     'id_str': '1276058041389953024',
#     'name': 'The Data Science Bot',
#     'screen_name': 'datasciencebot_',
#     'location': '',
#     'description': "A bot created by @PatkarSumedh to retweet hashtags #DataScience & #DataVisualization\n\nLet's learn together!\n\nMisusing hashtags and spam will not be tolerated",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1098,
#     'friends_count': 1,
#     'listed_count': 17,
#     'created_at': 'Thu Jun 25 07:42:09 +0000 2020',
#     'favourites_count': 21,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 129145,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1276064635456647168/omX9K1KU_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1276064635456647168/omX9K1KU_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1276058041389953024/1593080314',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 20:59:18 +0000 2020',
#     'id': 1319020460122775552,
#     'id_str': '1319020460122775552',
#     'text': '#DeepLearning for #Virtual Try On Clothes – Challenges and Opportunities\nby Maksym Tatariants @kdnuggets\n\nLearn mor… https://t.co/2uN5vi0Ku4',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'DeepLearning', 'indices': [0, 13]},
#       {'text': 'Virtual', 'indices': [18, 26]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'kdnuggets',
#        'name': 'KDnuggets',
#        'id': 20167623,
#        'id_str': '20167623',
#        'indices': [94, 104]}],
#      'urls': [{'url': 'https://t.co/2uN5vi0Ku4',
#        'expanded_url': 'https://twitter.com/i/web/status/1319020460122775552',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 555031989,
#      'id_str': '555031989',
#      'name': 'Ronald van Loon',
#      'screen_name': 'Ronald_vanLoon',
#      'location': 'The Netherlands',
#      'description': 'Helping data driven companies generating value•Top10Influencer #AI #BigData #DataScience #IoT #MachineLearning #Analytics #Cloud #5G',
#      'url': 'https://t.co/AfBzeHuLQM',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/AfBzeHuLQM',
#          'expanded_url': 'https://linktr.ee/RonaldvanLoon',
#          'display_url': 'linktr.ee/RonaldvanLoon',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 234035,
#      'friends_count': 182815,
#      'listed_count': 5487,
#      'created_at': 'Mon Apr 16 07:55:31 +0000 2012',
#      'favourites_count': 183076,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 90756,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1107936345769607169/sJKWJd7g_normal.png',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1107936345769607169/sJKWJd7g_normal.png',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/555031989/1504691055',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 6,
#     'favorite_count': 6,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 6,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:41:48 +0000 2020',
#    'id': 1319031156524916739,
#    'id_str': '1319031156524916739',
#    'text': 'RT @ProgrammingHero: Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.\n.\n#…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ProgrammingHero',
#       'name': 'Programming Hero',
#       'id': 1254869948796674048,
#       'id_str': '1254869948796674048',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://dreamsofimran.in" rel="nofollow">TheDeveloperBot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1250164632968298497,
#     'id_str': '1250164632968298497',
#     'name': 'The Developer Bot',
#     'screen_name': 'TheDeveloperBot',
#     'location': '',
#     'description': "I'm a bot created by @DreamsOfImran with a little bit of NodeJs and lots of ❤️\nI like and retweet posts related to #javascript, #vuejs, #reactjs, #Nodejs & etc",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1832,
#     'friends_count': 1,
#     'listed_count': 41,
#     'created_at': 'Tue Apr 14 20:51:03 +0000 2020',
#     'favourites_count': 124780,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 342016,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1250454907871580162/Al-vkUN1_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1250454907871580162/Al-vkUN1_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1250164632968298497/1586966908',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 21:41:43 +0000 2020',
#     'id': 1319031134135545856,
#     'id_str': '1319031134135545856',
#     'text': 'Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.… https://t.co/ezaBFrIrOl',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/ezaBFrIrOl',
#        'expanded_url': 'https://twitter.com/i/web/status/1319031134135545856',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1254869948796674048,
#      'id_str': '1254869948796674048',
#      'name': 'Programming Hero',
#      'screen_name': 'ProgrammingHero',
#      'location': '',
#      'description': 'Coding Just Got Fun',
#      'url': 'https://t.co/KCaEvKJ2ZA',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/KCaEvKJ2ZA',
#          'expanded_url': 'https://www.programming-hero.com/',
#          'display_url': 'programming-hero.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 236,
#      'friends_count': 56,
#      'listed_count': 2,
#      'created_at': 'Mon Apr 27 20:28:19 +0000 2020',
#      'favourites_count': 310,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 292,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1254869948796674048/1602616573',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 7,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 7,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:41:48 +0000 2020',
#    'id': 1319031156457852932,
#    'id_str': '1319031156457852932',
#    'text': 'RT @ProgrammingHero: Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.\n.\n#…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ProgrammingHero',
#       'name': 'Programming Hero',
#       'id': 1254869948796674048,
#       'id_str': '1254869948796674048',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://localhost.com" rel="nofollow">Serverless Tweet/Retweet Bot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 971620109197312000,
#     'id_str': '971620109197312000',
#     'name': 'Serverless Fan',
#     'screen_name': 'ServerlessFan',
#     'location': 'Sri Lanka',
#     'description': '#Serverless #Computing',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 3289,
#     'friends_count': 6,
#     'listed_count': 125,
#     'created_at': 'Thu Mar 08 05:34:20 +0000 2018',
#     'favourites_count': 7,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 272197,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/973611685822058497/yRRo9D52_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/973611685822058497/yRRo9D52_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/971620109197312000/1525426121',
#     'profile_link_color': '000000',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 21:41:43 +0000 2020',
#     'id': 1319031134135545856,
#     'id_str': '1319031134135545856',
#     'text': 'Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.… https://t.co/ezaBFrIrOl',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/ezaBFrIrOl',
#        'expanded_url': 'https://twitter.com/i/web/status/1319031134135545856',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1254869948796674048,
#      'id_str': '1254869948796674048',
#      'name': 'Programming Hero',
#      'screen_name': 'ProgrammingHero',
#      'location': '',
#      'description': 'Coding Just Got Fun',
#      'url': 'https://t.co/KCaEvKJ2ZA',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/KCaEvKJ2ZA',
#          'expanded_url': 'https://www.programming-hero.com/',
#          'display_url': 'programming-hero.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 236,
#      'friends_count': 56,
#      'listed_count': 2,
#      'created_at': 'Mon Apr 27 20:28:19 +0000 2020',
#      'favourites_count': 310,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 292,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1254869948796674048/1602616573',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 7,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 7,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:41:46 +0000 2020',
#    'id': 1319031148257939457,
#    'id_str': '1319031148257939457',
#    'text': 'RT @ProgrammingHero: Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.\n.\n#…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ProgrammingHero',
#       'name': 'Programming Hero',
#       'id': 1254869948796674048,
#       'id_str': '1254869948796674048',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://occlude.netlify.app/" rel="nofollow">OccludejsBot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1275056773443973124,
#     'id_str': '1275056773443973124',
#     'name': 'Candis',
#     'screen_name': 'Women_who_code',
#     'location': 'bootcamp',
#     'description': '24💐 • MERN Stack Developer • React Geek • ☕ Coffee • 🦄 Unicorn • SDE @nytimes',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 734,
#     'friends_count': 25,
#     'listed_count': 19,
#     'created_at': 'Mon Jun 22 13:23:34 +0000 2020',
#     'favourites_count': 236,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 97618,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1314621116191629312/vQLAcsnS_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1314621116191629312/vQLAcsnS_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1275056773443973124/1599976745',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 21:41:43 +0000 2020',
#     'id': 1319031134135545856,
#     'id_str': '1319031134135545856',
#     'text': 'Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.… https://t.co/ezaBFrIrOl',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/ezaBFrIrOl',
#        'expanded_url': 'https://twitter.com/i/web/status/1319031134135545856',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1254869948796674048,
#      'id_str': '1254869948796674048',
#      'name': 'Programming Hero',
#      'screen_name': 'ProgrammingHero',
#      'location': '',
#      'description': 'Coding Just Got Fun',
#      'url': 'https://t.co/KCaEvKJ2ZA',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/KCaEvKJ2ZA',
#          'expanded_url': 'https://www.programming-hero.com/',
#          'display_url': 'programming-hero.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 236,
#      'friends_count': 56,
#      'listed_count': 2,
#      'created_at': 'Mon Apr 27 20:28:19 +0000 2020',
#      'favourites_count': 310,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 292,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1254869948796674048/1602616573',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 7,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 7,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:41:46 +0000 2020',
#    'id': 1319031147964305419,
#    'id_str': '1319031147964305419',
#    'text': 'RT @ProgrammingHero: Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.\n.\n#…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ProgrammingHero',
#       'name': 'Programming Hero',
#       'id': 1254869948796674048,
#       'id_str': '1254869948796674048',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://nlogn.in" rel="nofollow">nlognrobot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1260062769543434240,
#     'id_str': '1260062769543434240',
#     'name': '#100DaysOfCode',
#     'screen_name': 'nlognbot',
#     'location': 'Server',
#     'description': "Hi, I'm a bot that retweets #100daysofcode     \n                 \nP.S. I was created by @NlognHQ follow them.",
#     'url': 'https://t.co/PujHDQomPA',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/PujHDQomPA',
#         'expanded_url': 'http://nlogn.in',
#         'display_url': 'nlogn.in',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 4376,
#     'friends_count': 3,
# ...
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1254869948796674048,
#     'id_str': '1254869948796674048',
#     'name': 'Programming Hero',
#     'screen_name': 'ProgrammingHero',
#     'location': '',
#     'description': 'Coding Just Got Fun',
#     'url': 'https://t.co/KCaEvKJ2ZA',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/KCaEvKJ2ZA',
#         'expanded_url': 'https://www.programming-hero.com/',
#         'display_url': 'programming-hero.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 236,
#     'friends_count': 56,
#     'listed_count': 2,
#     'created_at': 'Mon Apr 27 20:28:19 +0000 2020',
#     'favourites_count': 310,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 292,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1254869948796674048/1602616573',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 7,
#    'favorite_count': 2,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:41:39 +0000 2020',
#    'id': 1319031118755135503,
#    'id_str': '1319031118755135503',
#    'text': 'Bitvore: Implementing AI in Financing: The hottest new commodity in finance. via @TDataScience:… https://t.co/ZI4ceSpN0H',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'TDataScience',
#       'name': 'Towards Data Science',
#       'id': 788898706586275840,
#       'id_str': '788898706586275840',
#       'indices': [81, 94]}],
#     'urls': [{'url': 'https://t.co/ZI4ceSpN0H',
#       'expanded_url': 'https://twitter.com/i/web/status/1319031118755135503',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [97, 120]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2303101,
#     'id_str': '2303101',
#     'name': 'Greg Bolcer',
#     'screen_name': 'gbolcer',
#     'location': 'Orange County, CA',
#     'description': 'computer geek, semi-corporate stooge with a brain for math, finesse with computers, the eyes of an artist, and the heart of an entrepreneur',
#     'url': 'http://t.co/hXj4WTV9qJ',
#     'entities': {'url': {'urls': [{'url': 'http://t.co/hXj4WTV9qJ',
#         'expanded_url': 'http://bolcer.org/',
#         'display_url': 'bolcer.org',
#         'indices': [0, 22]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 166,
#     'friends_count': 604,
#     'listed_count': 4,
#     'created_at': 'Mon Mar 26 14:08:05 +0000 2007',
#     'favourites_count': 399,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1046,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '9AE4E8',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/29959562/Greg-8_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/29959562/Greg-8_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2303101/1402090619',
#     'profile_link_color': '77778C',
#     'profile_sidebar_border_color': '87BC44',
#     'profile_sidebar_fill_color': 'E0FF92',
#     'profile_text_color': '000000',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:41:34 +0000 2020',
#    'id': 1319031095304781824,
#    'id_str': '1319031095304781824',
#    'text': "We're always on the lookout for new books for our #DataScience series. Please DM me if you have an idea you would l… https://t.co/TdpDhU8YCn",
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'DataScience', 'indices': [50, 62]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/TdpDhU8YCn',
#       'expanded_url': 'https://twitter.com/i/web/status/1319031095304781824',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 3596301683,
#     'id_str': '3596301683',
#     'name': 'Rob Calver',
#     'screen_name': 'RobCalver5',
#     'location': '',
#     'description': 'Senior Publisher of #Mathematics, #Statistics, and #Physics books at @CRCPress. Opinions are my own. #rstats #datascience @tandfSTEM @CRC_MathStats',
#     'url': 'https://t.co/zg0X9x23ZH',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/zg0X9x23ZH',
#         'expanded_url': 'https://www.routledge.com/statistics',
#         'display_url': 'routledge.com/statistics',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1124,
#     'friends_count': 1581,
#     'listed_count': 22,
#     'created_at': 'Wed Sep 09 08:00:56 +0000 2015',
#     'favourites_count': 5758,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 2854,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/976918559866617862/nZRveEhW_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/976918559866617862/nZRveEhW_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3596301683/1589661747',
#     'profile_link_color': '981CEB',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:41:30 +0000 2020',
#    'id': 1319031080658272258,
#    'id_str': '1319031080658272258',
#    'text': 'RT @gp_pulipaka: Machine Learning using Titanic Data. #BigData #Analytics #DataScience #AI #MachineLearning #IoT #IIoT #Python #RStats #Ten…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'BigData', 'indices': [54, 62]},
#      {'text': 'Analytics', 'indices': [63, 73]},
#      {'text': 'DataScience', 'indices': [74, 86]},
#      {'text': 'AI', 'indices': [87, 90]},
#      {'text': 'MachineLearning', 'indices': [91, 107]},
#      {'text': 'IoT', 'indices': [108, 112]},
#      {'text': 'IIoT', 'indices': [113, 118]},
#      {'text': 'Python', 'indices': [119, 126]},
#      {'text': 'RStats', 'indices': [127, 134]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'gp_pulipaka',
#       'name': 'Dr. Ganapathi Pulipaka',
#       'id': 4263007693,
#       'id_str': '4263007693',
#       'indices': [3, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://www.sankalpsaxena.com" rel="nofollow">RT #MachineLearning</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1132890775891505152,
#     'id_str': '1132890775891505152',
#     'name': 'Olivia',
#     'screen_name': '_OliviaBot',
#     'location': 'India',
#     'description': 'I retweet every mention of #MachineLearning Meet my humble daddy ❤ : @sankalp_saxena 😎',
#     'url': 'https://t.co/Sf9KtbVG2n',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/Sf9KtbVG2n',
#         'expanded_url': 'http://sankalpsaxena.com',
#         'display_url': 'sankalpsaxena.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 606,
#     'friends_count': 6,
#     'listed_count': 26,
#     'created_at': 'Mon May 27 06:06:23 +0000 2019',
#     'favourites_count': 75,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 34318,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1159212500572753920/49WAfJuf_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1159212500572753920/49WAfJuf_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1132890775891505152/1558939931',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Oct 15 14:42:51 +0000 2020',
#     'id': 1316751396193079296,
#     'id_str': '1316751396193079296',
#     'text': 'Machine Learning using Titanic Data. #BigData #Analytics #DataScience #AI #MachineLearning #IoT #IIoT #Python… https://t.co/h6Kqiy0vHO',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'BigData', 'indices': [37, 45]},
#       {'text': 'Analytics', 'indices': [46, 56]},
#       {'text': 'DataScience', 'indices': [57, 69]},
#       {'text': 'AI', 'indices': [70, 73]},
#       {'text': 'MachineLearning', 'indices': [74, 90]},
#       {'text': 'IoT', 'indices': [91, 95]},
#       {'text': 'IIoT', 'indices': [96, 101]},
#       {'text': 'Python', 'indices': [102, 109]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/h6Kqiy0vHO',
#        'expanded_url': 'https://twitter.com/i/web/status/1316751396193079296',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [111, 134]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 4263007693,
#      'id_str': '4263007693',
#      'name': 'Dr. Ganapathi Pulipaka',
#      'screen_name': 'gp_pulipaka',
#      'location': 'Redondo Beach, CA',
#      'description': 'Chief #AI #HPC Scientist | #Speaker | PostDoc CS, PhD | Bestselling #Author | 18.4M V | Top #BigData #DataScience #MachineLearning #IIoT Influencer @Onalytica',
#      'url': 'https://t.co/eYyaJsEcfw',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/eYyaJsEcfw',
#          'expanded_url': 'http://www.gppulipaka.org',
#          'display_url': 'gppulipaka.org',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 101394,
#      'friends_count': 25866,
#      'listed_count': 3495,
#      'created_at': 'Tue Nov 17 02:19:09 +0000 2015',
#      'favourites_count': 9,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 58478,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1315479714790694912/MQmkjugW_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1315479714790694912/MQmkjugW_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4263007693/1599491057',
#      'profile_link_color': 'DD2E44',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 131,
#     'favorite_count': 76,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 131,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.118,
#   'max_id': 1319031297503825920,
#   'max_id_str': '1319031297503825920',
#   'next_results': '?max_id=1319031080658272257&q=%23DataScience&include_entities=1',
#   'query': '%23DataScience',
#   'refresh_url': '?since_id=1319031297503825920&q=%23DataScience&include_entities=1',
#   'count': 15,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %%
# and for good measure, we'll use both
find_hashtag('#DataScience', count=50, search_type='popular')
# Out:
# {'statuses': [{'created_at': 'Wed Oct 21 21:42:22 +0000 2020',
#    'id': 1319031297503825920,
#    'id_str': '1319031297503825920',
#    'text': 'RT @David_Analytics: Announcing: Graph-Native Machine Learning in Neo4j!\nBy Alicia Frame and @amyhodler You gotta check it out before your…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'David_Analytics',
#       'name': 'David Vessie',
#       'id': 1446596928,
#       'id_str': '1446596928',
#       'indices': [3, 19]},
#      {'screen_name': 'amyhodler',
#       'name': 'Amy Hodler',
#       'id': 48175748,
#       'id_str': '48175748',
#       'indices': [93, 103]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://youngapp.co" rel="nofollow">Yap Code Learn</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1221691042325508098,
#     'id_str': '1221691042325508098',
#     'name': 'API Learn Community',
#     'screen_name': 'api_learnn',
#     'location': '',
#     'description': 'Share great ressources for learn next-gen API on NodeJS 💪. #serverless #graphql 🙌🙌',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 2127,
#     'friends_count': 5001,
#     'listed_count': 19,
#     'created_at': 'Mon Jan 27 07:07:15 +0000 2020',
#     'favourites_count': 501,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 34797,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1261829900534775809/7hzVnb57_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1261829900534775809/7hzVnb57_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1221691042325508098/1580394962',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 21:12:07 +0000 2020',
#     'id': 1319023684930199560,
#     'id_str': '1319023684930199560',
#     'text': 'Announcing: Graph-Native Machine Learning in Neo4j!\nBy Alicia Frame and @amyhodler You gotta check it out before yo… https://t.co/Fm7NzgMpay',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'amyhodler',
#        'name': 'Amy Hodler',
#        'id': 48175748,
#        'id_str': '48175748',
#        'indices': [72, 82]}],
#      'urls': [{'url': 'https://t.co/Fm7NzgMpay',
#        'expanded_url': 'https://twitter.com/i/web/status/1319023684930199560',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://www.linkedin.com/" rel="nofollow">LinkedIn</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1446596928,
#      'id_str': '1446596928',
#      'name': 'David Vessie',
#      'screen_name': 'David_Analytics',
#      'location': 'Aliso Viejo, CA',
#      'description': 'Neo4j Buying advisor, Socal, AZ, NV, leader in Graph databases',
#      'url': 'https://t.co/JSIaZFJEaE',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/JSIaZFJEaE',
#          'expanded_url': 'https://neo4j.com/',
#          'display_url': 'neo4j.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 183,
#      'friends_count': 389,
#      'listed_count': 7,
#      'created_at': 'Tue May 21 15:23:43 +0000 2013',
#      'favourites_count': 12,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 527,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1082399550420045824/bam03M5v_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1082399550420045824/bam03M5v_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1446596928/1427823210',
#      'profile_link_color': '3B94D9',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:42:10 +0000 2020',
#    'id': 1319031248506028034,
#    'id_str': '1319031248506028034',
#    'text': 'RT @ProgrammingHero: Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.\n.\n#…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ProgrammingHero',
#       'name': 'Programming Hero',
#       'id': 1254869948796674048,
#       'id_str': '1254869948796674048',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://hubofco.de" rel="nofollow">hubofml</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 3040871649,
#     'id_str': '3040871649',
#     'name': 'HubofMachineLearning',
#     'screen_name': 'hubofml',
#     'location': 'Germany ',
#     'description': "Once a month, you'll get a newsletter from me with lots of exciting stuff on data science, engineering, and machine learning. Subscribe here 👉 https://t.co/VRnN9grEfw",
#     'url': 'https://t.co/VRnN9grEfw',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/VRnN9grEfw',
#         'expanded_url': 'http://bit.ly/hubofml1',
#         'display_url': 'bit.ly/hubofml1',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/VRnN9grEfw',
#         'expanded_url': 'http://bit.ly/hubofml1',
#         'display_url': 'bit.ly/hubofml1',
#         'indices': [143, 166]}]}},
#     'protected': False,
#     'followers_count': 6194,
#     'friends_count': 10,
#     'listed_count': 128,
#     'created_at': 'Mon Feb 16 15:33:55 +0000 2015',
#     'favourites_count': 32108,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 267957,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1254334743333818373/F3xeh1db_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1254334743333818373/F3xeh1db_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3040871649/1587892795',
#     'profile_link_color': '4A913C',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 21:41:43 +0000 2020',
#     'id': 1319031134135545856,
#     'id_str': '1319031134135545856',
#     'text': 'Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.… https://t.co/ezaBFrIrOl',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/ezaBFrIrOl',
#        'expanded_url': 'https://twitter.com/i/web/status/1319031134135545856',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1254869948796674048,
#      'id_str': '1254869948796674048',
#      'name': 'Programming Hero',
#      'screen_name': 'ProgrammingHero',
#      'location': '',
#      'description': 'Coding Just Got Fun',
#      'url': 'https://t.co/KCaEvKJ2ZA',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/KCaEvKJ2ZA',
#          'expanded_url': 'https://www.programming-hero.com/',
#          'display_url': 'programming-hero.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 236,
#      'friends_count': 56,
#      'listed_count': 2,
#      'created_at': 'Mon Apr 27 20:28:19 +0000 2020',
#      'favourites_count': 310,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 292,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1254869948796674048/1602616573',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 7,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 7,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:42:04 +0000 2020',
#    'id': 1319031224078274560,
#    'id_str': '1319031224078274560',
#    'text': 'RT @ProgrammingHero: Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.\n.\n#…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ProgrammingHero',
#       'name': 'Programming Hero',
#       'id': 1254869948796674048,
#       'id_str': '1254869948796674048',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://techdox.nz" rel="nofollow">LinuxBot2.0</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1190726565073522694,
#     'id_str': '1190726565073522694',
#     'name': 'LinuxBot',
#     'screen_name': 'LlnuxBot',
#     'location': 'Raspberry Pi',
#     'description': 'Linux Bot | I retweet Linux | Created by @techydox\n\nhttps://t.co/DrRaUtSPGJ',
#     'url': 'https://t.co/QySTldc3HS',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/QySTldc3HS',
#         'expanded_url': 'http://www.techdox.nz',
#         'display_url': 'techdox.nz',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/DrRaUtSPGJ',
#         'expanded_url': 'https://buymeacoff.ee/techdox',
#         'display_url': 'buymeacoff.ee/techdox',
#         'indices': [52, 75]}]}},
#     'protected': False,
#     'followers_count': 3050,
#     'friends_count': 0,
#     'listed_count': 73,
#     'created_at': 'Sat Nov 02 20:25:26 +0000 2019',
#     'favourites_count': 1,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 427666,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1190727216885358597/OoGENW9l_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1190727216885358597/OoGENW9l_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1190726565073522694/1586607550',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 21:41:43 +0000 2020',
#     'id': 1319031134135545856,
#     'id_str': '1319031134135545856',
#     'text': 'Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.… https://t.co/ezaBFrIrOl',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/ezaBFrIrOl',
#        'expanded_url': 'https://twitter.com/i/web/status/1319031134135545856',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1254869948796674048,
#      'id_str': '1254869948796674048',
#      'name': 'Programming Hero',
#      'screen_name': 'ProgrammingHero',
#      'location': '',
#      'description': 'Coding Just Got Fun',
#      'url': 'https://t.co/KCaEvKJ2ZA',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/KCaEvKJ2ZA',
#          'expanded_url': 'https://www.programming-hero.com/',
#          'display_url': 'programming-hero.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 236,
#      'friends_count': 56,
#      'listed_count': 2,
#      'created_at': 'Mon Apr 27 20:28:19 +0000 2020',
#      'favourites_count': 310,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 292,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1254869948796674048/1602616573',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 7,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 7,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:42:03 +0000 2020',
#    'id': 1319031218537590784,
#    'id_str': '1319031218537590784',
#    'text': '#AMLO_21oct2020 #AMLO #ConferenciaPresidente #DivisionDeAnalisisDeDatos #DataScience #CienciaDeDatos… https://t.co/djjnT63Ki8',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'AMLO_21oct2020', 'indices': [0, 15]},
#      {'text': 'AMLO', 'indices': [16, 21]},
#      {'text': 'ConferenciaPresidente', 'indices': [22, 44]},
#      {'text': 'DivisionDeAnalisisDeDatos', 'indices': [45, 71]},
#      {'text': 'DataScience', 'indices': [72, 84]},
#      {'text': 'CienciaDeDatos', 'indices': [85, 100]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/djjnT63Ki8',
#       'expanded_url': 'https://twitter.com/i/web/status/1319031218537590784',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [102, 125]}]},
#    'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1164987784291069952,
#     'id_str': '1164987784291069952',
#     'name': 'Ricardo Pérez-Aguila',
#     'screen_name': 'neote5',
#     'location': 'Huajuapan de León, Oaxaca, MX',
#     'description': 'Socio & Científico de Datos en División de Análisis de Datos (DAD).\nSocio & Desarrollador en Soluciones Inteligentes de Análisis de Multimedios (SIAM).',
#     'url': 'https://t.co/E7xy13eNfl',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/E7xy13eNfl',
#         'expanded_url': 'http://ricardo.perez.aguila.googlepages.com',
#         'display_url': 'ricardo.perez.aguila.googlepages.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 18,
#     'friends_count': 50,
#     'listed_count': 0,
#     'created_at': 'Fri Aug 23 19:48:35 +0000 2019',
#     'favourites_count': 460,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 459,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1164988219378847747/diUuQJlm_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1164988219378847747/diUuQJlm_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'und'},
#   {'created_at': 'Wed Oct 21 21:42:00 +0000 2020',
#    'id': 1319031204553854979,
#    'id_str': '1319031204553854979',
#    'text': 'RT @Ronald_vanLoon: #DeepLearning for #Virtual Try On Clothes – Challenges and Opportunities\nby Maksym Tatariants @kdnuggets\n\nLearn more ht…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'DeepLearning', 'indices': [20, 33]},
#      {'text': 'Virtual', 'indices': [38, 46]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Ronald_vanLoon',
#       'name': 'Ronald van Loon',
#       'id': 555031989,
#       'id_str': '555031989',
#       'indices': [3, 18]},
#      {'screen_name': 'kdnuggets',
#       'name': 'KDnuggets',
#       'id': 20167623,
#       'id_str': '20167623',
#       'indices': [114, 124]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://twitter.com/datasciencebot_" rel="nofollow">TheDataScienceBot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1276058041389953024,
#     'id_str': '1276058041389953024',
#     'name': 'The Data Science Bot',
#     'screen_name': 'datasciencebot_',
#     'location': '',
#     'description': "A bot created by @PatkarSumedh to retweet hashtags #DataScience & #DataVisualization\n\nLet's learn together!\n\nMisusing hashtags and spam will not be tolerated",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1098,
#     'friends_count': 1,
#     'listed_count': 17,
#     'created_at': 'Thu Jun 25 07:42:09 +0000 2020',
#     'favourites_count': 21,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 129145,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1276064635456647168/omX9K1KU_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1276064635456647168/omX9K1KU_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1276058041389953024/1593080314',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 20:59:18 +0000 2020',
#     'id': 1319020460122775552,
#     'id_str': '1319020460122775552',
#     'text': '#DeepLearning for #Virtual Try On Clothes – Challenges and Opportunities\nby Maksym Tatariants @kdnuggets\n\nLearn mor… https://t.co/2uN5vi0Ku4',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'DeepLearning', 'indices': [0, 13]},
#       {'text': 'Virtual', 'indices': [18, 26]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'kdnuggets',
#        'name': 'KDnuggets',
#        'id': 20167623,
#        'id_str': '20167623',
#        'indices': [94, 104]}],
#      'urls': [{'url': 'https://t.co/2uN5vi0Ku4',
#        'expanded_url': 'https://twitter.com/i/web/status/1319020460122775552',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 555031989,
#      'id_str': '555031989',
#      'name': 'Ronald van Loon',
#      'screen_name': 'Ronald_vanLoon',
#      'location': 'The Netherlands',
#      'description': 'Helping data driven companies generating value•Top10Influencer #AI #BigData #DataScience #IoT #MachineLearning #Analytics #Cloud #5G',
#      'url': 'https://t.co/AfBzeHuLQM',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/AfBzeHuLQM',
#          'expanded_url': 'https://linktr.ee/RonaldvanLoon',
#          'display_url': 'linktr.ee/RonaldvanLoon',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 234035,
#      'friends_count': 182815,
#      'listed_count': 5487,
#      'created_at': 'Mon Apr 16 07:55:31 +0000 2012',
#      'favourites_count': 183076,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 90756,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1107936345769607169/sJKWJd7g_normal.png',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1107936345769607169/sJKWJd7g_normal.png',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/555031989/1504691055',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 6,
#     'favorite_count': 6,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 6,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:41:48 +0000 2020',
#    'id': 1319031156524916739,
#    'id_str': '1319031156524916739',
#    'text': 'RT @ProgrammingHero: Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.\n.\n#…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ProgrammingHero',
#       'name': 'Programming Hero',
#       'id': 1254869948796674048,
#       'id_str': '1254869948796674048',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://dreamsofimran.in" rel="nofollow">TheDeveloperBot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1250164632968298497,
#     'id_str': '1250164632968298497',
#     'name': 'The Developer Bot',
#     'screen_name': 'TheDeveloperBot',
#     'location': '',
#     'description': "I'm a bot created by @DreamsOfImran with a little bit of NodeJs and lots of ❤️\nI like and retweet posts related to #javascript, #vuejs, #reactjs, #Nodejs & etc",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1832,
#     'friends_count': 1,
#     'listed_count': 41,
#     'created_at': 'Tue Apr 14 20:51:03 +0000 2020',
#     'favourites_count': 124780,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 342016,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1250454907871580162/Al-vkUN1_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1250454907871580162/Al-vkUN1_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1250164632968298497/1586966908',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 21:41:43 +0000 2020',
#     'id': 1319031134135545856,
#     'id_str': '1319031134135545856',
#     'text': 'Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.… https://t.co/ezaBFrIrOl',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/ezaBFrIrOl',
#        'expanded_url': 'https://twitter.com/i/web/status/1319031134135545856',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1254869948796674048,
#      'id_str': '1254869948796674048',
#      'name': 'Programming Hero',
#      'screen_name': 'ProgrammingHero',
#      'location': '',
#      'description': 'Coding Just Got Fun',
#      'url': 'https://t.co/KCaEvKJ2ZA',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/KCaEvKJ2ZA',
#          'expanded_url': 'https://www.programming-hero.com/',
#          'display_url': 'programming-hero.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 236,
#      'friends_count': 56,
#      'listed_count': 2,
#      'created_at': 'Mon Apr 27 20:28:19 +0000 2020',
#      'favourites_count': 310,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 292,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1254869948796674048/1602616573',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 7,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 7,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:41:48 +0000 2020',
#    'id': 1319031156457852932,
#    'id_str': '1319031156457852932',
#    'text': 'RT @ProgrammingHero: Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.\n.\n#…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ProgrammingHero',
#       'name': 'Programming Hero',
#       'id': 1254869948796674048,
#       'id_str': '1254869948796674048',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://localhost.com" rel="nofollow">Serverless Tweet/Retweet Bot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 971620109197312000,
#     'id_str': '971620109197312000',
#     'name': 'Serverless Fan',
#     'screen_name': 'ServerlessFan',
#     'location': 'Sri Lanka',
#     'description': '#Serverless #Computing',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 3289,
#     'friends_count': 6,
#     'listed_count': 125,
#     'created_at': 'Thu Mar 08 05:34:20 +0000 2018',
#     'favourites_count': 7,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 272197,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/973611685822058497/yRRo9D52_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/973611685822058497/yRRo9D52_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/971620109197312000/1525426121',
#     'profile_link_color': '000000',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 21:41:43 +0000 2020',
#     'id': 1319031134135545856,
#     'id_str': '1319031134135545856',
#     'text': 'Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.… https://t.co/ezaBFrIrOl',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/ezaBFrIrOl',
#        'expanded_url': 'https://twitter.com/i/web/status/1319031134135545856',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1254869948796674048,
#      'id_str': '1254869948796674048',
#      'name': 'Programming Hero',
#      'screen_name': 'ProgrammingHero',
#      'location': '',
#      'description': 'Coding Just Got Fun',
#      'url': 'https://t.co/KCaEvKJ2ZA',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/KCaEvKJ2ZA',
#          'expanded_url': 'https://www.programming-hero.com/',
#          'display_url': 'programming-hero.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 236,
#      'friends_count': 56,
#      'listed_count': 2,
#      'created_at': 'Mon Apr 27 20:28:19 +0000 2020',
#      'favourites_count': 310,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 292,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1254869948796674048/1602616573',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 7,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 7,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:41:46 +0000 2020',
#    'id': 1319031148257939457,
#    'id_str': '1319031148257939457',
#    'text': 'RT @ProgrammingHero: Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.\n.\n#…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ProgrammingHero',
#       'name': 'Programming Hero',
#       'id': 1254869948796674048,
#       'id_str': '1254869948796674048',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://occlude.netlify.app/" rel="nofollow">OccludejsBot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1275056773443973124,
#     'id_str': '1275056773443973124',
#     'name': 'Candis',
#     'screen_name': 'Women_who_code',
#     'location': 'bootcamp',
#     'description': '24💐 • MERN Stack Developer • React Geek • ☕ Coffee • 🦄 Unicorn • SDE @nytimes',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 734,
#     'friends_count': 25,
#     'listed_count': 19,
#     'created_at': 'Mon Jun 22 13:23:34 +0000 2020',
#     'favourites_count': 236,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 97618,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1314621116191629312/vQLAcsnS_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1314621116191629312/vQLAcsnS_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1275056773443973124/1599976745',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 21:41:43 +0000 2020',
#     'id': 1319031134135545856,
#     'id_str': '1319031134135545856',
#     'text': 'Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.… https://t.co/ezaBFrIrOl',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/ezaBFrIrOl',
#        'expanded_url': 'https://twitter.com/i/web/status/1319031134135545856',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [116, 139]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1254869948796674048,
#      'id_str': '1254869948796674048',
#      'name': 'Programming Hero',
#      'screen_name': 'ProgrammingHero',
#      'location': '',
#      'description': 'Coding Just Got Fun',
#      'url': 'https://t.co/KCaEvKJ2ZA',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/KCaEvKJ2ZA',
#          'expanded_url': 'https://www.programming-hero.com/',
#          'display_url': 'programming-hero.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 236,
#      'friends_count': 56,
#      'listed_count': 2,
#      'created_at': 'Mon Apr 27 20:28:19 +0000 2020',
#      'favourites_count': 310,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 292,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1255235119306215425/1PLSzQrB_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1254869948796674048/1602616573',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 7,
#     'favorite_count': 2,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 7,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:41:46 +0000 2020',
#    'id': 1319031147964305419,
#    'id_str': '1319031147964305419',
#    'text': 'RT @ProgrammingHero: Cloud computing has multiplied over the past several years. \n\nHave a look at Top 5 Cloud Providers In 2020\n.\n.\n.\n.\n.\n#…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'ProgrammingHero',
#       'name': 'Programming Hero',
#       'id': 1254869948796674048,
#       'id_str': '1254869948796674048',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://nlogn.in" rel="nofollow">nlognrobot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1260062769543434240,
#     'id_str': '1260062769543434240',
#     'name': '#100DaysOfCode',
#     'screen_name': 'nlognbot',
#     'location': 'Server',
#     'description': "Hi, I'm a bot that retweets #100daysofcode     \n                 \nP.S. I was created by @NlognHQ follow them.",
#     'url': 'https://t.co/PujHDQomPA',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/PujHDQomPA',
#         'expanded_url': 'http://nlogn.in',
#         'display_url': 'nlogn.in',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 4376,
#     'friends_count': 3,
# ...
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [113, 136]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 4263007693,
#      'id_str': '4263007693',
#      'name': 'Dr. Ganapathi Pulipaka',
#      'screen_name': 'gp_pulipaka',
#      'location': 'Redondo Beach, CA',
#      'description': 'Chief #AI #HPC Scientist | #Speaker | PostDoc CS, PhD | Bestselling #Author | 18.4M V | Top #BigData #DataScience #MachineLearning #IIoT Influencer @Onalytica',
#      'url': 'https://t.co/eYyaJsEcfw',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/eYyaJsEcfw',
#          'expanded_url': 'http://www.gppulipaka.org',
#          'display_url': 'gppulipaka.org',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 101394,
#      'friends_count': 25866,
#      'listed_count': 3495,
#      'created_at': 'Tue Nov 17 02:19:09 +0000 2015',
#      'favourites_count': 9,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 58478,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1315479714790694912/MQmkjugW_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1315479714790694912/MQmkjugW_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4263007693/1599491057',
#      'profile_link_color': 'DD2E44',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 133,
#     'favorite_count': 47,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 133,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:37:45 +0000 2020',
#    'id': 1319030137996767232,
#    'id_str': '1319030137996767232',
#    'text': 'RT @dataiku: What is driving rapid edge computing adoption? | https://t.co/V35T00T9yP #DataScience #DataQuality #DeepLearning #Algorithm #D…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'DataScience', 'indices': [86, 98]},
#      {'text': 'DataQuality', 'indices': [99, 111]},
#      {'text': 'DeepLearning', 'indices': [112, 125]},
#      {'text': 'Algorithm', 'indices': [126, 136]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'dataiku',
#       'name': 'Dataiku',
#       'id': 816825631,
#       'id_str': '816825631',
#       'indices': [3, 11]}],
#     'urls': [{'url': 'https://t.co/V35T00T9yP',
#       'expanded_url': 'https://bit.ly/2FKFgv2',
#       'display_url': 'bit.ly/2FKFgv2',
#       'indices': [62, 85]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://www.fabricio-dev.com.br/" rel="nofollow">twitter-bot-fab</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1051649960,
#     'id_str': '1051649960',
#     'name': 'Fabricio Cavalcante',
#     'screen_name': 'Fabriciosx',
#     'location': 'Rio de janeiro',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1472,
#     'friends_count': 108,
#     'listed_count': 22,
#     'created_at': 'Tue Jan 01 02:32:07 +0000 2013',
#     'favourites_count': 0,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 194092,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '9FB272',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/445285336663326720/Xc9HLhJB_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/445285336663326720/Xc9HLhJB_normal.jpeg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1051649960/1357242372',
#     'profile_link_color': '799A7B',
#     'profile_sidebar_border_color': 'D0C9AF',
#     'profile_sidebar_fill_color': '292C25',
#     'profile_text_color': '457079',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 21:34:59 +0000 2020',
#     'id': 1319029441700515843,
#     'id_str': '1319029441700515843',
#     'text': 'What is driving rapid edge computing adoption? | https://t.co/V35T00T9yP #DataScience #DataQuality #DeepLearning… https://t.co/lCj7aw7FHO',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'DataScience', 'indices': [73, 85]},
#       {'text': 'DataQuality', 'indices': [86, 98]},
#       {'text': 'DeepLearning', 'indices': [99, 112]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/V35T00T9yP',
#        'expanded_url': 'https://bit.ly/2FKFgv2',
#        'display_url': 'bit.ly/2FKFgv2',
#        'indices': [49, 72]},
#       {'url': 'https://t.co/lCj7aw7FHO',
#        'expanded_url': 'https://twitter.com/i/web/status/1319029441700515843',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [114, 137]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://www.hubspot.com/" rel="nofollow">HubSpot</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 816825631,
#      'id_str': '816825631',
#      'name': 'Dataiku',
#      'screen_name': 'dataiku',
#      'location': 'New York, NY',
#      'description': 'Dataiku connects people, technologies and processes to pave the fast, stable, sustainable path to enterprise AI.',
#      'url': 'https://t.co/6nzXAxDroj',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/6nzXAxDroj',
#          'expanded_url': 'https://www.dataiku.com',
#          'display_url': 'dataiku.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 19951,
#      'friends_count': 504,
#      'listed_count': 1489,
#      'created_at': 'Tue Sep 11 06:27:36 +0000 2012',
#      'favourites_count': 5297,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 14116,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '045067',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1277621608161689601/4a0QzD8o_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1277621608161689601/4a0QzD8o_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/816825631/1581956038',
#      'profile_link_color': '2AB1AC',
#      'profile_sidebar_border_color': 'EEEEEE',
#      'profile_sidebar_fill_color': 'EFEFEF',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 3,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 3,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Wed Oct 21 21:37:45 +0000 2020',
#    'id': 1319030137887854594,
#    'id_str': '1319030137887854594',
#    'text': 'RT @odsc: Join us at #ODSCWest this October to hear renowned speakers and experts share their knowledge of the topics and tools driving the…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'ODSCWest', 'indices': [21, 30]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'odsc',
#       'name': 'Open Data Science',
#       'id': 3018841323,
#       'id_str': '3018841323',
#       'indices': [3, 8]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://www.fabricio-dev.com.br/" rel="nofollow">twitter-bot-fab</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1051649960,
#     'id_str': '1051649960',
#     'name': 'Fabricio Cavalcante',
#     'screen_name': 'Fabriciosx',
#     'location': 'Rio de janeiro',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1472,
#     'friends_count': 108,
#     'listed_count': 22,
#     'created_at': 'Tue Jan 01 02:32:07 +0000 2013',
#     'favourites_count': 0,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 194092,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '9FB272',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/445285336663326720/Xc9HLhJB_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/445285336663326720/Xc9HLhJB_normal.jpeg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1051649960/1357242372',
#     'profile_link_color': '799A7B',
#     'profile_sidebar_border_color': 'D0C9AF',
#     'profile_sidebar_fill_color': '292C25',
#     'profile_text_color': '457079',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Oct 21 21:35:00 +0000 2020',
#     'id': 1319029445559279617,
#     'id_str': '1319029445559279617',
#     'text': 'Join us at #ODSCWest this October to hear renowned speakers and experts share their knowledge of the topics and too… https://t.co/8PAIZ1KuLa',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'ODSCWest', 'indices': [11, 20]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/8PAIZ1KuLa',
#        'expanded_url': 'https://twitter.com/i/web/status/1319029445559279617',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://www.hubspot.com/" rel="nofollow">HubSpot</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 3018841323,
#      'id_str': '3018841323',
#      'name': 'Open Data Science',
#      'screen_name': 'odsc',
#      'location': 'Boston, MA',
#      'description': 'Bringing together the global data science community to help foster the exchange of innovative ideas and encourage the growth of open source software.',
#      'url': 'https://t.co/UBbHYS8ReL',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/UBbHYS8ReL',
#          'expanded_url': 'http://odsc.com',
#          'display_url': 'odsc.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 73371,
#      'friends_count': 28178,
#      'listed_count': 2379,
#      'created_at': 'Wed Feb 04 22:35:11 +0000 2015',
#      'favourites_count': 15897,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 46951,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '131516',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1115210960271228929/lHua2G3l_normal.png',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1115210960271228929/lHua2G3l_normal.png',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3018841323/1600849929',
#      'profile_link_color': '009999',
#      'profile_sidebar_border_color': 'EEEEEE',
#      'profile_sidebar_fill_color': 'EFEFEF',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.131,
#   'max_id': 1319031297503825920,
#   'max_id_str': '1319031297503825920',
#   'next_results': '?max_id=1319030137887854593&q=%23DataScience&count=50&include_entities=1',
#   'query': '%23DataScience',
#   'refresh_url': '?since_id=1319031297503825920&q=%23DataScience&include_entities=1',
#   'count': 50,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %% [markdown]
# ##### Function 3 (Required)

# %% [markdown]
# **Name:** `get_followers`
#
# **Returns:** list of data objects for each of the users followers, returning values for the `name`, `followers_count`, `friends_count`, and `screen_name` key for each user.
#
# **Arguments:**
#
#  - `screen_name`: str, required; Twitter handle to search for.  **Results should not depend on user inputting the @ symbol.**
#  - `keys`: list, required;  keys to return for each user.  default value: [`name`, `followers_count`, `friends_count`, `screen_name`]; if something else is listed, values for those keys should be returned
#  - `to_df`: bool, required; default value: False; if True, return results in a dataframe.  Every value provided in the `keys` argument should be its own column, with rows populated by the corresponding values for each one for every user.

# %%
def get_followers(screen_name, keys=['name', 'followers_count', 'friends_count', 'screen_name'], to_df=False):
   
    # check if the first item is an @ symbol
    screen_name  = check_handle(screen_name)
    
    # url to use
    base_url     = 'https://api.twitter.com/1.1/followers/list.json'
    # query to attach
    query_string = f'?screen_name={screen_name}'
    
    # generate the request
    users        = requests.get(base_url + query_string, auth=tokens).json()['users']
    
    # create dictionaries that only contain the keys specified in the keys argument
    abbreviated_users = [{key: user[key] for key in keys} for user in users]
    
    # if returning results in a dataframe
    if to_df:
        import pandas as pd
        # create a dictionary with key values for each one 
        df_dict = {key: [user[key] for user in abbreviated_users] for key in keys }
        return pd.DataFrame(df_dict)
    
    return abbreviated_users

# %%
# with GA handle
get_followers('@GA')
# Out:
# [{'name': 'Quwanie Gordon',
#   'followers_count': 387,
#   'friends_count': 1737,
#   'screen_name': 'QuwanieGordon'},
#  {'name': 'David Knudson',
#   'followers_count': 7,
#   'friends_count': 28,
#   'screen_name': 'djknudson'},
#  {'name': 'Lesley S.',
#   'followers_count': 1591,
#   'friends_count': 2210,
#   'screen_name': 'msgigglez'},
#  {'name': 'Eppik',
#   'followers_count': 1097,
#   'friends_count': 4650,
#   'screen_name': 'eppikstories'},
#  {'name': 'Quest Engineering Solutions',
#   'followers_count': 15,
#   'friends_count': 139,
#   'screen_name': 'QESEngineering'},
#  {'name': 'Srikanth',
#   'followers_count': 5,
#   'friends_count': 170,
#   'screen_name': 'Srikant65202945'},
#  {'name': 'TUSIIME CHRISTBELL',
#   'followers_count': 492,
#   'friends_count': 1998,
#   'screen_name': 'TUSIIMECHRISTB1'},
#  {'name': 'iamsamhacker',
#   'followers_count': 67,
#   'friends_count': 222,
#   'screen_name': 'iamsamhacker'},
#  {'name': 'joshua d chapel',
#   'followers_count': 1,
#   'friends_count': 74,
#   'screen_name': 'chapel_joshua'},
#  {'name': '.',
#   'followers_count': 160,
#   'friends_count': 117,
#   'screen_name': 'jarrell_idk'},
#  {'name': 'NEM Support',
#   'followers_count': 0,
#   'friends_count': 79,
#   'screen_name': 'NemSupport'},
#  {'name': 'Further 🇦🇺',
#   'followers_count': 34,
#   'friends_count': 26,
#   'screen_name': 'further_global'},
#  {'name': 'Jasmin Alvarez',
#   'followers_count': 0,
#   'friends_count': 25,
#   'screen_name': 'JasminA87599169'},
#  {'name': 'Nick Dyer',
#   'followers_count': 58,
#   'friends_count': 785,
#   'screen_name': 'RealNickDyer'},
#  {'name': 'Pramit Majumder',
#   'followers_count': 39,
#   'friends_count': 1464,
#   'screen_name': 'MajumderPramit'},
#  {'name': 'melisa 🌱',
#   'followers_count': 19,
#   'friends_count': 52,
#   'screen_name': 'melisaglser'},
#  {'name': 'Susie Vernalis',
#   'followers_count': 687,
#   'friends_count': 4455,
#   'screen_name': 'smvernalis'},
#  {'name': 'delara chowdhury',
#   'followers_count': 110,
#   'friends_count': 111,
#   'screen_name': 'delaracy'},
#  {'name': 'Lobster Coaching',
#   'followers_count': 52,
#   'friends_count': 166,
#   'screen_name': 'lobstercoaching'},
#  {'name': 'jena adeke',
#   'followers_count': 5,
#   'friends_count': 115,
#   'screen_name': 'AdekeJena'}]

# %%
# and without the @ symbol
get_followers('GA')
# Out:
# [{'name': 'Quwanie Gordon',
#   'followers_count': 387,
#   'friends_count': 1737,
#   'screen_name': 'QuwanieGordon'},
#  {'name': 'David Knudson',
#   'followers_count': 7,
#   'friends_count': 28,
#   'screen_name': 'djknudson'},
#  {'name': 'Lesley S.',
#   'followers_count': 1591,
#   'friends_count': 2210,
#   'screen_name': 'msgigglez'},
#  {'name': 'Eppik',
#   'followers_count': 1097,
#   'friends_count': 4650,
#   'screen_name': 'eppikstories'},
#  {'name': 'Quest Engineering Solutions',
#   'followers_count': 15,
#   'friends_count': 139,
#   'screen_name': 'QESEngineering'},
#  {'name': 'Srikanth',
#   'followers_count': 5,
#   'friends_count': 170,
#   'screen_name': 'Srikant65202945'},
#  {'name': 'TUSIIME CHRISTBELL',
#   'followers_count': 492,
#   'friends_count': 1998,
#   'screen_name': 'TUSIIMECHRISTB1'},
#  {'name': 'iamsamhacker',
#   'followers_count': 67,
#   'friends_count': 222,
#   'screen_name': 'iamsamhacker'},
#  {'name': 'joshua d chapel',
#   'followers_count': 1,
#   'friends_count': 74,
#   'screen_name': 'chapel_joshua'},
#  {'name': '.',
#   'followers_count': 160,
#   'friends_count': 117,
#   'screen_name': 'jarrell_idk'},
#  {'name': 'NEM Support',
#   'followers_count': 0,
#   'friends_count': 79,
#   'screen_name': 'NemSupport'},
#  {'name': 'Further 🇦🇺',
#   'followers_count': 34,
#   'friends_count': 26,
#   'screen_name': 'further_global'},
#  {'name': 'Jasmin Alvarez',
#   'followers_count': 0,
#   'friends_count': 25,
#   'screen_name': 'JasminA87599169'},
#  {'name': 'Nick Dyer',
#   'followers_count': 58,
#   'friends_count': 785,
#   'screen_name': 'RealNickDyer'},
#  {'name': 'Pramit Majumder',
#   'followers_count': 39,
#   'friends_count': 1464,
#   'screen_name': 'MajumderPramit'},
#  {'name': 'melisa 🌱',
#   'followers_count': 19,
#   'friends_count': 52,
#   'screen_name': 'melisaglser'},
#  {'name': 'Susie Vernalis',
#   'followers_count': 687,
#   'friends_count': 4455,
#   'screen_name': 'smvernalis'},
#  {'name': 'delara chowdhury',
#   'followers_count': 110,
#   'friends_count': 111,
#   'screen_name': 'delaracy'},
#  {'name': 'Lobster Coaching',
#   'followers_count': 52,
#   'friends_count': 166,
#   'screen_name': 'lobstercoaching'},
#  {'name': 'jena adeke',
#   'followers_count': 5,
#   'friends_count': 115,
#   'screen_name': 'AdekeJena'}]

# %%
# and now only use certain keys
get_followers('GA', keys=['name', 'followers_count'])
# Out:
# [{'name': 'Quwanie Gordon', 'followers_count': 387},
#  {'name': 'David Knudson', 'followers_count': 7},
#  {'name': 'Lesley S.', 'followers_count': 1591},
#  {'name': 'Eppik', 'followers_count': 1097},
#  {'name': 'Quest Engineering Solutions', 'followers_count': 15},
#  {'name': 'Srikanth', 'followers_count': 5},
#  {'name': 'TUSIIME CHRISTBELL', 'followers_count': 492},
#  {'name': 'iamsamhacker', 'followers_count': 67},
#  {'name': 'joshua d chapel', 'followers_count': 1},
#  {'name': '.', 'followers_count': 160},
#  {'name': 'NEM Support', 'followers_count': 0},
#  {'name': 'Further 🇦🇺', 'followers_count': 34},
#  {'name': 'Jasmin Alvarez', 'followers_count': 0},
#  {'name': 'Nick Dyer', 'followers_count': 58},
#  {'name': 'Pramit Majumder', 'followers_count': 39},
#  {'name': 'melisa 🌱', 'followers_count': 19},
#  {'name': 'Susie Vernalis', 'followers_count': 687},
#  {'name': 'delara chowdhury', 'followers_count': 110},
#  {'name': 'Lobster Coaching', 'followers_count': 52},
#  {'name': 'jena adeke', 'followers_count': 5}]

# %%
# and put those results in a dataframe
get_followers('GA', keys=['name', 'followers_count'], to_df=True)
# Out:
#                            name  followers_count
# 0                    @NG*E 👩🏾‍🎤              826
# 1               Hafsa Nefouci ✨               83
# 2                             🏹              801
# 3                         Lydia                1
# 4                         MARCO               46
# 5                  Aaron Dunphy              196
# 6                  Dorian Lopez               28
# 7                 Sifat Hossain              128
# 8   Christina Magnetic Thompson                5
# 9                  Ryan DeMilio              133
# 10                 Amanda.ux.ui                2
# 11              Alyssa Johnasen                8
# 12                         peri              204
# 13                 Jeevan Singh               67
# 14                       Verner               94
# 15            CEO for One Month             8174
# 16               Travis Tincher               20
# 17              Victoria Medina              633
# 18                seppe peeters               30
# 19                           🖕🏼               52

# %%
# and test the same thing, but without any keys specified
get_followers('GA', to_df=True)
# Out:
#                            name  followers_count  friends_count  \
# 0                Quwanie Gordon              387           1737
# 1                 David Knudson                7             28
# 2                     Lesley S.             1591           2210
# 3                         Eppik             1097           4650
# 4   Quest Engineering Solutions               16            139
# 5                      Srikanth                5            170
# 6            TUSIIME CHRISTBELL              490           1998
# 7                  iamsamhacker               67            222
# 8               joshua d chapel                1             74
# 9                             .              160            117
# 10                  NEM Support                0             79
# 11                   Further 🇦🇺               34             26
# 12               Jasmin Alvarez                0             25
# 13                    Nick Dyer               59            796
# 14              Pramit Majumder               41           1503
# 15                     melisa 🌱               19             52
# 16               Susie Vernalis              687           4455
# 17             delara chowdhury              110            111
# 18             Lobster Coaching               52            166
# 19                   jena adeke                5            115
#
#         screen_name
# 0     QuwanieGordon
# 1         djknudson
# 2         msgigglez
# 3      eppikstories
# 4    QESEngineering
# 5   Srikant65202945
# 6   TUSIIMECHRISTB1
# 7      iamsamhacker
# 8     chapel_joshua
# 9       jarrell_idk
# 10       NemSupport
# 11   further_global
# 12  JasminA87599169
# 13     RealNickDyer
# 14   MajumderPramit
# 15      melisaglser
# 16       smvernalis
# 17         delaracy
# 18  lobstercoaching
# 19        AdekeJena

# %% [markdown]
# ##### Function 4 (Optional)

# %% [markdown]
# **Name:** `friends_of_friends`
#
# **Returns:** list of data objects for each user that two Twitter users have in common
#
# **Arguments:**
#
#  - `names`: list, required; list of two Twitter handles to compare friends list with.  **Results should be insensitive to whether or not the '@' symbol is included or not.**
#  - `keys`: list, optional; list of keys to return for information about each user.  Default value should be to return the entire data object.
#  - `to_df`: bool, required; default value: False; if True, returns results in a dataframe.

# %%
def friends_of_friends(names, keys=None, to_df=False):
    # modify handles if necessary
    names    = [check_handle(name) for name in names]
    # base url
    url      = 'https://api.twitter.com/1.1/friends/list.json'
    # get friends of both users -- note we return the list associated with the 'users' key
    results  = [requests.get(url + f'?screen_name={name}&count=200', auth=tokens).json()['users']
                for name in names]
    
    # ids of first friend
    user1_ids = [result['id'] for result in results[0]]
    # ids of second friend
    user2_ids = [result['id'] for result in results[1]]
    
    # ids that are common in both of the above lists
    joint_ids = [user_id for user_id in user1_ids if user_id in user2_ids]
    
    # return the users that have the id that's held jointly by each user
    friends_of_friends = [user for user in results[0] if user['id'] in joint_ids]
    
    # if keys are provided
    if keys is not None:
        # do the following comprehension:
         # create a dictionary which contains the value for each key provided
         # for every person in the friend_of_friends list
        friends_of_friends = [{key: friend[key] for key in keys} for friend in friends_of_friends]
        
    # if we want the results in a dataframe
    if to_df:
        import pandas as pd
        # first check to see if there's a specific list of keys we need to use
        if keys is not None:
            # if yes, create a dictionary, where each key is a list with all of its values
            df_dict = {key: [friend[key] if friend[key] else None for friend in friends_of_friends] for key in keys}
            return pd.DataFrame(df_dict)
        
        # likewise, if keys are not provided, then get them inside of a list
        keys = friends_of_friends[0].keys()
        # and create a dataframe friendly dictionary in the same way
        df_dict = {key: [friend[key] for friend in friends_of_friends] for key in keys}
        return pd.DataFrame(df_dict)
            
    # and if none of the above conditions are true, just return the original friends_of_friends list
    return friends_of_friends

# %%
# mutual friends
friends_of_friends(['Beyonce', 'MariahCarey'])
# Out:
# [{'id': 40908929,
#   'id_str': '40908929',
#   'name': 'Usher Raymond IV',
#   'screen_name': 'Usher',
#   'location': '',
#   'description': 'Text me (404) 737-1821',
#   'url': 'https://t.co/Vj0zkZ2Rr0',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/Vj0zkZ2Rr0',
#       'expanded_url': 'http://smarturl.it/xicry',
#       'display_url': 'smarturl.it/xicry',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 12192202,
#   'friends_count': 564,
#   'listed_count': 26263,
#   'created_at': 'Mon May 18 16:36:50 +0000 2009',
#   'favourites_count': 1333,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': True,
#   'statuses_count': 5992,
#   'lang': None,
#   'status': {'created_at': 'Wed Aug 05 19:10:55 +0000 2020',
#    'id': 1291089318597890048,
#    'id_str': '1291089318597890048',
#    'text': 'A 4-Day Celebration of Community Power + Cultural Resistance. Tune in live on August 6 + 7 + 12 + 18, 2020 for… https://t.co/jUZQCv1dUF',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/jUZQCv1dUF',
#       'expanded_url': 'https://twitter.com/i/web/status/1291089318597890048',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [112, 135]}]},
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 70,
#    'favorite_count': 250,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': True,
#   'profile_background_color': '000000',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1226991892857884672/70shiuOh_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1226991892857884672/70shiuOh_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/40908929/1593214738',
#   'profile_link_color': 'ABB8C2',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': 'DDFFCC',
#   'profile_text_color': '333333',
#   'profile_use_background_image': False,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'regular'},
#  {'id': 30782495,
#   'id_str': '30782495',
#   'name': 'KELENDRIA ROWLAND',
#   'screen_name': 'KELLYROWLAND',
#   'location': '',
#   'description': 'COFFEE – out now!',
#   'url': 'https://t.co/IUvpsr9qhu',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/IUvpsr9qhu',
#       'expanded_url': 'https://eqdistro.io/coffee',
#       'display_url': 'eqdistro.io/coffee',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 6896645,
#   'friends_count': 1701,
#   'listed_count': 13680,
#   'created_at': 'Mon Apr 13 02:15:13 +0000 2009',
#   'favourites_count': 1287,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': True,
#   'statuses_count': 13330,
#   'lang': None,
#   'status': {'created_at': 'Tue Aug 04 19:45:49 +0000 2020',
#    'id': 1290735713990750208,
#    'id_str': '1290735713990750208',
#    'text': 'There are state primaries happening today in Michigan, Arizona, Kansas, Missouri and Washington! Mask up and let yo… https://t.co/MjjZT5MS7J',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/MjjZT5MS7J',
#       'expanded_url': 'https://twitter.com/i/web/status/1290735713990750208',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 56,
#    'favorite_count': 210,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '072E59',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1249910282685542402/k5AuXj1k_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1249910282685542402/k5AuXj1k_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/30782495/1587096324',
#   'profile_link_color': '8A8C8C',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': '95E8EC',
#   'profile_text_color': '3C3940',
#   'profile_use_background_image': False,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'},
#  {'id': 18395177,
#   'id_str': '18395177',
#   'name': 'solange knowles',
#   'screen_name': 'solangeknowles',
#   'location': '',
#   'description': 'water, melanin, bones, blood.',
#   'url': 'https://t.co/8F2cZD8D37',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/8F2cZD8D37',
#       'expanded_url': 'http://www.saintheron.com',
#       'display_url': 'saintheron.com',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 4151877,
#   'friends_count': 167,
#   'listed_count': 8921,
#   'created_at': 'Fri Dec 26 20:54:15 +0000 2008',
#   'favourites_count': 3252,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': True,
#   'statuses_count': 560,
#   'lang': None,
#   'status': {'created_at': 'Fri Aug 07 21:25:09 +0000 2020',
#    'id': 1291847877099167746,
#    'id_str': '1291847877099167746',
#    'text': 'it’s the run at 2:14 for meeeee 😭 @4everBrandy https://t.co/OrReZpzOEf',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': '4everBrandy',
#       'name': 'b r a n d y',
#       'id': 27406401,
#       'id_str': '27406401',
#       'indices': [34, 46]}],
#     'urls': [],
#     'media': [{'id': 1291847873378869249,
#       'id_str': '1291847873378869249',
#       'indices': [47, 70],
#       'media_url': 'http://pbs.twimg.com/media/Ee2Qy9yXYAE4Eai.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/Ee2Qy9yXYAE4Eai.jpg',
#       'url': 'https://t.co/OrReZpzOEf',
#       'display_url': 'pic.twitter.com/OrReZpzOEf',
#       'expanded_url': 'https://twitter.com/solangeknowles/status/1291847877099167746/photo/1',
#       'type': 'photo',
#       'sizes': {'medium': {'w': 705, 'h': 1200, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 400, 'h': 680, 'resize': 'fit'},
#        'large': {'w': 749, 'h': 1274, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1291847873378869249,
#       'id_str': '1291847873378869249',
#       'indices': [47, 70],
#       'media_url': 'http://pbs.twimg.com/media/Ee2Qy9yXYAE4Eai.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/Ee2Qy9yXYAE4Eai.jpg',
#       'url': 'https://t.co/OrReZpzOEf',
#       'display_url': 'pic.twitter.com/OrReZpzOEf',
#       'expanded_url': 'https://twitter.com/solangeknowles/status/1291847877099167746/photo/1',
#       'type': 'photo',
#       'sizes': {'medium': {'w': 705, 'h': 1200, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 400, 'h': 680, 'resize': 'fit'},
#        'large': {'w': 749, 'h': 1274, 'resize': 'fit'}}}]},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1755,
#    'favorite_count': 12730,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'FFF04D',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#   'profile_background_tile': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1109657367577133057/44jmIiZ6_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1109657367577133057/44jmIiZ6_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/18395177/1528451677',
#   'profile_link_color': 'EDE31F',
#   'profile_sidebar_border_color': 'FFFFFF',
#   'profile_sidebar_fill_color': 'EFEFEF',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'live_following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'muting': False,
#   'blocking': False,
#   'blocked_by': False,
#   'translator_type': 'none'}]

# %%
# mutual friends, returned in a dataframe
friends_of_friends(['Beyonce', 'MariahCarey'], to_df=True)
# Out:
#          id    id_str               name     screen_name location  \
# 0  40908929  40908929   Usher Raymond IV           Usher
# 1  30782495  30782495  KELENDRIA ROWLAND    KELLYROWLAND
# 2  18395177  18395177    solange knowles  solangeknowles
#
#                      description                      url  \
# 0         Text me (404) 737-1821  https://t.co/Vj0zkZ2Rr0
# 1              COFFEE – out now!  https://t.co/IUvpsr9qhu
# 2  water, melanin, bones, blood.  https://t.co/8F2cZD8D37
#
#                                             entities  protected  \
# 0  {'url': {'urls': [{'url': 'https://t.co/Vj0zkZ...      False
# 1  {'url': {'urls': [{'url': 'https://t.co/IUvpsr...      False
# 2  {'url': {'urls': [{'url': 'https://t.co/8F2cZD...      False
#
#    followers_count  ...  default_profile  default_profile_image following  \
# 0         12192202  ...            False                  False     False
# 1          6896645  ...            False                  False     False
# 2          4151877  ...            False                  False     False
#
#    live_following follow_request_sent notifications  muting  blocking  \
# 0           False               False         False   False     False
# 1           False               False         False   False     False
# 2           False               False         False   False     False
#
#    blocked_by translator_type
# 0       False         regular
# 1       False            none
# 2       False            none
#
# [3 rows x 47 columns]

# %%
# friends of friends, with keys passed in
friends_of_friends(['Beyonce', 'MariahCarey'], keys=['id', 'name'])
# Out:
# [{'id': 40908929, 'name': 'Usher Raymond IV'},
#  {'id': 30782495, 'name': 'KELENDRIA ROWLAND'},
#  {'id': 18395177, 'name': 'solange knowles'}]

# %%
# f_o_f, with keys and to_df specified
friends_of_friends(['Beyonce', 'MariahCarey'], keys=['id', 'name'], to_df=True)
# Out:
#          id               name
# 0  40908929   Usher Raymond IV
# 1  30782495  KELENDRIA ROWLAND
# 2  18395177    solange knowles

# %% [markdown]
#  ##### Function 5 (Optional)

# %% [markdown]
# Rewrite the `friends_of_friends` function, except this time include an argument called `full_search`, which accepts a boolean value.  If set to `True`, use cursoring to cycle through the complete set of users for the users provided.
#
# The twitter API only returns a subset of users in your results to save bandwidth, so you have to cycle through multiple result sets to get all of the values.
#
# You can read more about how this works here:  https://developer.twitter.com/en/docs/basics/cursoring
#
# Basically you have to do a `while` loop to continually make a new request using the values stored in the `next_cursor` key as part of your next query string until there's nothing left to search.
#
# **Note:** We're using the free API, so we're operating under some limitations.  One of them being that you can only make 15 API calls in a 15 minute span.  You can also only return up to 200 results per cursor, so this means you won't be able to completely search for everyone even if you set this up correctly.
#
# That's fine, just do what you can under the circumstances.

# %%
# we'll create a separate function to handle the cursoring
def cursor_user(username):
    # check the username
    username  = check_handle(username)
    # set the following variables to use in the loop
    cursor    = -1
    followers = []
    
    # while this condition is True
    while cursor != 0:
        # set the url using the value of cursor & username
        url = f'https://api.twitter.com/1.1/friends/list.json?screen_name={username}&count=200&cursor={cursor}'
        # do the request
        req = requests.get(url, auth=tokens).json()
        # add the values returned by the request
        followers.extend(req['users'])
        # set the value of cursor to value inside this key
        cursor = req['next_cursor']
    
    # and when you're finished, return the list
    return followers

# %%
# and now we'll stick it inside friends_of_friends
def friends_of_friends(names, keys=None, to_df=False, full_search=False):
    names    = [check_handle(name) for name in names]
    url      = 'https://api.twitter.com/1.1/friends/list.json'
    
    # if full_search, use the cursor_user() fn for each person 
    if full_search:
        results = [cursor_user(name) for name in names]
    # if not, then do a standard search
    else:
        results = [requests.get(url + f'?screen_name={name}&count=200', auth=tokens).json()['users']
                   for name in names]
    
    user1_ids = [result['id'] for result in results[0]]
    user2_ids = [result['id'] for result in results[1]]
    
    joint_ids = [user_id for user_id in user1_ids if user_id in user2_ids]
    
    friends_of_friends = [user for user in results[0] if user['id'] in joint_ids]
    
    if keys is not None:
        friends_of_friends = [{key: friend[key] for key in keys} for friend in friends_of_friends]
        
    if to_df:
        import pandas as pd
        if keys is not None:
            df_dict = {key: [friend[key] for friend in friends_of_friends] for key in keys}
            return pd.DataFrame(df_dict)
        
        keys = friends_of_friends[0].keys()
        df_dict = {key: [friend[key] for friend in friends_of_friends] for key in keys}
        return pd.DataFrame(df_dict)
            
    return friends_of_friends

# %%
# if you search for 200 friends, you'll find 4 people in common
len(friends_of_friends(['ezraklein', 'tylercowen']))
# Out:
# 9

# %%
# if you add full_search, then it'll find 54 people
len(friends_of_friends(['ezraklein', 'tylercowen'], full_search=True))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-35124d0134d1> in <module>
#       1 # if you add full_search, then it'll find 54 people
# ----> 2 len(friends_of_friends(['ezraklein', 'tylercowen'], full_search=True))
#
# <ipython-input-36-22446aec57eb> in friends_of_friends(names, keys, to_df, full_search)
#       6     # if full_search, use the cursor_user() fn for each person
#       7     if full_search:
# ----> 8         results = [cursor_user(name) for name in names]
#       9     # if not, then do a standard search
#      10     else:
#
# <ipython-input-36-22446aec57eb> in <listcomp>(.0)
#       6     # if full_search, use the cursor_user() fn for each person
#       7     if full_search:
# ----> 8         results = [cursor_user(name) for name in names]
#       9     # if not, then do a standard search
#      10     else:
#
# <ipython-input-34-e96317bd0bd8> in cursor_user(username)
#      14         req = requests.get(url, auth=tokens).json()
#      15         # add the values returned by the request
# ---> 16         followers.extend(req['users'])
#      17         # set the value of cursor to value inside this key
#      18         cursor = req['next_cursor']
#
# KeyError: 'users'
