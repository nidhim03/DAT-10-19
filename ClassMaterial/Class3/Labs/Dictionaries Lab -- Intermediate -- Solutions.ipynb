# %% [markdown]
# ## Intermediate Lab:  Creating A Dataset Using the GitHub API
#
# In this lab you'll create a dataset containing all the meta information about your classmates github repos, using only the csv file with everyone's url.
#
# The process will be done in these 4 general steps:
#
#  - load in the csv file
#  - clean the individual lines of each file to get them ready to use
#  - connect to the GitHub api to obtain information about everyone's repos
#  - re-structure this information to turn it into a dataframe.
#
# It'll be a great way to work through the first step of many data science problems: creating a workable dataset out of unorganized, messy data.  Let's get started!

# %% [markdown]
# ### Step 1:  Load in the csv file with everyone's github repo

# %%
import requests
import pandas as pd

# %%
url = r"C:\Users\Jonat\Downloads\Github Repos DAT-10-19 - Sheet1.csv"

# %%
with open(url) as f:
    data = f.readlines()

# %%
data
# Out:
# ['Name,Github URL\n',
#  'Chlo̩,https://github.com/chloemd\n',
#  ',\n',
#  'Gary,https://github.com/Gmarin10\n',
#  'Cameron ,https://github.com/clefevre01\n',
#  'Oore,https://github.com/ladipoore\n',
#  'Jaryd Thornton,https://github.com/jcolethornton\n',
#  'Peter,https://github.com/Lothdyn/my-1019-repo\n',
#  'Alvaro ,https://github.com/alvarog01/mydat1019\n',
#  ',\n',
#  'Amanda Chernishkin,https://github.com/amandachernishkin\n',
#  'John Mayer,https://github.com/mayerjp01\n',
#  'Nidhi Mahambre,https://github.com/nidhim03']

# %%
urls = [url for url in data if 'https' in url]

# %%
urls
# Out:
# ['Chlo̩,https://github.com/chloemd\n',
#  'Gary,https://github.com/Gmarin10\n',
#  'Cameron ,https://github.com/clefevre01\n',
#  'Oore,https://github.com/ladipoore\n',
#  'Jaryd Thornton,https://github.com/jcolethornton\n',
#  'Peter,https://github.com/Lothdyn/my-1019-repo\n',
#  'Alvaro ,https://github.com/alvarog01/mydat1019\n',
#  'Amanda Chernishkin,https://github.com/amandachernishkin\n',
#  'John Mayer,https://github.com/mayerjp01\n',
#  'Nidhi Mahambre,https://github.com/nidhim03']

# %%
[len(url.split('/')) for url in urls]
# Out:
# [4, 4, 4, 4, 4, 5, 5, 4, 4, 4]

# %%
for url in urls:
    if len(url.split('/')) == 4:
        print(url.split('/')[-1])
    else:
        print(url.split('/')[-2])
# Out:
# chloemd
#
# Gmarin10
#
# clefevre01
#
# ladipoore
#
# jcolethornton
#
# Lothdyn
# alvarog01
# amandachernishkin
#
# mayerjp01
#
# nidhim03

# %%
usernames = []

for url in urls:
    if len(url.split('/')) == 4:
        usernames.append(url.split('/')[-1])
    else:
        usernames.append(url.split('/')[-2])

# %%
usernames[0].replace('\n', '')
# Out:
# 'chloemd'

# %%
usernames = [user.replace('\n', '') for user in usernames]

# %%
usernames
# Out:
# ['chloemd',
#  'Gmarin10',
#  'clefevre01',
#  'ladipoore',
#  'jcolethornton',
#  'Lothdyn',
#  'alvarog01',
#  'amandachernishkin',
#  'mayerjp01',
#  'nidhim03']

# %%
api_url = "https://api.github.com/users/chloemd/repos"
requests.get(api_url).json()
# Out:
# [{'id': 305542140,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzMDU1NDIxNDA=',
#   'name': 'DAT-1019-Chloe',
#   'full_name': 'chloemd/DAT-1019-Chloe',
#   'private': False,
#   'owner': {'login': 'chloemd',
#    'id': 73141231,
#    'node_id': 'MDQ6VXNlcjczMTQxMjMx',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/73141231?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/chloemd',
#    'html_url': 'https://github.com/chloemd',
#    'followers_url': 'https://api.github.com/users/chloemd/followers',
#    'following_url': 'https://api.github.com/users/chloemd/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/chloemd/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/chloemd/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/chloemd/subscriptions',
#    'organizations_url': 'https://api.github.com/users/chloemd/orgs',
#    'repos_url': 'https://api.github.com/users/chloemd/repos',
#    'events_url': 'https://api.github.com/users/chloemd/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/chloemd/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/chloemd/DAT-1019-Chloe',
#   'description': 'My DAT 10/19 repo',
#   'fork': False,
#   'url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe',
#   'forks_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/forks',
#   'keys_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/teams',
#   'hooks_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/hooks',
#   'issue_events_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/events',
#   'assignees_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/tags',
#   'blobs_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/languages',
#   'stargazers_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/stargazers',
#   'contributors_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/contributors',
#   'subscribers_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/subscribers',
#   'subscription_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/subscription',
#   'commits_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/merges',
#   'archive_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/downloads',
#   'issues_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/deployments',
#   'created_at': '2020-10-20T00:00:09Z',
#   'updated_at': '2020-10-26T22:03:37Z',
#   'pushed_at': '2020-10-26T22:03:35Z',
#   'git_url': 'git://github.com/chloemd/DAT-1019-Chloe.git',
#   'ssh_url': 'git@github.com:chloemd/DAT-1019-Chloe.git',
#   'clone_url': 'https://github.com/chloemd/DAT-1019-Chloe.git',
#   'svn_url': 'https://github.com/chloemd/DAT-1019-Chloe',
#   'homepage': None,
#   'size': 1456,
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 1,
#   'default_branch': 'main'}]

# %%
user_repos = [requests.get(f"https://api.github.com/users/{user}/repos").json()
              for user in usernames]

# %%
user_repos
# Out:
# [[{'id': 305542140,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkzMDU1NDIxNDA=',
#    'name': 'DAT-1019-Chloe',
#    'full_name': 'chloemd/DAT-1019-Chloe',
#    'private': False,
#    'owner': {'login': 'chloemd',
#     'id': 73141231,
#     'node_id': 'MDQ6VXNlcjczMTQxMjMx',
#     'avatar_url': 'https://avatars1.githubusercontent.com/u/73141231?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/chloemd',
#     'html_url': 'https://github.com/chloemd',
#     'followers_url': 'https://api.github.com/users/chloemd/followers',
#     'following_url': 'https://api.github.com/users/chloemd/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/chloemd/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/chloemd/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/chloemd/subscriptions',
#     'organizations_url': 'https://api.github.com/users/chloemd/orgs',
#     'repos_url': 'https://api.github.com/users/chloemd/repos',
#     'events_url': 'https://api.github.com/users/chloemd/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/chloemd/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/chloemd/DAT-1019-Chloe',
#    'description': 'My DAT 10/19 repo',
#    'fork': False,
#    'url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe',
#    'forks_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/forks',
#    'keys_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/teams',
#    'hooks_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/hooks',
#    'issue_events_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/events',
#    'assignees_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/tags',
#    'blobs_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/languages',
#    'stargazers_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/stargazers',
#    'contributors_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/contributors',
#    'subscribers_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/subscribers',
#    'subscription_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/subscription',
#    'commits_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/merges',
#    'archive_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/downloads',
#    'issues_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/chloemd/DAT-1019-Chloe/deployments',
#    'created_at': '2020-10-20T00:00:09Z',
#    'updated_at': '2020-10-26T22:03:37Z',
#    'pushed_at': '2020-10-26T22:03:35Z',
#    'git_url': 'git://github.com/chloemd/DAT-1019-Chloe.git',
#    'ssh_url': 'git@github.com:chloemd/DAT-1019-Chloe.git',
#    'clone_url': 'https://github.com/chloemd/DAT-1019-Chloe.git',
#    'svn_url': 'https://github.com/chloemd/DAT-1019-Chloe',
#    'homepage': None,
#    'size': 1456,
#    'stargazers_count': 1,
#    'watchers_count': 1,
#    'language': 'Jupyter Notebook',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 1,
#    'default_branch': 'main'}],
#  [{'id': 119903053,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkxMTk5MDMwNTM=',
#    'name': 'DP2',
#    'full_name': 'Gmarin10/DP2',
#    'private': False,
#    'owner': {'login': 'Gmarin10',
#     'id': 23226500,
#     'node_id': 'MDQ6VXNlcjIzMjI2NTAw',
#     'avatar_url': 'https://avatars1.githubusercontent.com/u/23226500?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/Gmarin10',
#     'html_url': 'https://github.com/Gmarin10',
#     'followers_url': 'https://api.github.com/users/Gmarin10/followers',
#     'following_url': 'https://api.github.com/users/Gmarin10/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/Gmarin10/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/Gmarin10/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/Gmarin10/subscriptions',
#     'organizations_url': 'https://api.github.com/users/Gmarin10/orgs',
#     'repos_url': 'https://api.github.com/users/Gmarin10/repos',
#     'events_url': 'https://api.github.com/users/Gmarin10/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/Gmarin10/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/Gmarin10/DP2',
#    'description': 'Senior design project',
#    'fork': False,
#    'url': 'https://api.github.com/repos/Gmarin10/DP2',
#    'forks_url': 'https://api.github.com/repos/Gmarin10/DP2/forks',
#    'keys_url': 'https://api.github.com/repos/Gmarin10/DP2/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/Gmarin10/DP2/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/Gmarin10/DP2/teams',
#    'hooks_url': 'https://api.github.com/repos/Gmarin10/DP2/hooks',
#    'issue_events_url': 'https://api.github.com/repos/Gmarin10/DP2/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/Gmarin10/DP2/events',
#    'assignees_url': 'https://api.github.com/repos/Gmarin10/DP2/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/Gmarin10/DP2/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/Gmarin10/DP2/tags',
#    'blobs_url': 'https://api.github.com/repos/Gmarin10/DP2/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/Gmarin10/DP2/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/Gmarin10/DP2/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/Gmarin10/DP2/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/Gmarin10/DP2/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/Gmarin10/DP2/languages',
#    'stargazers_url': 'https://api.github.com/repos/Gmarin10/DP2/stargazers',
#    'contributors_url': 'https://api.github.com/repos/Gmarin10/DP2/contributors',
#    'subscribers_url': 'https://api.github.com/repos/Gmarin10/DP2/subscribers',
#    'subscription_url': 'https://api.github.com/repos/Gmarin10/DP2/subscription',
#    'commits_url': 'https://api.github.com/repos/Gmarin10/DP2/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/Gmarin10/DP2/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/Gmarin10/DP2/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/Gmarin10/DP2/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/Gmarin10/DP2/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/Gmarin10/DP2/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/Gmarin10/DP2/merges',
#    'archive_url': 'https://api.github.com/repos/Gmarin10/DP2/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/Gmarin10/DP2/downloads',
#    'issues_url': 'https://api.github.com/repos/Gmarin10/DP2/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/Gmarin10/DP2/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/Gmarin10/DP2/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/Gmarin10/DP2/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/Gmarin10/DP2/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/Gmarin10/DP2/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/Gmarin10/DP2/deployments',
#    'created_at': '2018-02-01T22:47:29Z',
#    'updated_at': '2018-05-10T13:29:17Z',
#    'pushed_at': '2018-05-10T13:36:05Z',
#    'git_url': 'git://github.com/Gmarin10/DP2.git',
#    'ssh_url': 'git@github.com:Gmarin10/DP2.git',
#    'clone_url': 'https://github.com/Gmarin10/DP2.git',
#    'svn_url': 'https://github.com/Gmarin10/DP2',
#    'homepage': None,
#    'size': 8724,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': 'VHDL',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'forks_count': 1,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'forks': 1,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'master'},
#   {'id': 305542139,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkzMDU1NDIxMzk=',
#    'name': 'GA-DAT-1019',
#    'full_name': 'Gmarin10/GA-DAT-1019',
#    'private': False,
#    'owner': {'login': 'Gmarin10',
#     'id': 23226500,
#     'node_id': 'MDQ6VXNlcjIzMjI2NTAw',
#     'avatar_url': 'https://avatars1.githubusercontent.com/u/23226500?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/Gmarin10',
#     'html_url': 'https://github.com/Gmarin10',
#     'followers_url': 'https://api.github.com/users/Gmarin10/followers',
#     'following_url': 'https://api.github.com/users/Gmarin10/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/Gmarin10/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/Gmarin10/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/Gmarin10/subscriptions',
#     'organizations_url': 'https://api.github.com/users/Gmarin10/orgs',
#     'repos_url': 'https://api.github.com/users/Gmarin10/repos',
#     'events_url': 'https://api.github.com/users/Gmarin10/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/Gmarin10/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/Gmarin10/GA-DAT-1019',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/Gmarin10/GA-DAT-1019',
#    'forks_url': 'https://api.github.com/repos/Gmarin10/GA-DAT-1019/forks',
#    'keys_url': 'https://api.github.com/repos/Gmarin10/GA-DAT-1019/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/Gmarin10/GA-DAT-1019/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/Gmarin10/GA-DAT-1019/teams',
#    'hooks_url': 'https://api.github.com/repos/Gmarin10/GA-DAT-1019/hooks',
#    'issue_events_url': 'https://api.github.com/repos/Gmarin10/GA-DAT-1019/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/Gmarin10/GA-DAT-1019/events',
#    'assignees_url': 'https://api.github.com/repos/Gmarin10/GA-DAT-1019/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/Gmarin10/GA-DAT-1019/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/Gmarin10/GA-DAT-1019/tags',
#    'blobs_url': 'https://api.github.com/repos/Gmarin10/GA-DAT-1019/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/Gmarin10/GA-DAT-1019/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/Gmarin10/GA-DAT-1019/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/Gmarin10/GA-DAT-1019/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/Gmarin10/GA-DAT-1019/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/Gmarin10/GA-DAT-1019/languages',
#    'stargazers_url': 'https://api.github.com/repos/Gmarin10/GA-DAT-1019/stargazers',
#    'contributors_url': 'https://api.github.com/repos/Gmarin10/GA-DAT-1019/contributors',
#    'subscribers_url': 'https://api.github.com/repos/Gmarin10/GA-DAT-1019/subscribers',
#    'subscription_url': 'https://api.github.com/repos/Gmarin10/GA-DAT-1019/subscription',
#    'commits_url': 'https://api.github.com/repos/Gmarin10/GA-DAT-1019/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/Gmarin10/GA-DAT-1019/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/Gmarin10/GA-DAT-1019/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/Gmarin10/GA-DAT-1019/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/Gmarin10/GA-DAT-1019/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/Gmarin10/GA-DAT-1019/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/Gmarin10/GA-DAT-1019/merges',
#    'archive_url': 'https://api.github.com/repos/Gmarin10/GA-DAT-1019/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/Gmarin10/GA-DAT-1019/downloads',
#    'issues_url': 'https://api.github.com/repos/Gmarin10/GA-DAT-1019/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/Gmarin10/GA-DAT-1019/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/Gmarin10/GA-DAT-1019/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/Gmarin10/GA-DAT-1019/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/Gmarin10/GA-DAT-1019/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/Gmarin10/GA-DAT-1019/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/Gmarin10/GA-DAT-1019/deployments',
#    'created_at': '2020-10-20T00:00:09Z',
#    'updated_at': '2020-10-21T20:58:00Z',
#    'pushed_at': '2020-10-21T20:57:58Z',
#    'git_url': 'git://github.com/Gmarin10/GA-DAT-1019.git',
#    'ssh_url': 'git@github.com:Gmarin10/GA-DAT-1019.git',
#    'clone_url': 'https://github.com/Gmarin10/GA-DAT-1019.git',
#    'svn_url': 'https://github.com/Gmarin10/GA-DAT-1019',
#    'homepage': None,
#    'size': 1056,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': 'Jupyter Notebook',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'main'},
#   {'id': 191462349,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkxOTE0NjIzNDk=',
#    'name': 'Project-Basta',
#    'full_name': 'Gmarin10/Project-Basta',
#    'private': False,
#    'owner': {'login': 'Gmarin10',
#     'id': 23226500,
#     'node_id': 'MDQ6VXNlcjIzMjI2NTAw',
#     'avatar_url': 'https://avatars1.githubusercontent.com/u/23226500?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/Gmarin10',
#     'html_url': 'https://github.com/Gmarin10',
#     'followers_url': 'https://api.github.com/users/Gmarin10/followers',
#     'following_url': 'https://api.github.com/users/Gmarin10/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/Gmarin10/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/Gmarin10/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/Gmarin10/subscriptions',
#     'organizations_url': 'https://api.github.com/users/Gmarin10/orgs',
#     'repos_url': 'https://api.github.com/users/Gmarin10/repos',
#     'events_url': 'https://api.github.com/users/Gmarin10/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/Gmarin10/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/Gmarin10/Project-Basta',
#    'description': 'An algorithm that utilizes the Python Airtable API to match Basta Fellows to new job positions on the Basta Job Board',
#    'fork': False,
#    'url': 'https://api.github.com/repos/Gmarin10/Project-Basta',
#    'forks_url': 'https://api.github.com/repos/Gmarin10/Project-Basta/forks',
#    'keys_url': 'https://api.github.com/repos/Gmarin10/Project-Basta/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/Gmarin10/Project-Basta/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/Gmarin10/Project-Basta/teams',
#    'hooks_url': 'https://api.github.com/repos/Gmarin10/Project-Basta/hooks',
#    'issue_events_url': 'https://api.github.com/repos/Gmarin10/Project-Basta/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/Gmarin10/Project-Basta/events',
#    'assignees_url': 'https://api.github.com/repos/Gmarin10/Project-Basta/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/Gmarin10/Project-Basta/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/Gmarin10/Project-Basta/tags',
#    'blobs_url': 'https://api.github.com/repos/Gmarin10/Project-Basta/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/Gmarin10/Project-Basta/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/Gmarin10/Project-Basta/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/Gmarin10/Project-Basta/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/Gmarin10/Project-Basta/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/Gmarin10/Project-Basta/languages',
#    'stargazers_url': 'https://api.github.com/repos/Gmarin10/Project-Basta/stargazers',
#    'contributors_url': 'https://api.github.com/repos/Gmarin10/Project-Basta/contributors',
#    'subscribers_url': 'https://api.github.com/repos/Gmarin10/Project-Basta/subscribers',
#    'subscription_url': 'https://api.github.com/repos/Gmarin10/Project-Basta/subscription',
#    'commits_url': 'https://api.github.com/repos/Gmarin10/Project-Basta/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/Gmarin10/Project-Basta/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/Gmarin10/Project-Basta/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/Gmarin10/Project-Basta/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/Gmarin10/Project-Basta/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/Gmarin10/Project-Basta/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/Gmarin10/Project-Basta/merges',
#    'archive_url': 'https://api.github.com/repos/Gmarin10/Project-Basta/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/Gmarin10/Project-Basta/downloads',
#    'issues_url': 'https://api.github.com/repos/Gmarin10/Project-Basta/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/Gmarin10/Project-Basta/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/Gmarin10/Project-Basta/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/Gmarin10/Project-Basta/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/Gmarin10/Project-Basta/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/Gmarin10/Project-Basta/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/Gmarin10/Project-Basta/deployments',
#    'created_at': '2019-06-11T23:08:20Z',
#    'updated_at': '2019-07-25T20:18:06Z',
#    'pushed_at': '2019-07-25T20:18:05Z',
#    'git_url': 'git://github.com/Gmarin10/Project-Basta.git',
#    'ssh_url': 'git@github.com:Gmarin10/Project-Basta.git',
#    'clone_url': 'https://github.com/Gmarin10/Project-Basta.git',
#    'svn_url': 'https://github.com/Gmarin10/Project-Basta',
#    'homepage': '',
#    'size': 25,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'gpl-3.0',
#     'name': 'GNU General Public License v3.0',
#     'spdx_id': 'GPL-3.0',
#     'url': 'https://api.github.com/licenses/gpl-3.0',
#     'node_id': 'MDc6TGljZW5zZTk='},
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'master'},
#   {'id': 193592471,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkxOTM1OTI0NzE=',
#    'name': 'Wallbreakers',
#    'full_name': 'Gmarin10/Wallbreakers',
#    'private': False,
#    'owner': {'login': 'Gmarin10',
#     'id': 23226500,
#     'node_id': 'MDQ6VXNlcjIzMjI2NTAw',
#     'avatar_url': 'https://avatars1.githubusercontent.com/u/23226500?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/Gmarin10',
#     'html_url': 'https://github.com/Gmarin10',
#     'followers_url': 'https://api.github.com/users/Gmarin10/followers',
#     'following_url': 'https://api.github.com/users/Gmarin10/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/Gmarin10/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/Gmarin10/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/Gmarin10/subscriptions',
#     'organizations_url': 'https://api.github.com/users/Gmarin10/orgs',
#     'repos_url': 'https://api.github.com/users/Gmarin10/repos',
#     'events_url': 'https://api.github.com/users/Gmarin10/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/Gmarin10/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/Gmarin10/Wallbreakers',
#    'description': 'weekly coding exercises for Wallbreakers fellowship',
#    'fork': False,
#    'url': 'https://api.github.com/repos/Gmarin10/Wallbreakers',
#    'forks_url': 'https://api.github.com/repos/Gmarin10/Wallbreakers/forks',
#    'keys_url': 'https://api.github.com/repos/Gmarin10/Wallbreakers/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/Gmarin10/Wallbreakers/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/Gmarin10/Wallbreakers/teams',
#    'hooks_url': 'https://api.github.com/repos/Gmarin10/Wallbreakers/hooks',
#    'issue_events_url': 'https://api.github.com/repos/Gmarin10/Wallbreakers/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/Gmarin10/Wallbreakers/events',
#    'assignees_url': 'https://api.github.com/repos/Gmarin10/Wallbreakers/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/Gmarin10/Wallbreakers/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/Gmarin10/Wallbreakers/tags',
#    'blobs_url': 'https://api.github.com/repos/Gmarin10/Wallbreakers/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/Gmarin10/Wallbreakers/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/Gmarin10/Wallbreakers/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/Gmarin10/Wallbreakers/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/Gmarin10/Wallbreakers/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/Gmarin10/Wallbreakers/languages',
#    'stargazers_url': 'https://api.github.com/repos/Gmarin10/Wallbreakers/stargazers',
#    'contributors_url': 'https://api.github.com/repos/Gmarin10/Wallbreakers/contributors',
#    'subscribers_url': 'https://api.github.com/repos/Gmarin10/Wallbreakers/subscribers',
#    'subscription_url': 'https://api.github.com/repos/Gmarin10/Wallbreakers/subscription',
#    'commits_url': 'https://api.github.com/repos/Gmarin10/Wallbreakers/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/Gmarin10/Wallbreakers/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/Gmarin10/Wallbreakers/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/Gmarin10/Wallbreakers/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/Gmarin10/Wallbreakers/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/Gmarin10/Wallbreakers/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/Gmarin10/Wallbreakers/merges',
#    'archive_url': 'https://api.github.com/repos/Gmarin10/Wallbreakers/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/Gmarin10/Wallbreakers/downloads',
#    'issues_url': 'https://api.github.com/repos/Gmarin10/Wallbreakers/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/Gmarin10/Wallbreakers/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/Gmarin10/Wallbreakers/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/Gmarin10/Wallbreakers/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/Gmarin10/Wallbreakers/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/Gmarin10/Wallbreakers/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/Gmarin10/Wallbreakers/deployments',
#    'created_at': '2019-06-24T22:59:34Z',
#    'updated_at': '2019-06-26T15:46:04Z',
#    'pushed_at': '2019-06-26T15:46:02Z',
#    'git_url': 'git://github.com/Gmarin10/Wallbreakers.git',
#    'ssh_url': 'git@github.com:Gmarin10/Wallbreakers.git',
#    'clone_url': 'https://github.com/Gmarin10/Wallbreakers.git',
#    'svn_url': 'https://github.com/Gmarin10/Wallbreakers',
#    'homepage': None,
#    'size': 10,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'mit',
#     'name': 'MIT License',
#     'spdx_id': 'MIT',
#     'url': 'https://api.github.com/licenses/mit',
#     'node_id': 'MDc6TGljZW5zZTEz'},
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'master'}],
#  [{'id': 305542132,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkzMDU1NDIxMzI=',
#    'name': 'Test-Repo',
#    'full_name': 'clefevre01/Test-Repo',
#    'private': False,
#    'owner': {'login': 'clefevre01',
#     'id': 73093116,
#     'node_id': 'MDQ6VXNlcjczMDkzMTE2',
#     'avatar_url': 'https://avatars3.githubusercontent.com/u/73093116?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/clefevre01',
#     'html_url': 'https://github.com/clefevre01',
#     'followers_url': 'https://api.github.com/users/clefevre01/followers',
#     'following_url': 'https://api.github.com/users/clefevre01/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/clefevre01/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/clefevre01/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/clefevre01/subscriptions',
#     'organizations_url': 'https://api.github.com/users/clefevre01/orgs',
#     'repos_url': 'https://api.github.com/users/clefevre01/repos',
#     'events_url': 'https://api.github.com/users/clefevre01/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/clefevre01/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/clefevre01/Test-Repo',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/clefevre01/Test-Repo',
#    'forks_url': 'https://api.github.com/repos/clefevre01/Test-Repo/forks',
#    'keys_url': 'https://api.github.com/repos/clefevre01/Test-Repo/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/clefevre01/Test-Repo/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/clefevre01/Test-Repo/teams',
#    'hooks_url': 'https://api.github.com/repos/clefevre01/Test-Repo/hooks',
#    'issue_events_url': 'https://api.github.com/repos/clefevre01/Test-Repo/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/clefevre01/Test-Repo/events',
#    'assignees_url': 'https://api.github.com/repos/clefevre01/Test-Repo/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/clefevre01/Test-Repo/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/clefevre01/Test-Repo/tags',
#    'blobs_url': 'https://api.github.com/repos/clefevre01/Test-Repo/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/clefevre01/Test-Repo/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/clefevre01/Test-Repo/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/clefevre01/Test-Repo/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/clefevre01/Test-Repo/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/clefevre01/Test-Repo/languages',
#    'stargazers_url': 'https://api.github.com/repos/clefevre01/Test-Repo/stargazers',
#    'contributors_url': 'https://api.github.com/repos/clefevre01/Test-Repo/contributors',
#    'subscribers_url': 'https://api.github.com/repos/clefevre01/Test-Repo/subscribers',
#    'subscription_url': 'https://api.github.com/repos/clefevre01/Test-Repo/subscription',
#    'commits_url': 'https://api.github.com/repos/clefevre01/Test-Repo/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/clefevre01/Test-Repo/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/clefevre01/Test-Repo/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/clefevre01/Test-Repo/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/clefevre01/Test-Repo/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/clefevre01/Test-Repo/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/clefevre01/Test-Repo/merges',
#    'archive_url': 'https://api.github.com/repos/clefevre01/Test-Repo/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/clefevre01/Test-Repo/downloads',
#    'issues_url': 'https://api.github.com/repos/clefevre01/Test-Repo/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/clefevre01/Test-Repo/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/clefevre01/Test-Repo/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/clefevre01/Test-Repo/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/clefevre01/Test-Repo/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/clefevre01/Test-Repo/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/clefevre01/Test-Repo/deployments',
#    'created_at': '2020-10-20T00:00:08Z',
#    'updated_at': '2020-10-21T22:00:19Z',
#    'pushed_at': '2020-10-21T22:00:16Z',
#    'git_url': 'git://github.com/clefevre01/Test-Repo.git',
#    'ssh_url': 'git@github.com:clefevre01/Test-Repo.git',
#    'clone_url': 'https://github.com/clefevre01/Test-Repo.git',
#    'svn_url': 'https://github.com/clefevre01/Test-Repo',
#    'homepage': None,
#    'size': 1066,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': 'Jupyter Notebook',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'main'}],
#  [{'id': 305542154,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkzMDU1NDIxNTQ=',
#    'name': 'DAT-1019',
#    'full_name': 'ladipoore/DAT-1019',
#    'private': False,
#    'owner': {'login': 'ladipoore',
#     'id': 22856225,
#     'node_id': 'MDQ6VXNlcjIyODU2MjI1',
#     'avatar_url': 'https://avatars0.githubusercontent.com/u/22856225?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/ladipoore',
#     'html_url': 'https://github.com/ladipoore',
#     'followers_url': 'https://api.github.com/users/ladipoore/followers',
#     'following_url': 'https://api.github.com/users/ladipoore/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/ladipoore/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/ladipoore/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/ladipoore/subscriptions',
#     'organizations_url': 'https://api.github.com/users/ladipoore/orgs',
#     'repos_url': 'https://api.github.com/users/ladipoore/repos',
#     'events_url': 'https://api.github.com/users/ladipoore/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/ladipoore/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/ladipoore/DAT-1019',
#    'description': 'ga dat 1019 class',
#    'fork': False,
#    'url': 'https://api.github.com/repos/ladipoore/DAT-1019',
#    'forks_url': 'https://api.github.com/repos/ladipoore/DAT-1019/forks',
#    'keys_url': 'https://api.github.com/repos/ladipoore/DAT-1019/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/ladipoore/DAT-1019/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/ladipoore/DAT-1019/teams',
#    'hooks_url': 'https://api.github.com/repos/ladipoore/DAT-1019/hooks',
#    'issue_events_url': 'https://api.github.com/repos/ladipoore/DAT-1019/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/ladipoore/DAT-1019/events',
#    'assignees_url': 'https://api.github.com/repos/ladipoore/DAT-1019/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/ladipoore/DAT-1019/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/ladipoore/DAT-1019/tags',
#    'blobs_url': 'https://api.github.com/repos/ladipoore/DAT-1019/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/ladipoore/DAT-1019/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/ladipoore/DAT-1019/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/ladipoore/DAT-1019/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/ladipoore/DAT-1019/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/ladipoore/DAT-1019/languages',
#    'stargazers_url': 'https://api.github.com/repos/ladipoore/DAT-1019/stargazers',
#    'contributors_url': 'https://api.github.com/repos/ladipoore/DAT-1019/contributors',
#    'subscribers_url': 'https://api.github.com/repos/ladipoore/DAT-1019/subscribers',
#    'subscription_url': 'https://api.github.com/repos/ladipoore/DAT-1019/subscription',
#    'commits_url': 'https://api.github.com/repos/ladipoore/DAT-1019/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/ladipoore/DAT-1019/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/ladipoore/DAT-1019/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/ladipoore/DAT-1019/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/ladipoore/DAT-1019/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/ladipoore/DAT-1019/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/ladipoore/DAT-1019/merges',
#    'archive_url': 'https://api.github.com/repos/ladipoore/DAT-1019/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/ladipoore/DAT-1019/downloads',
#    'issues_url': 'https://api.github.com/repos/ladipoore/DAT-1019/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/ladipoore/DAT-1019/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/ladipoore/DAT-1019/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/ladipoore/DAT-1019/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/ladipoore/DAT-1019/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/ladipoore/DAT-1019/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/ladipoore/DAT-1019/deployments',
#    'created_at': '2020-10-20T00:00:13Z',
#    'updated_at': '2020-10-22T01:05:54Z',
#    'pushed_at': '2020-10-26T02:43:32Z',
#    'git_url': 'git://github.com/ladipoore/DAT-1019.git',
#    'ssh_url': 'git@github.com:ladipoore/DAT-1019.git',
#    'clone_url': 'https://github.com/ladipoore/DAT-1019.git',
#    'svn_url': 'https://github.com/ladipoore/DAT-1019',
#    'homepage': None,
#    'size': 729,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': 'Jupyter Notebook',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'main'},
#   {'id': 98481060,
#    'node_id': 'MDEwOlJlcG9zaXRvcnk5ODQ4MTA2MA==',
#    'name': 'EdgarSearch',
#    'full_name': 'ladipoore/EdgarSearch',
#    'private': False,
#    'owner': {'login': 'ladipoore',
#     'id': 22856225,
#     'node_id': 'MDQ6VXNlcjIyODU2MjI1',
#     'avatar_url': 'https://avatars0.githubusercontent.com/u/22856225?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/ladipoore',
#     'html_url': 'https://github.com/ladipoore',
#     'followers_url': 'https://api.github.com/users/ladipoore/followers',
#     'following_url': 'https://api.github.com/users/ladipoore/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/ladipoore/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/ladipoore/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/ladipoore/subscriptions',
#     'organizations_url': 'https://api.github.com/users/ladipoore/orgs',
#     'repos_url': 'https://api.github.com/users/ladipoore/repos',
#     'events_url': 'https://api.github.com/users/ladipoore/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/ladipoore/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/ladipoore/EdgarSearch',
#    'description': 'A script to download fillings from Edgar more efficiently',
#    'fork': False,
#    'url': 'https://api.github.com/repos/ladipoore/EdgarSearch',
#    'forks_url': 'https://api.github.com/repos/ladipoore/EdgarSearch/forks',
#    'keys_url': 'https://api.github.com/repos/ladipoore/EdgarSearch/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/ladipoore/EdgarSearch/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/ladipoore/EdgarSearch/teams',
#    'hooks_url': 'https://api.github.com/repos/ladipoore/EdgarSearch/hooks',
#    'issue_events_url': 'https://api.github.com/repos/ladipoore/EdgarSearch/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/ladipoore/EdgarSearch/events',
#    'assignees_url': 'https://api.github.com/repos/ladipoore/EdgarSearch/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/ladipoore/EdgarSearch/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/ladipoore/EdgarSearch/tags',
#    'blobs_url': 'https://api.github.com/repos/ladipoore/EdgarSearch/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/ladipoore/EdgarSearch/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/ladipoore/EdgarSearch/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/ladipoore/EdgarSearch/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/ladipoore/EdgarSearch/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/ladipoore/EdgarSearch/languages',
#    'stargazers_url': 'https://api.github.com/repos/ladipoore/EdgarSearch/stargazers',
#    'contributors_url': 'https://api.github.com/repos/ladipoore/EdgarSearch/contributors',
#    'subscribers_url': 'https://api.github.com/repos/ladipoore/EdgarSearch/subscribers',
#    'subscription_url': 'https://api.github.com/repos/ladipoore/EdgarSearch/subscription',
#    'commits_url': 'https://api.github.com/repos/ladipoore/EdgarSearch/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/ladipoore/EdgarSearch/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/ladipoore/EdgarSearch/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/ladipoore/EdgarSearch/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/ladipoore/EdgarSearch/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/ladipoore/EdgarSearch/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/ladipoore/EdgarSearch/merges',
#    'archive_url': 'https://api.github.com/repos/ladipoore/EdgarSearch/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/ladipoore/EdgarSearch/downloads',
#    'issues_url': 'https://api.github.com/repos/ladipoore/EdgarSearch/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/ladipoore/EdgarSearch/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/ladipoore/EdgarSearch/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/ladipoore/EdgarSearch/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/ladipoore/EdgarSearch/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/ladipoore/EdgarSearch/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/ladipoore/EdgarSearch/deployments',
#    'created_at': '2017-07-27T01:36:00Z',
#    'updated_at': '2017-07-27T01:37:48Z',
#    'pushed_at': '2017-07-27T01:37:47Z',
#    'git_url': 'git://github.com/ladipoore/EdgarSearch.git',
#    'ssh_url': 'git@github.com:ladipoore/EdgarSearch.git',
#    'clone_url': 'https://github.com/ladipoore/EdgarSearch.git',
#    'svn_url': 'https://github.com/ladipoore/EdgarSearch',
#    'homepage': None,
#    'size': 1,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'master'},
#   {'id': 81528354,
#    'node_id': 'MDEwOlJlcG9zaXRvcnk4MTUyODM1NA==',
#    'name': 'Euler',
#    'full_name': 'ladipoore/Euler',
#    'private': False,
#    'owner': {'login': 'ladipoore',
#     'id': 22856225,
#     'node_id': 'MDQ6VXNlcjIyODU2MjI1',
#     'avatar_url': 'https://avatars0.githubusercontent.com/u/22856225?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/ladipoore',
#     'html_url': 'https://github.com/ladipoore',
#     'followers_url': 'https://api.github.com/users/ladipoore/followers',
#     'following_url': 'https://api.github.com/users/ladipoore/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/ladipoore/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/ladipoore/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/ladipoore/subscriptions',
#     'organizations_url': 'https://api.github.com/users/ladipoore/orgs',
#     'repos_url': 'https://api.github.com/users/ladipoore/repos',
#     'events_url': 'https://api.github.com/users/ladipoore/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/ladipoore/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/ladipoore/Euler',
#    'description': 'trying out a few project euler problems in python',
#    'fork': False,
#    'url': 'https://api.github.com/repos/ladipoore/Euler',
#    'forks_url': 'https://api.github.com/repos/ladipoore/Euler/forks',
#    'keys_url': 'https://api.github.com/repos/ladipoore/Euler/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/ladipoore/Euler/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/ladipoore/Euler/teams',
#    'hooks_url': 'https://api.github.com/repos/ladipoore/Euler/hooks',
#    'issue_events_url': 'https://api.github.com/repos/ladipoore/Euler/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/ladipoore/Euler/events',
#    'assignees_url': 'https://api.github.com/repos/ladipoore/Euler/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/ladipoore/Euler/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/ladipoore/Euler/tags',
#    'blobs_url': 'https://api.github.com/repos/ladipoore/Euler/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/ladipoore/Euler/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/ladipoore/Euler/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/ladipoore/Euler/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/ladipoore/Euler/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/ladipoore/Euler/languages',
#    'stargazers_url': 'https://api.github.com/repos/ladipoore/Euler/stargazers',
#    'contributors_url': 'https://api.github.com/repos/ladipoore/Euler/contributors',
#    'subscribers_url': 'https://api.github.com/repos/ladipoore/Euler/subscribers',
#    'subscription_url': 'https://api.github.com/repos/ladipoore/Euler/subscription',
#    'commits_url': 'https://api.github.com/repos/ladipoore/Euler/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/ladipoore/Euler/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/ladipoore/Euler/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/ladipoore/Euler/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/ladipoore/Euler/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/ladipoore/Euler/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/ladipoore/Euler/merges',
#    'archive_url': 'https://api.github.com/repos/ladipoore/Euler/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/ladipoore/Euler/downloads',
#    'issues_url': 'https://api.github.com/repos/ladipoore/Euler/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/ladipoore/Euler/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/ladipoore/Euler/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/ladipoore/Euler/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/ladipoore/Euler/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/ladipoore/Euler/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/ladipoore/Euler/deployments',
#    'created_at': '2017-02-10T04:59:29Z',
#    'updated_at': '2017-02-10T04:59:29Z',
#    'pushed_at': '2017-02-25T01:38:11Z',
#    'git_url': 'git://github.com/ladipoore/Euler.git',
#    'ssh_url': 'git@github.com:ladipoore/Euler.git',
#    'clone_url': 'https://github.com/ladipoore/Euler.git',
#    'svn_url': 'https://github.com/ladipoore/Euler',
#    'homepage': None,
#    'size': 1,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': None,
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': True,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'forks': 0,
# ...
#     'followers_url': 'https://api.github.com/users/amandachernishkin/followers',
#     'following_url': 'https://api.github.com/users/amandachernishkin/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amandachernishkin/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amandachernishkin/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amandachernishkin/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amandachernishkin/orgs',
#     'repos_url': 'https://api.github.com/users/amandachernishkin/repos',
#     'events_url': 'https://api.github.com/users/amandachernishkin/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amandachernishkin/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/amandachernishkin/My_repo',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/amandachernishkin/My_repo',
#    'forks_url': 'https://api.github.com/repos/amandachernishkin/My_repo/forks',
#    'keys_url': 'https://api.github.com/repos/amandachernishkin/My_repo/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amandachernishkin/My_repo/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amandachernishkin/My_repo/teams',
#    'hooks_url': 'https://api.github.com/repos/amandachernishkin/My_repo/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amandachernishkin/My_repo/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amandachernishkin/My_repo/events',
#    'assignees_url': 'https://api.github.com/repos/amandachernishkin/My_repo/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amandachernishkin/My_repo/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amandachernishkin/My_repo/tags',
#    'blobs_url': 'https://api.github.com/repos/amandachernishkin/My_repo/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amandachernishkin/My_repo/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amandachernishkin/My_repo/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amandachernishkin/My_repo/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amandachernishkin/My_repo/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amandachernishkin/My_repo/languages',
#    'stargazers_url': 'https://api.github.com/repos/amandachernishkin/My_repo/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amandachernishkin/My_repo/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amandachernishkin/My_repo/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amandachernishkin/My_repo/subscription',
#    'commits_url': 'https://api.github.com/repos/amandachernishkin/My_repo/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amandachernishkin/My_repo/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amandachernishkin/My_repo/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amandachernishkin/My_repo/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amandachernishkin/My_repo/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amandachernishkin/My_repo/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amandachernishkin/My_repo/merges',
#    'archive_url': 'https://api.github.com/repos/amandachernishkin/My_repo/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amandachernishkin/My_repo/downloads',
#    'issues_url': 'https://api.github.com/repos/amandachernishkin/My_repo/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amandachernishkin/My_repo/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amandachernishkin/My_repo/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amandachernishkin/My_repo/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amandachernishkin/My_repo/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amandachernishkin/My_repo/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amandachernishkin/My_repo/deployments',
#    'created_at': '2020-10-20T00:00:08Z',
#    'updated_at': '2020-10-26T01:18:28Z',
#    'pushed_at': '2020-10-26T01:18:25Z',
#    'git_url': 'git://github.com/amandachernishkin/My_repo.git',
#    'ssh_url': 'git@github.com:amandachernishkin/My_repo.git',
#    'clone_url': 'https://github.com/amandachernishkin/My_repo.git',
#    'svn_url': 'https://github.com/amandachernishkin/My_repo',
#    'homepage': None,
#    'size': 722,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': 'Jupyter Notebook',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'main'}],
#  [{'id': 305542128,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkzMDU1NDIxMjg=',
#    'name': 'Data-Science',
#    'full_name': 'mayerjp01/Data-Science',
#    'private': False,
#    'owner': {'login': 'mayerjp01',
#     'id': 61216805,
#     'node_id': 'MDQ6VXNlcjYxMjE2ODA1',
#     'avatar_url': 'https://avatars2.githubusercontent.com/u/61216805?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/mayerjp01',
#     'html_url': 'https://github.com/mayerjp01',
#     'followers_url': 'https://api.github.com/users/mayerjp01/followers',
#     'following_url': 'https://api.github.com/users/mayerjp01/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/mayerjp01/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/mayerjp01/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/mayerjp01/subscriptions',
#     'organizations_url': 'https://api.github.com/users/mayerjp01/orgs',
#     'repos_url': 'https://api.github.com/users/mayerjp01/repos',
#     'events_url': 'https://api.github.com/users/mayerjp01/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/mayerjp01/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/mayerjp01/Data-Science',
#    'description': 'Stuff for Data Science',
#    'fork': False,
#    'url': 'https://api.github.com/repos/mayerjp01/Data-Science',
#    'forks_url': 'https://api.github.com/repos/mayerjp01/Data-Science/forks',
#    'keys_url': 'https://api.github.com/repos/mayerjp01/Data-Science/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/mayerjp01/Data-Science/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/mayerjp01/Data-Science/teams',
#    'hooks_url': 'https://api.github.com/repos/mayerjp01/Data-Science/hooks',
#    'issue_events_url': 'https://api.github.com/repos/mayerjp01/Data-Science/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/mayerjp01/Data-Science/events',
#    'assignees_url': 'https://api.github.com/repos/mayerjp01/Data-Science/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/mayerjp01/Data-Science/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/mayerjp01/Data-Science/tags',
#    'blobs_url': 'https://api.github.com/repos/mayerjp01/Data-Science/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/mayerjp01/Data-Science/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/mayerjp01/Data-Science/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/mayerjp01/Data-Science/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/mayerjp01/Data-Science/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/mayerjp01/Data-Science/languages',
#    'stargazers_url': 'https://api.github.com/repos/mayerjp01/Data-Science/stargazers',
#    'contributors_url': 'https://api.github.com/repos/mayerjp01/Data-Science/contributors',
#    'subscribers_url': 'https://api.github.com/repos/mayerjp01/Data-Science/subscribers',
#    'subscription_url': 'https://api.github.com/repos/mayerjp01/Data-Science/subscription',
#    'commits_url': 'https://api.github.com/repos/mayerjp01/Data-Science/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/mayerjp01/Data-Science/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/mayerjp01/Data-Science/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/mayerjp01/Data-Science/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/mayerjp01/Data-Science/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/mayerjp01/Data-Science/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/mayerjp01/Data-Science/merges',
#    'archive_url': 'https://api.github.com/repos/mayerjp01/Data-Science/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/mayerjp01/Data-Science/downloads',
#    'issues_url': 'https://api.github.com/repos/mayerjp01/Data-Science/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/mayerjp01/Data-Science/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/mayerjp01/Data-Science/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/mayerjp01/Data-Science/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/mayerjp01/Data-Science/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/mayerjp01/Data-Science/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/mayerjp01/Data-Science/deployments',
#    'created_at': '2020-10-20T00:00:07Z',
#    'updated_at': '2020-10-25T21:11:03Z',
#    'pushed_at': '2020-10-25T21:11:01Z',
#    'git_url': 'git://github.com/mayerjp01/Data-Science.git',
#    'ssh_url': 'git@github.com:mayerjp01/Data-Science.git',
#    'clone_url': 'https://github.com/mayerjp01/Data-Science.git',
#    'svn_url': 'https://github.com/mayerjp01/Data-Science',
#    'homepage': None,
#    'size': 1429,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': 'Jupyter Notebook',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'main'}],
#  [{'id': 305543627,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkzMDU1NDM2Mjc=',
#    'name': 'GA_DAT-10-19',
#    'full_name': 'nidhim03/GA_DAT-10-19',
#    'private': False,
#    'owner': {'login': 'nidhim03',
#     'id': 73145938,
#     'node_id': 'MDQ6VXNlcjczMTQ1OTM4',
#     'avatar_url': 'https://avatars0.githubusercontent.com/u/73145938?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/nidhim03',
#     'html_url': 'https://github.com/nidhim03',
#     'followers_url': 'https://api.github.com/users/nidhim03/followers',
#     'following_url': 'https://api.github.com/users/nidhim03/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/nidhim03/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/nidhim03/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/nidhim03/subscriptions',
#     'organizations_url': 'https://api.github.com/users/nidhim03/orgs',
#     'repos_url': 'https://api.github.com/users/nidhim03/repos',
#     'events_url': 'https://api.github.com/users/nidhim03/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/nidhim03/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/nidhim03/GA_DAT-10-19',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/nidhim03/GA_DAT-10-19',
#    'forks_url': 'https://api.github.com/repos/nidhim03/GA_DAT-10-19/forks',
#    'keys_url': 'https://api.github.com/repos/nidhim03/GA_DAT-10-19/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/nidhim03/GA_DAT-10-19/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/nidhim03/GA_DAT-10-19/teams',
#    'hooks_url': 'https://api.github.com/repos/nidhim03/GA_DAT-10-19/hooks',
#    'issue_events_url': 'https://api.github.com/repos/nidhim03/GA_DAT-10-19/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/nidhim03/GA_DAT-10-19/events',
#    'assignees_url': 'https://api.github.com/repos/nidhim03/GA_DAT-10-19/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/nidhim03/GA_DAT-10-19/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/nidhim03/GA_DAT-10-19/tags',
#    'blobs_url': 'https://api.github.com/repos/nidhim03/GA_DAT-10-19/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/nidhim03/GA_DAT-10-19/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/nidhim03/GA_DAT-10-19/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/nidhim03/GA_DAT-10-19/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/nidhim03/GA_DAT-10-19/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/nidhim03/GA_DAT-10-19/languages',
#    'stargazers_url': 'https://api.github.com/repos/nidhim03/GA_DAT-10-19/stargazers',
#    'contributors_url': 'https://api.github.com/repos/nidhim03/GA_DAT-10-19/contributors',
#    'subscribers_url': 'https://api.github.com/repos/nidhim03/GA_DAT-10-19/subscribers',
#    'subscription_url': 'https://api.github.com/repos/nidhim03/GA_DAT-10-19/subscription',
#    'commits_url': 'https://api.github.com/repos/nidhim03/GA_DAT-10-19/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/nidhim03/GA_DAT-10-19/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/nidhim03/GA_DAT-10-19/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/nidhim03/GA_DAT-10-19/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/nidhim03/GA_DAT-10-19/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/nidhim03/GA_DAT-10-19/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/nidhim03/GA_DAT-10-19/merges',
#    'archive_url': 'https://api.github.com/repos/nidhim03/GA_DAT-10-19/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/nidhim03/GA_DAT-10-19/downloads',
#    'issues_url': 'https://api.github.com/repos/nidhim03/GA_DAT-10-19/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/nidhim03/GA_DAT-10-19/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/nidhim03/GA_DAT-10-19/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/nidhim03/GA_DAT-10-19/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/nidhim03/GA_DAT-10-19/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/nidhim03/GA_DAT-10-19/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/nidhim03/GA_DAT-10-19/deployments',
#    'created_at': '2020-10-20T00:10:22Z',
#    'updated_at': '2020-10-20T00:31:31Z',
#    'pushed_at': '2020-10-20T00:31:28Z',
#    'git_url': 'git://github.com/nidhim03/GA_DAT-10-19.git',
#    'ssh_url': 'git@github.com:nidhim03/GA_DAT-10-19.git',
#    'clone_url': 'https://github.com/nidhim03/GA_DAT-10-19.git',
#    'svn_url': 'https://github.com/nidhim03/GA_DAT-10-19',
#    'homepage': None,
#    'size': 690,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': 'Jupyter Notebook',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'main'}]]

# %%
# notice that data is a list filled with strings that contain info about each line
data
# Out:
# ['Name,Repo\n',
#  'Jonathan Bechtel,https://github.com/JonathanBechtel\n',
#  'Aoife Duna,https://github.com/aoifeduna\n',
#  'Erik Lindernoren,https://github.com/eriklindernoren']

# %% [markdown]
# ### Step 2: Remove the `\n` from each item in the list, as well as the item that contains the header info.

# %%
# this loops through each item in the list, starting at position 1, and replace the \n character with nothing
cleaned_data = [repo.replace('\n', "") for repo in data[1:]]

# %%
# we can confirm now that these marks are no longer there
cleaned_data
# Out:
# ['Jonathan Bechtel,https://github.com/JonathanBechtel',
#  'Aoife Duna,https://github.com/aoifeduna',
#  'Erik Lindernoren,https://github.com/eriklindernoren']

# %% [markdown]
# ### Step 3:  Separate the username in each string from everything else

# %%
# we do the same thing, except we take the LAST item from the list returned by split()
usernames = [url.split('/')[-1] for url in repo_urls]

# %% [markdown]
# ### Step 4: Obtain the repo data for every single github username

# %%
# this part of the url will never change
base_url = 'https://api.github.com'

# %%
# this goes through every username, and inserts it into the api url, and then passes that into requests.get().json()
# to obtain a list of repos for every single user
repo_lists = [requests.get(f"{base_url}/users/{username}/repos").json() for username in usernames]

# %% [markdown]
# ### Step 5: Create a 'flat' list that contains every unique repo for every single user

# %% [markdown]
# Answer with list comprehension:

# %%
# this is a nested for-loop using a list comprehension that returns each item inside the inner list
repos = [repo for user in repo_lists for repo in user]

# %% [markdown]
# Nested loops with comprehensions can be difficult to interpret sometimes, so if a regular for-loop is easier to digest, this is a different way of writing the same thing:

# %%
repos = []

for user in repo_lists:
    for repo in user:
        repos.append(repo)

# %% [markdown]
# ### Step 6:  Get information about the name, owner, url, and date of every single repo.

# %%
# this creates a list of all the values for the name key
repo_names = [repo['name'] for repo in repos]
# ditto for the login key -- notice it's accessed inside the owner key
owners     = [repo['owner']['login'] for repo in repos]
# next two work the same way
urls       = [repo['html_url'] for repo in repos]
dates      = [repo['created_at'] for repo in repos]

# %% [markdown]
# ### Step 7:  Create a dictionary with the data created from step 7

# %%
data_dict = {
    'Owner': owners,
    'Name': repo_names,
    'URL': urls,
    'Date': dates
}

# %% [markdown]
# ### Step 8:  Pass your dictionary into the `pd.dataframe()` method to get your final dataset

# %%
import pandas as pd

# this will take your dictionary and turn it into a dataframe
df = pd.DataFrame(data_dict)

# %%
# look how pretty it is :)
df.head()
# Out:
#              Owner           Name  \
# 0  JonathanBechtel  cdc-dashboard
# 1  JonathanBechtel      DAT-01-21
# 2  JonathanBechtel      DAT-06-24
# 3  JonathanBechtel      DAT-10-14
# 4  JonathanBechtel           data
#
#                                                 URL                  Date
# 0  https://github.com/JonathanBechtel/cdc-dashboard  2016-11-02T14:39:37Z
# 1      https://github.com/JonathanBechtel/DAT-01-21  2020-01-21T12:57:43Z
# 2      https://github.com/JonathanBechtel/DAT-06-24  2019-06-26T15:12:49Z
# 3      https://github.com/JonathanBechtel/DAT-10-14  2019-10-14T16:13:47Z
# 4           https://github.com/JonathanBechtel/data  2019-01-14T22:09:06Z
